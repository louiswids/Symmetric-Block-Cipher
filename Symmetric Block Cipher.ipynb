# %% [markdown]
# # Cryptography and Information Security
# ## Symmetric Block Cipher assignment
#
# - Fathi Al Adha Hylmi (22/492195/PA/21008)
# - Louis Widi Anandaputra(22/492218/PA/21090)
#
# We well be constructing a symmetric block cipher for a text message. This method would also work with other data, but we will be implementing it on encrypting strings using the CBC structure (for more than 1 block data) in a feistel structure which uses a finite field arithmetic (addition operation) for a Galois Field(GF).
#
# 1 block wold contain 2^32 data and the finite field arithmetic would use a GF(2^16). The feistel structure rounds can be set as a parameter but we will be using a 16 rounds feistel structure. We also define several functions:
#
# - initialGenKey(length) --> intializing keys for both the key and initial vector (IV). Taking an integer parameter length (bytes)
# - subGenKey(key) --> creating subkeys for the feistel cipher encryption process. Taking an integer parameter (key)
# - reverseSubGenKey(last_key) --> reversing back the subkeys to the original key. Taking an integer parameter (last_key)
# - GFaddition(plain, key) --> Finite Field addition on GF(2^16). Taking integer parameters (plain) and (key)
# <br><br>
# - encrypt_messageCBC(blockList, key, iv, len_of_block, round) --> CBC structure encryption for all blocks. Taking string array parameter (blockList), bytearray parameters (key) and (iv), and integer parameters (len_of_block) and (round)
# - encrypt(plain_block, key) --> initial encryption with IV. Taking string parameter (plain_block) and bytearray parameter (key)
# - feistelEncrypt(plain, key, round) --> feistel structure block encryption. Taking bytearray parameter (plain) and (key), and taking integer parameter (round)
# <br><br>
# - decrypt_cipherCBC(list_cipher, key, iv, round) --> CBC structure decryption for all blocks. Taking bytearray parameters (list_cipher) and (iv), and taking integer parameters (key, round)
# - feistelDecrypt(cipher, key_int, round) --> feistel structure block decryption. Taking bytearray parameter (list) and integer parameters (key_int) and (round)
# - decrypt(cipher, key) --> decryption with IV
# <br><br>
# - breakMessage(message, len_of_blocks) --> breaking data into blocks. Taking string parameter (message) and taking integer parameters (len_of_blocks)
#
# ### reference for code: https://www.youtube.com/watch?v=wwTsRONdAaw
# <br><br>
# <img src = 'https://ctf-wiki.mahaloz.re/crypto/blockcipher/mode/figure/cbc_encryption.png'> <img src = 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Feistel_cipher_diagram_en.svg/300px-Feistel_cipher_diagram_en.svg.png'>

# %% [markdown]
# ## Keys and Finite Field Arithmetic

# %%
from os import urandom

# Initial key generator
def initialGenKey(length):
    return bytearray(urandom(length))
    
def subGenKey(key):
    # perform an addition by 1 and XOR by 1 and 0
    value = (key + 1) ^ 0x10
    # reset the value to 0 if it exceeds the maximum limit
    shifted_key = value & ((1 << 16) - 1)  # 16 bit limit
    print(f"Initial key: {key}; new key: {shifted_key}")
    return shifted_key
    
def reverseSubGenKey(last_key):
    # perform the inverse XOR operation to recover the value before XOR
    value = (last_key ^ 0x10)-1
    # reset the value to 0 if it exceeds the maximum limit
    key = value & ((1 << 16) - 1)# 16 bit limit
    print(f"Initial key: {last_key}; new key: {key}")
    return key
    
# we will be using a 2^16 finite field addition operation, which will be using XOR operation
def GFaddition(plain, key):
    value = plain ^ key
    value = value & ((1 << 16) - 1)
    return value

# %% [markdown]
# ## Encryption

# %%
def encrypt_messageCBC(blockList, key, iv, len_of_block, round):
    list_of_ciphers = []
    for i in range(len(blockList)):
        print (f"\nBlock {i}:\n{blockList[i]}\n")
        # performing initial encryption with initial vector
        cipher1 = encrypt(blockList[i], iv)
        # performing the feistel cipher encryption
        cipher2, key_last = feistelEncrypt(cipher1, key, round)
        list_of_ciphers.append(cipher2)
        iv = cipher2
    return list_of_ciphers, key_last

# %%
def encrypt(plain_block, key):
    return bytearray([ord(plain_block[i]) ^ key[i] for i in range(len(plain_block))])

# %%
def feistelEncrypt(plain, key, round):
    # Changing key and plaintext into integers for encryption process
    key_int = int.from_bytes(key, byteorder='big')
    plain = int.from_bytes(plain, byteorder='big')

    # Splitting the bits to half (16 - 16)
    left = plain >> 16
    right = plain & 0xffff
    print(f"Initial left partition: {left}\nInitial right partition: {right}\n")

    # feistel structure
    for k in range ( round):  #rounds
        right = GFaddition(right, key_int) # Using the Galois Field encryption
        left = left ^ right
        print(f"Round {k+1}:Round {k+1}:\n right partition(after applied F, Key:{key_int}): {right}\n left partition(after XOR with right, right:{right}): {left}")

        # generating new subkey
        key_int = subGenKey(key_int)

        #switching the left and right data
        temp = right
        right = left
        left = temp
        print(f"Round {k+1} switching results:\n left partition: {left}\n right partition: {right}\n")

    # final switch for the left and right data   
    temp = right
    right = left
    left = temp    
    print(f"Final left partition: {left}\nInitial right partition: {right}\n")
    
    key = key_int
    # making sure the length is still 2^16
    encrypted_block = (left <<16)|right
    # changing back into bytes
    encrypted_block = encrypted_block.to_bytes((encrypted_block.bit_length() + 7) // 8, byteorder='big')
    return encrypted_block, key

# %% [markdown]
# ## Decryption

# %%
def decrypt_cipherCBC(list_cipher, key, iv, round):
    list_of_decrypted_blocks = []
    temp, key_last = feistelDecrypt(list_cipher[0], key, round)
    plain = decrypt(temp, iv)
    list_of_decrypted_blocks.append(plain)
    for i in range(1, len(list_cipher)):
        temp, key_last = feistelDecrypt(list_cipher[i], key, round)
        plain = decrypt(temp, list_cipher[i-1])
        list_of_decrypted_blocks.append(plain)
    return list_of_decrypted_blocks

# %%
# Change this according to the feistel encryption method
def feistelDecrypt(cipher, key_int, round):
    cipher = int.from_bytes(cipher, byteorder='big')
    key_int = reverseSubGenKey(key_int)
    left = cipher >> 16
    right = cipher & 0xffff
    print(f"Initial left partition: {left}\nInitial right partition: {right}\n")
  
    for k in range (round):  #rounds
        left = left ^ right
        right = GFaddition(right, key_int)
        
        print(f"Round {k+1}:\n right partition(after applied F, Key:{key_int}): {right}\n left partition(after XOR with right, right:{right}): {left}")
        
        key_int = reverseSubGenKey(key_int)
        temp = right
        right = left
        left = temp
        print(f"Round {k+1} switching results:\n left partition: {left}\n right partition: {right}\n")

    temp = right
    right = left
    left = temp
    print(f"Final left partition: {left}\nInitial right partition: {right}\n")
    
    key = key_int
    decrypted_block = (left <<16)|right
    decrypted_block = decrypted_block.to_bytes((decrypted_block.bit_length() + 7) // 8, byteorder='big')
    return decrypted_block, key

# %%
# Change this according to the feistel encryption method
def decrypt(cipher, key):
    return [chr(cipher[i] ^ key[i]) for i in range(len(cipher))]

# %% [markdown]
# ## Block Creation

# %%
def breakMessage(message, len_of_blocks):
    list_of_blocks = []
    for i in range (0, len(message), len_of_blocks):
        block = message[i:i+len_of_block]
        if(len(block) == len_of_blocks):
            list_of_blocks.append(block)
        else:
            c = len_of_blocks - len(block)
            for i in range(c):
                block = block + " "
            list_of_blocks.append(block)
    return list_of_blocks

# %% [markdown]
# ## Demo

# %%
# Initialization
text = "Hello world! This is Hylmi and Louis"
len_of_block = 4
len_of_feistel = 2
round = 16
blockList = breakMessage(text, len_of_block)

# %%
key = initialGenKey(len_of_feistel)
iv = initialGenKey(len_of_block)

# %%
print(f"Key: {key}\nIV: {iv}")
# Out:
# Key: bytearray(b'E\xd4')
# IV: bytearray(b'vF\x1dK')

# %%
# encryption
cipher_list, key_last_used= encrypt_messageCBC(blockList, key, iv, len_of_block, round = round)
# Out:
# Block 0:
# Hell
#
# Initial left partition: 15907
# Initial right partition: 28967
#
# Round 1:Round 1:
#  right partition(after applied F, Key:17876): 13555
#  left partition(after XOR with right, right:13555): 2768
# Initial key: 17876; new key: 17861
# Round 1 switching results:
#  left partition: 13555
#  right partition: 2768
#
# Round 2:Round 2:
#  right partition(after applied F, Key:17861): 20245
#  left partition(after XOR with right, right:20245): 31718
# Initial key: 17861; new key: 17878
# Round 2 switching results:
#  left partition: 20245
#  right partition: 31718
#
# Round 3:Round 3:
#  right partition(after applied F, Key:17878): 15920
#  left partition(after XOR with right, right:15920): 28965
# Initial key: 17878; new key: 17863
# Round 3 switching results:
#  left partition: 15920
#  right partition: 28965
#
# Round 4:Round 4:
#  right partition(after applied F, Key:17863): 13538
#  left partition(after XOR with right, right:13538): 2770
# Initial key: 17863; new key: 17880
# Round 4 switching results:
#  left partition: 13538
#  right partition: 2770
#
# Round 5:Round 5:
#  right partition(after applied F, Key:17880): 20234
#  left partition(after XOR with right, right:20234): 31720
# Initial key: 17880; new key: 17865
# Round 5 switching results:
#  left partition: 20234
#  right partition: 31720
#
# Round 6:Round 6:
#  right partition(after applied F, Key:17865): 15905
#  left partition(after XOR with right, right:15905): 28971
# Initial key: 17865; new key: 17882
# Round 6 switching results:
#  left partition: 15905
#  right partition: 28971
#
# Round 7:Round 7:
#  right partition(after applied F, Key:17882): 13553
#  left partition(after XOR with right, right:13553): 2768
# Initial key: 17882; new key: 17867
# Round 7 switching results:
#  left partition: 13553
#  right partition: 2768
#
# Round 8:Round 8:
#  right partition(after applied F, Key:17867): 20251
#  left partition(after XOR with right, right:20251): 31722
# Initial key: 17867; new key: 17884
# Round 8 switching results:
#  left partition: 20251
#  right partition: 31722
#
# Round 9:Round 9:
#  right partition(after applied F, Key:17884): 15926
#  left partition(after XOR with right, right:15926): 28973
# Initial key: 17884; new key: 17869
# Round 9 switching results:
#  left partition: 15926
#  right partition: 28973
#
# Round 10:Round 10:
#  right partition(after applied F, Key:17869): 13536
#  left partition(after XOR with right, right:13536): 2774
# Initial key: 17869; new key: 17886
# Round 10 switching results:
#  left partition: 13536
#  right partition: 2774
#
# Round 11:Round 11:
#  right partition(after applied F, Key:17886): 20232
#  left partition(after XOR with right, right:20232): 31720
# Initial key: 17886; new key: 17871
# Round 11 switching results:
#  left partition: 20232
#  right partition: 31720
#
# Round 12:Round 12:
#  right partition(after applied F, Key:17871): 15911
#  left partition(after XOR with right, right:15911): 28975
# Initial key: 17871; new key: 17856
# Round 12 switching results:
#  left partition: 15911
#  right partition: 28975
#
# Round 13:Round 13:
#  right partition(after applied F, Key:17856): 13551
#  left partition(after XOR with right, right:13551): 2760
# Initial key: 17856; new key: 17873
# Round 13 switching results:
#  left partition: 13551
#  right partition: 2760
#
# Round 14:Round 14:
#  right partition(after applied F, Key:17873): 20249
#  left partition(after XOR with right, right:20249): 31734
# Initial key: 17873; new key: 17858
# Round 14 switching results:
#  left partition: 20249
#  right partition: 31734
#
# Round 15:Round 15:
#  right partition(after applied F, Key:17858): 15924
#  left partition(after XOR with right, right:15924): 28973
# Initial key: 17858; new key: 17875
# Round 15 switching results:
#  left partition: 15924
#  right partition: 28973
#
# Round 16:Round 16:
#  right partition(after applied F, Key:17875): 13566
#  left partition(after XOR with right, right:13566): 2762
# Initial key: 17875; new key: 17860
# Round 16 switching results:
#  left partition: 13566
#  right partition: 2762
#
# Final left partition: 2762
# Initial right partition: 13566
#
#
# Block 1:
# o wo
#
# Initial left partition: 26090
# Initial right partition: 17297
#
# Round 1:Round 1:
#  right partition(after applied F, Key:17876): 1605
#  left partition(after XOR with right, right:1605): 25519
# Initial key: 17876; new key: 17861
# Round 1 switching results:
#  left partition: 1605
#  right partition: 25519
#
# Round 2:Round 2:
#  right partition(after applied F, Key:17861): 9834
#  left partition(after XOR with right, right:9834): 8239
# Initial key: 17861; new key: 17878
# Round 2 switching results:
#  left partition: 9834
#  right partition: 8239
#
# Round 3:Round 3:
#  right partition(after applied F, Key:17878): 26105
#  left partition(after XOR with right, right:26105): 17299
# Initial key: 17878; new key: 17863
# Round 3 switching results:
#  left partition: 26105
#  right partition: 17299
#
# Round 4:Round 4:
#  right partition(after applied F, Key:17863): 1620
#  left partition(after XOR with right, right:1620): 25517
# Initial key: 17863; new key: 17880
# Round 4 switching results:
#  left partition: 1620
#  right partition: 25517
#
# Round 5:Round 5:
#  right partition(after applied F, Key:17880): 9845
#  left partition(after XOR with right, right:9845): 8225
# Initial key: 17880; new key: 17865
# Round 5 switching results:
#  left partition: 9845
#  right partition: 8225
#
# Round 6:Round 6:
#  right partition(after applied F, Key:17865): 26088
#  left partition(after XOR with right, right:26088): 17309
# Initial key: 17865; new key: 17882
# Round 6 switching results:
#  left partition: 26088
#  right partition: 17309
#
# Round 7:Round 7:
#  right partition(after applied F, Key:17882): 1607
#  left partition(after XOR with right, right:1607): 25519
# Initial key: 17882; new key: 17867
# Round 7 switching results:
#  left partition: 1607
#  right partition: 25519
#
# Round 8:Round 8:
#  right partition(after applied F, Key:17867): 9828
#  left partition(after XOR with right, right:9828): 8227
# Initial key: 17867; new key: 17884
# Round 8 switching results:
#  left partition: 9828
#  right partition: 8227
#
# Round 9:Round 9:
#  right partition(after applied F, Key:17884): 26111
#  left partition(after XOR with right, right:26111): 17307
# Initial key: 17884; new key: 17869
# Round 9 switching results:
#  left partition: 26111
#  right partition: 17307
#
# Round 10:Round 10:
#  right partition(after applied F, Key:17869): 1622
#  left partition(after XOR with right, right:1622): 25513
# Initial key: 17869; new key: 17886
# Round 10 switching results:
#  left partition: 1622
#  right partition: 25513
#
# Round 11:Round 11:
#  right partition(after applied F, Key:17886): 9847
#  left partition(after XOR with right, right:9847): 8225
# Initial key: 17886; new key: 17871
# Round 11 switching results:
#  left partition: 9847
#  right partition: 8225
#
# Round 12:Round 12:
#  right partition(after applied F, Key:17871): 26094
#  left partition(after XOR with right, right:26094): 17305
# Initial key: 17871; new key: 17856
# Round 12 switching results:
#  left partition: 26094
#  right partition: 17305
#
# Round 13:Round 13:
#  right partition(after applied F, Key:17856): 1625
#  left partition(after XOR with right, right:1625): 25527
# Initial key: 17856; new key: 17873
# Round 13 switching results:
#  left partition: 1625
#  right partition: 25527
#
# Round 14:Round 14:
#  right partition(after applied F, Key:17873): 9830
#  left partition(after XOR with right, right:9830): 8255
# Initial key: 17873; new key: 17858
# Round 14 switching results:
#  left partition: 9830
#  right partition: 8255
#
# Round 15:Round 15:
#  right partition(after applied F, Key:17858): 26109
#  left partition(after XOR with right, right:26109): 17307
# Initial key: 17858; new key: 17875
# Round 15 switching results:
#  left partition: 26109
#  right partition: 17307
#
# Round 16:Round 16:
#  right partition(after applied F, Key:17875): 1608
#  left partition(after XOR with right, right:1608): 25525
# Initial key: 17875; new key: 17860
# Round 16 switching results:
#  left partition: 1608
#  right partition: 25525
#
# Final left partition: 25525
# Initial right partition: 1608
#
#
# Block 2:
# rld!
#
# Initial left partition: 4569
# Initial right partition: 25193
#
# Round 1:Round 1:
#  right partition(after applied F, Key:17876): 10173
#  left partition(after XOR with right, right:10173): 13924
# Initial key: 17876; new key: 17861
# Round 1 switching results:
#  left partition: 10173
#  right partition: 13924
#
# Round 2:Round 2:
#  right partition(after applied F, Key:17861): 29601
#  left partition(after XOR with right, right:29601): 21532
# Initial key: 17861; new key: 17878
# Round 2 switching results:
#  left partition: 29601
#  right partition: 21532
#
# Round 3:Round 3:
#  right partition(after applied F, Key:17878): 4554
#  left partition(after XOR with right, right:4554): 25195
# Initial key: 17878; new key: 17863
# Round 3 switching results:
#  left partition: 4554
#  right partition: 25195
#
# Round 4:Round 4:
#  right partition(after applied F, Key:17863): 10156
#  left partition(after XOR with right, right:10156): 13926
# Initial key: 17863; new key: 17880
# Round 4 switching results:
#  left partition: 10156
#  right partition: 13926
#
# Round 5:Round 5:
#  right partition(after applied F, Key:17880): 29630
#  left partition(after XOR with right, right:29630): 21522
# Initial key: 17880; new key: 17865
# Round 5 switching results:
#  left partition: 29630
#  right partition: 21522
#
# Round 6:Round 6:
#  right partition(after applied F, Key:17865): 4571
#  left partition(after XOR with right, right:4571): 25189
# Initial key: 17865; new key: 17882
# Round 6 switching results:
#  left partition: 4571
#  right partition: 25189
#
# Round 7:Round 7:
#  right partition(after applied F, Key:17882): 10175
#  left partition(after XOR with right, right:10175): 13924
# Initial key: 17882; new key: 17867
# Round 7 switching results:
#  left partition: 10175
#  right partition: 13924
#
# Round 8:Round 8:
#  right partition(after applied F, Key:17867): 29615
#  left partition(after XOR with right, right:29615): 21520
# Initial key: 17867; new key: 17884
# Round 8 switching results:
#  left partition: 29615
#  right partition: 21520
#
# Round 9:Round 9:
#  right partition(after applied F, Key:17884): 4556
#  left partition(after XOR with right, right:4556): 25187
# Initial key: 17884; new key: 17869
# Round 9 switching results:
#  left partition: 4556
#  right partition: 25187
#
# Round 10:Round 10:
#  right partition(after applied F, Key:17869): 10158
#  left partition(after XOR with right, right:10158): 13922
# Initial key: 17869; new key: 17886
# Round 10 switching results:
#  left partition: 10158
#  right partition: 13922
#
# Round 11:Round 11:
#  right partition(after applied F, Key:17886): 29628
#  left partition(after XOR with right, right:29628): 21522
# Initial key: 17886; new key: 17871
# Round 11 switching results:
#  left partition: 29628
#  right partition: 21522
#
# Round 12:Round 12:
#  right partition(after applied F, Key:17871): 4573
#  left partition(after XOR with right, right:4573): 25185
# Initial key: 17871; new key: 17856
# Round 12 switching results:
#  left partition: 4573
#  right partition: 25185
#
# Round 13:Round 13:
#  right partition(after applied F, Key:17856): 10145
#  left partition(after XOR with right, right:10145): 13948
# Initial key: 17856; new key: 17873
# Round 13 switching results:
#  left partition: 10145
#  right partition: 13948
#
# Round 14:Round 14:
#  right partition(after applied F, Key:17873): 29613
#  left partition(after XOR with right, right:29613): 21516
# Initial key: 17873; new key: 17858
# Round 14 switching results:
#  left partition: 29613
#  right partition: 21516
#
# Round 15:Round 15:
#  right partition(after applied F, Key:17858): 4558
#  left partition(after XOR with right, right:4558): 25187
# Initial key: 17858; new key: 17875
# Round 15 switching results:
#  left partition: 4558
#  right partition: 25187
#
# Round 16:Round 16:
#  right partition(after applied F, Key:17875): 10160
#  left partition(after XOR with right, right:10160): 13950
# Initial key: 17875; new key: 17860
# Round 16 switching results:
#  left partition: 10160
#  right partition: 13950
#
# Final left partition: 13950
# Initial right partition: 10160
#
#
# Block 3:
#  Thi
#
# Initial left partition: 5674
# Initial right partition: 20441
#
# Round 1:Round 1:
#  right partition(after applied F, Key:17876): 2573
#  left partition(after XOR with right, right:2573): 7207
# Initial key: 17876; new key: 17861
# Round 1 switching results:
#  left partition: 2573
#  right partition: 7207
#
# Round 2:Round 2:
#  right partition(after applied F, Key:17861): 23010
#  left partition(after XOR with right, right:23010): 21487
# Initial key: 17861; new key: 17878
# Round 2 switching results:
#  left partition: 23010
#  right partition: 21487
#
# Round 3:Round 3:
#  right partition(after applied F, Key:17878): 5689
#  left partition(after XOR with right, right:5689): 20443
# Initial key: 17878; new key: 17863
# Round 3 switching results:
#  left partition: 5689
#  right partition: 20443
#
# Round 4:Round 4:
#  right partition(after applied F, Key:17863): 2588
#  left partition(after XOR with right, right:2588): 7205
# Initial key: 17863; new key: 17880
# Round 4 switching results:
#  left partition: 2588
#  right partition: 7205
#
# Round 5:Round 5:
#  right partition(after applied F, Key:17880): 23037
#  left partition(after XOR with right, right:23037): 21473
# Initial key: 17880; new key: 17865
# Round 5 switching results:
#  left partition: 23037
#  right partition: 21473
#
# Round 6:Round 6:
#  right partition(after applied F, Key:17865): 5672
#  left partition(after XOR with right, right:5672): 20437
# Initial key: 17865; new key: 17882
# Round 6 switching results:
#  left partition: 5672
#  right partition: 20437
#
# Round 7:Round 7:
#  right partition(after applied F, Key:17882): 2575
#  left partition(after XOR with right, right:2575): 7207
# Initial key: 17882; new key: 17867
# Round 7 switching results:
#  left partition: 2575
#  right partition: 7207
#
# Round 8:Round 8:
#  right partition(after applied F, Key:17867): 23020
#  left partition(after XOR with right, right:23020): 21475
# Initial key: 17867; new key: 17884
# Round 8 switching results:
#  left partition: 23020
#  right partition: 21475
#
# Round 9:Round 9:
#  right partition(after applied F, Key:17884): 5695
#  left partition(after XOR with right, right:5695): 20435
# Initial key: 17884; new key: 17869
# Round 9 switching results:
#  left partition: 5695
#  right partition: 20435
#
# Round 10:Round 10:
#  right partition(after applied F, Key:17869): 2590
#  left partition(after XOR with right, right:2590): 7201
# Initial key: 17869; new key: 17886
# Round 10 switching results:
#  left partition: 2590
#  right partition: 7201
#
# Round 11:Round 11:
#  right partition(after applied F, Key:17886): 23039
#  left partition(after XOR with right, right:23039): 21473
# Initial key: 17886; new key: 17871
# Round 11 switching results:
#  left partition: 23039
#  right partition: 21473
#
# Round 12:Round 12:
#  right partition(after applied F, Key:17871): 5678
#  left partition(after XOR with right, right:5678): 20433
# Initial key: 17871; new key: 17856
# Round 12 switching results:
#  left partition: 5678
#  right partition: 20433
#
# Round 13:Round 13:
#  right partition(after applied F, Key:17856): 2577
#  left partition(after XOR with right, right:2577): 7231
# Initial key: 17856; new key: 17873
# Round 13 switching results:
#  left partition: 2577
#  right partition: 7231
#
# Round 14:Round 14:
#  right partition(after applied F, Key:17873): 23022
#  left partition(after XOR with right, right:23022): 21503
# Initial key: 17873; new key: 17858
# Round 14 switching results:
#  left partition: 23022
#  right partition: 21503
#
# Round 15:Round 15:
#  right partition(after applied F, Key:17858): 5693
#  left partition(after XOR with right, right:5693): 20435
# Initial key: 17858; new key: 17875
# Round 15 switching results:
#  left partition: 5693
#  right partition: 20435
#
# Round 16:Round 16:
#  right partition(after applied F, Key:17875): 2560
#  left partition(after XOR with right, right:2560): 7229
# Initial key: 17875; new key: 17860
# Round 16 switching results:
#  left partition: 2560
#  right partition: 7229
#
# Final left partition: 7229
# Initial right partition: 2560
#
#
# Block 4:
# s is
#
# Initial left partition: 28445
# Initial right partition: 25459
#
# Round 1:Round 1:
#  right partition(after applied F, Key:17876): 9895
#  left partition(after XOR with right, right:9895): 18874
# Initial key: 17876; new key: 17861
# Round 1 switching results:
#  left partition: 9895
#  right partition: 18874
#
# Round 2:Round 2:
#  right partition(after applied F, Key:17861): 3199
#  left partition(after XOR with right, right:3199): 10968
# Initial key: 17861; new key: 17878
# Round 2 switching results:
#  left partition: 3199
#  right partition: 10968
#
# Round 3:Round 3:
#  right partition(after applied F, Key:17878): 28430
#  left partition(after XOR with right, right:28430): 25457
# Initial key: 17878; new key: 17863
# Round 3 switching results:
#  left partition: 28430
#  right partition: 25457
#
# Round 4:Round 4:
#  right partition(after applied F, Key:17863): 9910
#  left partition(after XOR with right, right:9910): 18872
# Initial key: 17863; new key: 17880
# Round 4 switching results:
#  left partition: 9910
#  right partition: 18872
#
# Round 5:Round 5:
#  right partition(after applied F, Key:17880): 3168
#  left partition(after XOR with right, right:3168): 10966
# Initial key: 17880; new key: 17865
# Round 5 switching results:
#  left partition: 3168
#  right partition: 10966
#
# Round 6:Round 6:
#  right partition(after applied F, Key:17865): 28447
#  left partition(after XOR with right, right:28447): 25471
# Initial key: 17865; new key: 17882
# Round 6 switching results:
#  left partition: 28447
#  right partition: 25471
#
# Round 7:Round 7:
#  right partition(after applied F, Key:17882): 9893
#  left partition(after XOR with right, right:9893): 18874
# Initial key: 17882; new key: 17867
# Round 7 switching results:
#  left partition: 9893
#  right partition: 18874
#
# Round 8:Round 8:
#  right partition(after applied F, Key:17867): 3185
#  left partition(after XOR with right, right:3185): 10964
# Initial key: 17867; new key: 17884
# Round 8 switching results:
#  left partition: 3185
#  right partition: 10964
#
# Round 9:Round 9:
#  right partition(after applied F, Key:17884): 28424
#  left partition(after XOR with right, right:28424): 25465
# Initial key: 17884; new key: 17869
# Round 9 switching results:
#  left partition: 28424
#  right partition: 25465
#
# Round 10:Round 10:
#  right partition(after applied F, Key:17869): 9908
#  left partition(after XOR with right, right:9908): 18876
# Initial key: 17869; new key: 17886
# Round 10 switching results:
#  left partition: 9908
#  right partition: 18876
#
# Round 11:Round 11:
#  right partition(after applied F, Key:17886): 3170
#  left partition(after XOR with right, right:3170): 10966
# Initial key: 17886; new key: 17871
# Round 11 switching results:
#  left partition: 3170
#  right partition: 10966
#
# Round 12:Round 12:
#  right partition(after applied F, Key:17871): 28441
#  left partition(after XOR with right, right:28441): 25467
# Initial key: 17871; new key: 17856
# Round 12 switching results:
#  left partition: 28441
#  right partition: 25467
#
# Round 13:Round 13:
#  right partition(after applied F, Key:17856): 9915
#  left partition(after XOR with right, right:9915): 18850
# Initial key: 17856; new key: 17873
# Round 13 switching results:
#  left partition: 9915
#  right partition: 18850
#
# Round 14:Round 14:
#  right partition(after applied F, Key:17873): 3187
#  left partition(after XOR with right, right:3187): 10952
# Initial key: 17873; new key: 17858
# Round 14 switching results:
#  left partition: 3187
#  right partition: 10952
#
# Round 15:Round 15:
#  right partition(after applied F, Key:17858): 28426
#  left partition(after XOR with right, right:28426): 25465
# Initial key: 17858; new key: 17875
# Round 15 switching results:
#  left partition: 28426
#  right partition: 25465
#
# Round 16:Round 16:
#  right partition(after applied F, Key:17875): 9898
#  left partition(after XOR with right, right:9898): 18848
# Initial key: 17875; new key: 17860
# Round 16 switching results:
#  left partition: 9898
#  right partition: 18848
#
# Final left partition: 18848
# Initial right partition: 9898
#
#
# Block 5:
#  Hyl
#
# Initial left partition: 27112
# Initial right partition: 24518
#
# Round 1:Round 1:
#  right partition(after applied F, Key:17876): 6674
#  left partition(after XOR with right, right:6674): 29690
# Initial key: 17876; new key: 17861
# Round 1 switching results:
#  left partition: 6674
#  right partition: 29690
#
# Round 2:Round 2:
#  right partition(after applied F, Key:17861): 13887
#  left partition(after XOR with right, right:13887): 11309
# Initial key: 17861; new key: 17878
# Round 2 switching results:
#  left partition: 13887
#  right partition: 11309
#
# Round 3:Round 3:
#  right partition(after applied F, Key:17878): 27131
#  left partition(after XOR with right, right:27131): 24516
# Initial key: 17878; new key: 17863
# Round 3 switching results:
#  left partition: 27131
#  right partition: 24516
#
# Round 4:Round 4:
#  right partition(after applied F, Key:17863): 6659
#  left partition(after XOR with right, right:6659): 29688
# Initial key: 17863; new key: 17880
# Round 4 switching results:
#  left partition: 6659
#  right partition: 29688
#
# Round 5:Round 5:
#  right partition(after applied F, Key:17880): 13856
#  left partition(after XOR with right, right:13856): 11299
# Initial key: 17880; new key: 17865
# Round 5 switching results:
#  left partition: 13856
#  right partition: 11299
#
# Round 6:Round 6:
#  right partition(after applied F, Key:17865): 27114
#  left partition(after XOR with right, right:27114): 24522
# Initial key: 17865; new key: 17882
# Round 6 switching results:
#  left partition: 27114
#  right partition: 24522
#
# Round 7:Round 7:
#  right partition(after applied F, Key:17882): 6672
#  left partition(after XOR with right, right:6672): 29690
# Initial key: 17882; new key: 17867
# Round 7 switching results:
#  left partition: 6672
#  right partition: 29690
#
# Round 8:Round 8:
#  right partition(after applied F, Key:17867): 13873
#  left partition(after XOR with right, right:13873): 11297
# Initial key: 17867; new key: 17884
# Round 8 switching results:
#  left partition: 13873
#  right partition: 11297
#
# Round 9:Round 9:
#  right partition(after applied F, Key:17884): 27133
#  left partition(after XOR with right, right:27133): 24524
# Initial key: 17884; new key: 17869
# Round 9 switching results:
#  left partition: 27133
#  right partition: 24524
#
# Round 10:Round 10:
#  right partition(after applied F, Key:17869): 6657
#  left partition(after XOR with right, right:6657): 29692
# Initial key: 17869; new key: 17886
# Round 10 switching results:
#  left partition: 6657
#  right partition: 29692
#
# Round 11:Round 11:
#  right partition(after applied F, Key:17886): 13858
#  left partition(after XOR with right, right:13858): 11299
# Initial key: 17886; new key: 17871
# Round 11 switching results:
#  left partition: 13858
#  right partition: 11299
#
# Round 12:Round 12:
#  right partition(after applied F, Key:17871): 27116
#  left partition(after XOR with right, right:27116): 24526
# Initial key: 17871; new key: 17856
# Round 12 switching results:
#  left partition: 27116
#  right partition: 24526
#
# Round 13:Round 13:
#  right partition(after applied F, Key:17856): 6670
#  left partition(after XOR with right, right:6670): 29666
# Initial key: 17856; new key: 17873
# Round 13 switching results:
#  left partition: 6670
#  right partition: 29666
#
# Round 14:Round 14:
#  right partition(after applied F, Key:17873): 13875
#  left partition(after XOR with right, right:13875): 11325
# Initial key: 17873; new key: 17858
# Round 14 switching results:
#  left partition: 13875
#  right partition: 11325
#
# Round 15:Round 15:
#  right partition(after applied F, Key:17858): 27135
#  left partition(after XOR with right, right:27135): 24524
# Initial key: 17858; new key: 17875
# Round 15 switching results:
#  left partition: 27135
#  right partition: 24524
#
# Round 16:Round 16:
#  right partition(after applied F, Key:17875): 6687
#  left partition(after XOR with right, right:6687): 29664
# Initial key: 17875; new key: 17860
# Round 16 switching results:
#  left partition: 6687
#  right partition: 29664
#
# Final left partition: 29664
# Initial right partition: 6687
#
#
# Block 6:
# mi a
#
# Initial left partition: 7817
# Initial right partition: 14974
#
# Round 1:Round 1:
#  right partition(after applied F, Key:17876): 32682
#  left partition(after XOR with right, right:32682): 24867
# Initial key: 17876; new key: 17861
# Round 1 switching results:
#  left partition: 32682
#  right partition: 24867
#
# Round 2:Round 2:
#  right partition(after applied F, Key:17861): 9446
#  left partition(after XOR with right, right:9446): 23372
# Initial key: 17861; new key: 17878
# Round 2 switching results:
#  left partition: 9446
#  right partition: 23372
#
# Round 3:Round 3:
#  right partition(after applied F, Key:17878): 7834
#  left partition(after XOR with right, right:7834): 14972
# Initial key: 17878; new key: 17863
# Round 3 switching results:
#  left partition: 7834
#  right partition: 14972
#
# Round 4:Round 4:
#  right partition(after applied F, Key:17863): 32699
#  left partition(after XOR with right, right:32699): 24865
# Initial key: 17863; new key: 17880
# Round 4 switching results:
#  left partition: 32699
#  right partition: 24865
#
# Round 5:Round 5:
#  right partition(after applied F, Key:17880): 9465
#  left partition(after XOR with right, right:9465): 23362
# Initial key: 17880; new key: 17865
# Round 5 switching results:
#  left partition: 9465
#  right partition: 23362
#
# Round 6:Round 6:
#  right partition(after applied F, Key:17865): 7819
#  left partition(after XOR with right, right:7819): 14962
# Initial key: 17865; new key: 17882
# Round 6 switching results:
#  left partition: 7819
#  right partition: 14962
#
# Round 7:Round 7:
#  right partition(after applied F, Key:17882): 32680
#  left partition(after XOR with right, right:32680): 24867
# Initial key: 17882; new key: 17867
# Round 7 switching results:
#  left partition: 32680
#  right partition: 24867
#
# Round 8:Round 8:
#  right partition(after applied F, Key:17867): 9448
#  left partition(after XOR with right, right:9448): 23360
# Initial key: 17867; new key: 17884
# Round 8 switching results:
#  left partition: 9448
#  right partition: 23360
#
# Round 9:Round 9:
#  right partition(after applied F, Key:17884): 7836
#  left partition(after XOR with right, right:7836): 14964
# Initial key: 17884; new key: 17869
# Round 9 switching results:
#  left partition: 7836
#  right partition: 14964
#
# Round 10:Round 10:
#  right partition(after applied F, Key:17869): 32697
#  left partition(after XOR with right, right:32697): 24869
# Initial key: 17869; new key: 17886
# Round 10 switching results:
#  left partition: 32697
#  right partition: 24869
#
# Round 11:Round 11:
#  right partition(after applied F, Key:17886): 9467
#  left partition(after XOR with right, right:9467): 23362
# Initial key: 17886; new key: 17871
# Round 11 switching results:
#  left partition: 9467
#  right partition: 23362
#
# Round 12:Round 12:
#  right partition(after applied F, Key:17871): 7821
#  left partition(after XOR with right, right:7821): 14966
# Initial key: 17871; new key: 17856
# Round 12 switching results:
#  left partition: 7821
#  right partition: 14966
#
# Round 13:Round 13:
#  right partition(after applied F, Key:17856): 32694
#  left partition(after XOR with right, right:32694): 24891
# Initial key: 17856; new key: 17873
# Round 13 switching results:
#  left partition: 32694
#  right partition: 24891
#
# Round 14:Round 14:
#  right partition(after applied F, Key:17873): 9450
#  left partition(after XOR with right, right:9450): 23388
# Initial key: 17873; new key: 17858
# Round 14 switching results:
#  left partition: 9450
#  right partition: 23388
#
# Round 15:Round 15:
#  right partition(after applied F, Key:17858): 7838
#  left partition(after XOR with right, right:7838): 14964
# Initial key: 17858; new key: 17875
# Round 15 switching results:
#  left partition: 7838
#  right partition: 14964
#
# Round 16:Round 16:
#  right partition(after applied F, Key:17875): 32679
#  left partition(after XOR with right, right:32679): 24889
# Initial key: 17875; new key: 17860
# Round 16 switching results:
#  left partition: 32679
#  right partition: 24889
#
# Final left partition: 24889
# Initial right partition: 32679
#
#
# Block 7:
# nd L
#
# Initial left partition: 3933
# Initial right partition: 24555
#
# Round 1:Round 1:
#  right partition(after applied F, Key:17876): 6719
#  left partition(after XOR with right, right:6719): 5474
# Initial key: 17876; new key: 17861
# Round 1 switching results:
#  left partition: 6719
#  right partition: 5474
#
# Round 2:Round 2:
#  right partition(after applied F, Key:17861): 20647
#  left partition(after XOR with right, right:20647): 19096
# Initial key: 17861; new key: 17878
# Round 2 switching results:
#  left partition: 20647
#  right partition: 19096
#
# Round 3:Round 3:
#  right partition(after applied F, Key:17878): 3918
#  left partition(after XOR with right, right:3918): 24553
# Initial key: 17878; new key: 17863
# Round 3 switching results:
#  left partition: 3918
#  right partition: 24553
#
# Round 4:Round 4:
#  right partition(after applied F, Key:17863): 6702
#  left partition(after XOR with right, right:6702): 5472
# Initial key: 17863; new key: 17880
# Round 4 switching results:
#  left partition: 6702
#  right partition: 5472
#
# Round 5:Round 5:
#  right partition(after applied F, Key:17880): 20664
#  left partition(after XOR with right, right:20664): 19094
# Initial key: 17880; new key: 17865
# Round 5 switching results:
#  left partition: 20664
#  right partition: 19094
#
# Round 6:Round 6:
#  right partition(after applied F, Key:17865): 3935
#  left partition(after XOR with right, right:3935): 24551
# Initial key: 17865; new key: 17882
# Round 6 switching results:
#  left partition: 3935
#  right partition: 24551
#
# Round 7:Round 7:
#  right partition(after applied F, Key:17882): 6717
#  left partition(after XOR with right, right:6717): 5474
# Initial key: 17882; new key: 17867
# Round 7 switching results:
#  left partition: 6717
#  right partition: 5474
#
# Round 8:Round 8:
#  right partition(after applied F, Key:17867): 20649
#  left partition(after XOR with right, right:20649): 19092
# Initial key: 17867; new key: 17884
# Round 8 switching results:
#  left partition: 20649
#  right partition: 19092
#
# Round 9:Round 9:
#  right partition(after applied F, Key:17884): 3912
#  left partition(after XOR with right, right:3912): 24545
# Initial key: 17884; new key: 17869
# Round 9 switching results:
#  left partition: 3912
#  right partition: 24545
#
# Round 10:Round 10:
#  right partition(after applied F, Key:17869): 6700
#  left partition(after XOR with right, right:6700): 5476
# Initial key: 17869; new key: 17886
# Round 10 switching results:
#  left partition: 6700
#  right partition: 5476
#
# Round 11:Round 11:
#  right partition(after applied F, Key:17886): 20666
#  left partition(after XOR with right, right:20666): 19094
# Initial key: 17886; new key: 17871
# Round 11 switching results:
#  left partition: 20666
#  right partition: 19094
#
# Round 12:Round 12:
#  right partition(after applied F, Key:17871): 3929
#  left partition(after XOR with right, right:3929): 24547
# Initial key: 17871; new key: 17856
# Round 12 switching results:
#  left partition: 3929
#  right partition: 24547
#
# Round 13:Round 13:
#  right partition(after applied F, Key:17856): 6691
#  left partition(after XOR with right, right:6691): 5498
# Initial key: 17856; new key: 17873
# Round 13 switching results:
#  left partition: 6691
#  right partition: 5498
#
# Round 14:Round 14:
#  right partition(after applied F, Key:17873): 20651
#  left partition(after XOR with right, right:20651): 19080
# Initial key: 17873; new key: 17858
# Round 14 switching results:
#  left partition: 20651
#  right partition: 19080
#
# Round 15:Round 15:
#  right partition(after applied F, Key:17858): 3914
#  left partition(after XOR with right, right:3914): 24545
# Initial key: 17858; new key: 17875
# Round 15 switching results:
#  left partition: 3914
#  right partition: 24545
#
# Round 16:Round 16:
#  right partition(after applied F, Key:17875): 6706
#  left partition(after XOR with right, right:6706): 5496
# Initial key: 17875; new key: 17860
# Round 16 switching results:
#  left partition: 6706
#  right partition: 5496
#
# Final left partition: 5496
# Initial right partition: 6706
#
#
# Block 8:
# ouis
#
# Initial left partition: 31245
# Initial right partition: 29505
#
# Round 1:Round 1:
#  right partition(after applied F, Key:17876): 13973
#  left partition(after XOR with right, right:13973): 19608
# Initial key: 17876; new key: 17861
# Round 1 switching results:
#  left partition: 13973
#  right partition: 19608
#
# Round 2:Round 2:
#  right partition(after applied F, Key:17861): 2397
#  left partition(after XOR with right, right:2397): 16328
# Initial key: 17861; new key: 17878
# Round 2 switching results:
#  left partition: 2397
#  right partition: 16328
#
# Round 3:Round 3:
#  right partition(after applied F, Key:17878): 31262
#  left partition(after XOR with right, right:31262): 29507
# Initial key: 17878; new key: 17863
# Round 3 switching results:
#  left partition: 31262
#  right partition: 29507
#
# Round 4:Round 4:
#  right partition(after applied F, Key:17863): 13956
#  left partition(after XOR with right, right:13956): 19610
# Initial key: 17863; new key: 17880
# Round 4 switching results:
#  left partition: 13956
#  right partition: 19610
#
# Round 5:Round 5:
#  right partition(after applied F, Key:17880): 2370
#  left partition(after XOR with right, right:2370): 16326
# Initial key: 17880; new key: 17865
# Round 5 switching results:
#  left partition: 2370
#  right partition: 16326
#
# Round 6:Round 6:
#  right partition(after applied F, Key:17865): 31247
#  left partition(after XOR with right, right:31247): 29517
# Initial key: 17865; new key: 17882
# Round 6 switching results:
#  left partition: 31247
#  right partition: 29517
#
# Round 7:Round 7:
#  right partition(after applied F, Key:17882): 13975
#  left partition(after XOR with right, right:13975): 19608
# Initial key: 17882; new key: 17867
# Round 7 switching results:
#  left partition: 13975
#  right partition: 19608
#
# Round 8:Round 8:
#  right partition(after applied F, Key:17867): 2387
#  left partition(after XOR with right, right:2387): 16324
# Initial key: 17867; new key: 17884
# Round 8 switching results:
#  left partition: 2387
#  right partition: 16324
#
# Round 9:Round 9:
#  right partition(after applied F, Key:17884): 31256
#  left partition(after XOR with right, right:31256): 29515
# Initial key: 17884; new key: 17869
# Round 9 switching results:
#  left partition: 31256
#  right partition: 29515
#
# Round 10:Round 10:
#  right partition(after applied F, Key:17869): 13958
#  left partition(after XOR with right, right:13958): 19614
# Initial key: 17869; new key: 17886
# Round 10 switching results:
#  left partition: 13958
#  right partition: 19614
#
# Round 11:Round 11:
#  right partition(after applied F, Key:17886): 2368
#  left partition(after XOR with right, right:2368): 16326
# Initial key: 17886; new key: 17871
# Round 11 switching results:
#  left partition: 2368
#  right partition: 16326
#
# Round 12:Round 12:
#  right partition(after applied F, Key:17871): 31241
#  left partition(after XOR with right, right:31241): 29513
# Initial key: 17871; new key: 17856
# Round 12 switching results:
#  left partition: 31241
#  right partition: 29513
#
# Round 13:Round 13:
#  right partition(after applied F, Key:17856): 13961
#  left partition(after XOR with right, right:13961): 19584
# Initial key: 17856; new key: 17873
# Round 13 switching results:
#  left partition: 13961
#  right partition: 19584
#
# Round 14:Round 14:
#  right partition(after applied F, Key:17873): 2385
#  left partition(after XOR with right, right:2385): 16344
# Initial key: 17873; new key: 17858
# Round 14 switching results:
#  left partition: 2385
#  right partition: 16344
#
# Round 15:Round 15:
#  right partition(after applied F, Key:17858): 31258
#  left partition(after XOR with right, right:31258): 29515
# Initial key: 17858; new key: 17875
# Round 15 switching results:
#  left partition: 31258
#  right partition: 29515
#
# Round 16:Round 16:
#  right partition(after applied F, Key:17875): 13976
#  left partition(after XOR with right, right:13976): 19586
# Initial key: 17875; new key: 17860
# Round 16 switching results:
#  left partition: 13976
#  right partition: 19586
#
# Final left partition: 19586
# Initial right partition: 13976

# %%
# decryption
decrypted_list = decrypt_cipherCBC(cipher_list, key_last_used, iv, round)
# Out:
# Initial key: 17860; new key: 17875
# Initial left partition: 2762
# Initial right partition: 13566
#
# Round 1:
#  right partition(after applied F, Key:17875): 28973
#  left partition(after XOR with right, right:28973): 15924
# Initial key: 17875; new key: 17858
# Round 1 switching results:
#  left partition: 28973
#  right partition: 15924
#
# Round 2:
#  right partition(after applied F, Key:17858): 31734
#  left partition(after XOR with right, right:31734): 20249
# Initial key: 17858; new key: 17873
# Round 2 switching results:
#  left partition: 31734
#  right partition: 20249
#
# Round 3:
#  right partition(after applied F, Key:17873): 2760
#  left partition(after XOR with right, right:2760): 13551
# Initial key: 17873; new key: 17856
# Round 3 switching results:
#  left partition: 2760
#  right partition: 13551
#
# Round 4:
#  right partition(after applied F, Key:17856): 28975
#  left partition(after XOR with right, right:28975): 15911
# Initial key: 17856; new key: 17871
# Round 4 switching results:
#  left partition: 28975
#  right partition: 15911
#
# Round 5:
#  right partition(after applied F, Key:17871): 31720
#  left partition(after XOR with right, right:31720): 20232
# Initial key: 17871; new key: 17886
# Round 5 switching results:
#  left partition: 31720
#  right partition: 20232
#
# Round 6:
#  right partition(after applied F, Key:17886): 2774
#  left partition(after XOR with right, right:2774): 13536
# Initial key: 17886; new key: 17869
# Round 6 switching results:
#  left partition: 2774
#  right partition: 13536
#
# Round 7:
#  right partition(after applied F, Key:17869): 28973
#  left partition(after XOR with right, right:28973): 15926
# Initial key: 17869; new key: 17884
# Round 7 switching results:
#  left partition: 28973
#  right partition: 15926
#
# Round 8:
#  right partition(after applied F, Key:17884): 31722
#  left partition(after XOR with right, right:31722): 20251
# Initial key: 17884; new key: 17867
# Round 8 switching results:
#  left partition: 31722
#  right partition: 20251
#
# Round 9:
#  right partition(after applied F, Key:17867): 2768
#  left partition(after XOR with right, right:2768): 13553
# Initial key: 17867; new key: 17882
# Round 9 switching results:
#  left partition: 2768
#  right partition: 13553
#
# Round 10:
#  right partition(after applied F, Key:17882): 28971
#  left partition(after XOR with right, right:28971): 15905
# Initial key: 17882; new key: 17865
# Round 10 switching results:
#  left partition: 28971
#  right partition: 15905
#
# Round 11:
#  right partition(after applied F, Key:17865): 31720
#  left partition(after XOR with right, right:31720): 20234
# Initial key: 17865; new key: 17880
# Round 11 switching results:
#  left partition: 31720
#  right partition: 20234
#
# Round 12:
#  right partition(after applied F, Key:17880): 2770
#  left partition(after XOR with right, right:2770): 13538
# Initial key: 17880; new key: 17863
# Round 12 switching results:
#  left partition: 2770
#  right partition: 13538
#
# Round 13:
#  right partition(after applied F, Key:17863): 28965
#  left partition(after XOR with right, right:28965): 15920
# Initial key: 17863; new key: 17878
# Round 13 switching results:
#  left partition: 28965
#  right partition: 15920
#
# Round 14:
#  right partition(after applied F, Key:17878): 31718
#  left partition(after XOR with right, right:31718): 20245
# Initial key: 17878; new key: 17861
# Round 14 switching results:
#  left partition: 31718
#  right partition: 20245
#
# Round 15:
#  right partition(after applied F, Key:17861): 2768
#  left partition(after XOR with right, right:2768): 13555
# Initial key: 17861; new key: 17876
# Round 15 switching results:
#  left partition: 2768
#  right partition: 13555
#
# Round 16:
#  right partition(after applied F, Key:17876): 28967
#  left partition(after XOR with right, right:28967): 15907
# Initial key: 17876; new key: 17859
# Round 16 switching results:
#  left partition: 28967
#  right partition: 15907
#
# Final left partition: 15907
# Initial right partition: 28967
#
# Initial key: 17860; new key: 17875
# Initial left partition: 25525
# Initial right partition: 1608
#
# Round 1:
#  right partition(after applied F, Key:17875): 17307
#  left partition(after XOR with right, right:17307): 26109
# Initial key: 17875; new key: 17858
# Round 1 switching results:
#  left partition: 17307
#  right partition: 26109
#
# Round 2:
#  right partition(after applied F, Key:17858): 8255
#  left partition(after XOR with right, right:8255): 9830
# Initial key: 17858; new key: 17873
# Round 2 switching results:
#  left partition: 8255
#  right partition: 9830
#
# Round 3:
#  right partition(after applied F, Key:17873): 25527
#  left partition(after XOR with right, right:25527): 1625
# Initial key: 17873; new key: 17856
# Round 3 switching results:
#  left partition: 25527
#  right partition: 1625
#
# Round 4:
#  right partition(after applied F, Key:17856): 17305
#  left partition(after XOR with right, right:17305): 26094
# Initial key: 17856; new key: 17871
# Round 4 switching results:
#  left partition: 17305
#  right partition: 26094
#
# Round 5:
#  right partition(after applied F, Key:17871): 8225
#  left partition(after XOR with right, right:8225): 9847
# Initial key: 17871; new key: 17886
# Round 5 switching results:
#  left partition: 8225
#  right partition: 9847
#
# Round 6:
#  right partition(after applied F, Key:17886): 25513
#  left partition(after XOR with right, right:25513): 1622
# Initial key: 17886; new key: 17869
# Round 6 switching results:
#  left partition: 25513
#  right partition: 1622
#
# Round 7:
#  right partition(after applied F, Key:17869): 17307
#  left partition(after XOR with right, right:17307): 26111
# Initial key: 17869; new key: 17884
# Round 7 switching results:
#  left partition: 17307
#  right partition: 26111
#
# Round 8:
#  right partition(after applied F, Key:17884): 8227
#  left partition(after XOR with right, right:8227): 9828
# Initial key: 17884; new key: 17867
# Round 8 switching results:
#  left partition: 8227
#  right partition: 9828
#
# Round 9:
#  right partition(after applied F, Key:17867): 25519
#  left partition(after XOR with right, right:25519): 1607
# Initial key: 17867; new key: 17882
# Round 9 switching results:
#  left partition: 25519
#  right partition: 1607
#
# Round 10:
#  right partition(after applied F, Key:17882): 17309
#  left partition(after XOR with right, right:17309): 26088
# Initial key: 17882; new key: 17865
# Round 10 switching results:
#  left partition: 17309
#  right partition: 26088
#
# Round 11:
#  right partition(after applied F, Key:17865): 8225
#  left partition(after XOR with right, right:8225): 9845
# Initial key: 17865; new key: 17880
# Round 11 switching results:
#  left partition: 8225
#  right partition: 9845
#
# Round 12:
#  right partition(after applied F, Key:17880): 25517
#  left partition(after XOR with right, right:25517): 1620
# Initial key: 17880; new key: 17863
# Round 12 switching results:
#  left partition: 25517
#  right partition: 1620
#
# Round 13:
#  right partition(after applied F, Key:17863): 17299
#  left partition(after XOR with right, right:17299): 26105
# Initial key: 17863; new key: 17878
# Round 13 switching results:
#  left partition: 17299
#  right partition: 26105
#
# Round 14:
#  right partition(after applied F, Key:17878): 8239
#  left partition(after XOR with right, right:8239): 9834
# Initial key: 17878; new key: 17861
# Round 14 switching results:
#  left partition: 8239
#  right partition: 9834
#
# Round 15:
#  right partition(after applied F, Key:17861): 25519
#  left partition(after XOR with right, right:25519): 1605
# Initial key: 17861; new key: 17876
# Round 15 switching results:
#  left partition: 25519
#  right partition: 1605
#
# Round 16:
#  right partition(after applied F, Key:17876): 17297
#  left partition(after XOR with right, right:17297): 26090
# Initial key: 17876; new key: 17859
# Round 16 switching results:
#  left partition: 17297
#  right partition: 26090
#
# Final left partition: 26090
# Initial right partition: 17297
#
# Initial key: 17860; new key: 17875
# Initial left partition: 13950
# Initial right partition: 10160
#
# Round 1:
#  right partition(after applied F, Key:17875): 25187
#  left partition(after XOR with right, right:25187): 4558
# Initial key: 17875; new key: 17858
# Round 1 switching results:
#  left partition: 25187
#  right partition: 4558
#
# Round 2:
#  right partition(after applied F, Key:17858): 21516
#  left partition(after XOR with right, right:21516): 29613
# Initial key: 17858; new key: 17873
# Round 2 switching results:
#  left partition: 21516
#  right partition: 29613
#
# Round 3:
#  right partition(after applied F, Key:17873): 13948
#  left partition(after XOR with right, right:13948): 10145
# Initial key: 17873; new key: 17856
# Round 3 switching results:
#  left partition: 13948
#  right partition: 10145
#
# Round 4:
#  right partition(after applied F, Key:17856): 25185
#  left partition(after XOR with right, right:25185): 4573
# Initial key: 17856; new key: 17871
# Round 4 switching results:
#  left partition: 25185
#  right partition: 4573
#
# Round 5:
#  right partition(after applied F, Key:17871): 21522
#  left partition(after XOR with right, right:21522): 29628
# Initial key: 17871; new key: 17886
# Round 5 switching results:
#  left partition: 21522
#  right partition: 29628
#
# Round 6:
#  right partition(after applied F, Key:17886): 13922
#  left partition(after XOR with right, right:13922): 10158
# Initial key: 17886; new key: 17869
# Round 6 switching results:
#  left partition: 13922
#  right partition: 10158
#
# Round 7:
#  right partition(after applied F, Key:17869): 25187
#  left partition(after XOR with right, right:25187): 4556
# Initial key: 17869; new key: 17884
# Round 7 switching results:
#  left partition: 25187
#  right partition: 4556
#
# Round 8:
#  right partition(after applied F, Key:17884): 21520
#  left partition(after XOR with right, right:21520): 29615
# Initial key: 17884; new key: 17867
# Round 8 switching results:
#  left partition: 21520
#  right partition: 29615
#
# Round 9:
#  right partition(after applied F, Key:17867): 13924
#  left partition(after XOR with right, right:13924): 10175
# Initial key: 17867; new key: 17882
# Round 9 switching results:
#  left partition: 13924
#  right partition: 10175
#
# Round 10:
#  right partition(after applied F, Key:17882): 25189
#  left partition(after XOR with right, right:25189): 4571
# Initial key: 17882; new key: 17865
# Round 10 switching results:
#  left partition: 25189
#  right partition: 4571
#
# Round 11:
#  right partition(after applied F, Key:17865): 21522
#  left partition(after XOR with right, right:21522): 29630
# Initial key: 17865; new key: 17880
# Round 11 switching results:
#  left partition: 21522
#  right partition: 29630
#
# Round 12:
#  right partition(after applied F, Key:17880): 13926
#  left partition(after XOR with right, right:13926): 10156
# Initial key: 17880; new key: 17863
# Round 12 switching results:
#  left partition: 13926
#  right partition: 10156
#
# Round 13:
#  right partition(after applied F, Key:17863): 25195
#  left partition(after XOR with right, right:25195): 4554
# Initial key: 17863; new key: 17878
# Round 13 switching results:
#  left partition: 25195
#  right partition: 4554
#
# Round 14:
#  right partition(after applied F, Key:17878): 21532
#  left partition(after XOR with right, right:21532): 29601
# Initial key: 17878; new key: 17861
# Round 14 switching results:
#  left partition: 21532
#  right partition: 29601
#
# Round 15:
#  right partition(after applied F, Key:17861): 13924
#  left partition(after XOR with right, right:13924): 10173
# Initial key: 17861; new key: 17876
# Round 15 switching results:
#  left partition: 13924
#  right partition: 10173
#
# Round 16:
#  right partition(after applied F, Key:17876): 25193
#  left partition(after XOR with right, right:25193): 4569
# Initial key: 17876; new key: 17859
# Round 16 switching results:
#  left partition: 25193
#  right partition: 4569
#
# Final left partition: 4569
# Initial right partition: 25193
#
# Initial key: 17860; new key: 17875
# Initial left partition: 7229
# Initial right partition: 2560
#
# Round 1:
#  right partition(after applied F, Key:17875): 20435
#  left partition(after XOR with right, right:20435): 5693
# Initial key: 17875; new key: 17858
# Round 1 switching results:
#  left partition: 20435
#  right partition: 5693
#
# Round 2:
#  right partition(after applied F, Key:17858): 21503
#  left partition(after XOR with right, right:21503): 23022
# Initial key: 17858; new key: 17873
# Round 2 switching results:
#  left partition: 21503
#  right partition: 23022
#
# Round 3:
#  right partition(after applied F, Key:17873): 7231
#  left partition(after XOR with right, right:7231): 2577
# Initial key: 17873; new key: 17856
# Round 3 switching results:
#  left partition: 7231
#  right partition: 2577
#
# Round 4:
#  right partition(after applied F, Key:17856): 20433
#  left partition(after XOR with right, right:20433): 5678
# Initial key: 17856; new key: 17871
# Round 4 switching results:
#  left partition: 20433
#  right partition: 5678
#
# Round 5:
#  right partition(after applied F, Key:17871): 21473
#  left partition(after XOR with right, right:21473): 23039
# Initial key: 17871; new key: 17886
# Round 5 switching results:
#  left partition: 21473
#  right partition: 23039
#
# Round 6:
#  right partition(after applied F, Key:17886): 7201
#  left partition(after XOR with right, right:7201): 2590
# Initial key: 17886; new key: 17869
# Round 6 switching results:
#  left partition: 7201
#  right partition: 2590
#
# Round 7:
#  right partition(after applied F, Key:17869): 20435
#  left partition(after XOR with right, right:20435): 5695
# Initial key: 17869; new key: 17884
# Round 7 switching results:
#  left partition: 20435
#  right partition: 5695
#
# Round 8:
#  right partition(after applied F, Key:17884): 21475
#  left partition(after XOR with right, right:21475): 23020
# Initial key: 17884; new key: 17867
# Round 8 switching results:
#  left partition: 21475
#  right partition: 23020
#
# Round 9:
#  right partition(after applied F, Key:17867): 7207
#  left partition(after XOR with right, right:7207): 2575
# Initial key: 17867; new key: 17882
# Round 9 switching results:
#  left partition: 7207
#  right partition: 2575
#
# Round 10:
#  right partition(after applied F, Key:17882): 20437
#  left partition(after XOR with right, right:20437): 5672
# Initial key: 17882; new key: 17865
# Round 10 switching results:
#  left partition: 20437
#  right partition: 5672
#
# Round 11:
#  right partition(after applied F, Key:17865): 21473
#  left partition(after XOR with right, right:21473): 23037
# Initial key: 17865; new key: 17880
# Round 11 switching results:
#  left partition: 21473
#  right partition: 23037
#
# Round 12:
#  right partition(after applied F, Key:17880): 7205
#  left partition(after XOR with right, right:7205): 2588
# Initial key: 17880; new key: 17863
# Round 12 switching results:
#  left partition: 7205
#  right partition: 2588
#
# Round 13:
#  right partition(after applied F, Key:17863): 20443
#  left partition(after XOR with right, right:20443): 5689
# Initial key: 17863; new key: 17878
# Round 13 switching results:
#  left partition: 20443
#  right partition: 5689
#
# Round 14:
#  right partition(after applied F, Key:17878): 21487
#  left partition(after XOR with right, right:21487): 23010
# Initial key: 17878; new key: 17861
# Round 14 switching results:
#  left partition: 21487
#  right partition: 23010
#
# Round 15:
#  right partition(after applied F, Key:17861): 7207
#  left partition(after XOR with right, right:7207): 2573
# Initial key: 17861; new key: 17876
# Round 15 switching results:
#  left partition: 7207
#  right partition: 2573
#
# Round 16:
#  right partition(after applied F, Key:17876): 20441
#  left partition(after XOR with right, right:20441): 5674
# Initial key: 17876; new key: 17859
# Round 16 switching results:
#  left partition: 20441
#  right partition: 5674
#
# Final left partition: 5674
# Initial right partition: 20441
#
# Initial key: 17860; new key: 17875
# Initial left partition: 18848
# Initial right partition: 9898
#
# Round 1:
#  right partition(after applied F, Key:17875): 25465
#  left partition(after XOR with right, right:25465): 28426
# Initial key: 17875; new key: 17858
# Round 1 switching results:
#  left partition: 25465
#  right partition: 28426
#
# Round 2:
#  right partition(after applied F, Key:17858): 10952
#  left partition(after XOR with right, right:10952): 3187
# Initial key: 17858; new key: 17873
# Round 2 switching results:
#  left partition: 10952
#  right partition: 3187
#
# Round 3:
#  right partition(after applied F, Key:17873): 18850
#  left partition(after XOR with right, right:18850): 9915
# Initial key: 17873; new key: 17856
# Round 3 switching results:
#  left partition: 18850
#  right partition: 9915
#
# Round 4:
#  right partition(after applied F, Key:17856): 25467
#  left partition(after XOR with right, right:25467): 28441
# Initial key: 17856; new key: 17871
# Round 4 switching results:
#  left partition: 25467
#  right partition: 28441
#
# Round 5:
#  right partition(after applied F, Key:17871): 10966
#  left partition(after XOR with right, right:10966): 3170
# Initial key: 17871; new key: 17886
# Round 5 switching results:
#  left partition: 10966
#  right partition: 3170
#
# Round 6:
#  right partition(after applied F, Key:17886): 18876
#  left partition(after XOR with right, right:18876): 9908
# Initial key: 17886; new key: 17869
# Round 6 switching results:
#  left partition: 18876
#  right partition: 9908
#
# Round 7:
#  right partition(after applied F, Key:17869): 25465
#  left partition(after XOR with right, right:25465): 28424
# Initial key: 17869; new key: 17884
# Round 7 switching results:
#  left partition: 25465
#  right partition: 28424
#
# Round 8:
#  right partition(after applied F, Key:17884): 10964
#  left partition(after XOR with right, right:10964): 3185
# Initial key: 17884; new key: 17867
# Round 8 switching results:
#  left partition: 10964
#  right partition: 3185
#
# Round 9:
#  right partition(after applied F, Key:17867): 18874
#  left partition(after XOR with right, right:18874): 9893
# Initial key: 17867; new key: 17882
# Round 9 switching results:
#  left partition: 18874
#  right partition: 9893
#
# Round 10:
#  right partition(after applied F, Key:17882): 25471
#  left partition(after XOR with right, right:25471): 28447
# Initial key: 17882; new key: 17865
# Round 10 switching results:
#  left partition: 25471
#  right partition: 28447
#
# Round 11:
#  right partition(after applied F, Key:17865): 10966
#  left partition(after XOR with right, right:10966): 3168
# Initial key: 17865; new key: 17880
# Round 11 switching results:
#  left partition: 10966
#  right partition: 3168
#
# Round 12:
#  right partition(after applied F, Key:17880): 18872
#  left partition(after XOR with right, right:18872): 9910
# Initial key: 17880; new key: 17863
# Round 12 switching results:
#  left partition: 18872
#  right partition: 9910
#
# Round 13:
#  right partition(after applied F, Key:17863): 25457
#  left partition(after XOR with right, right:25457): 28430
# Initial key: 17863; new key: 17878
# Round 13 switching results:
#  left partition: 25457
#  right partition: 28430
#
# Round 14:
#  right partition(after applied F, Key:17878): 10968
#  left partition(after XOR with right, right:10968): 3199
# Initial key: 17878; new key: 17861
# Round 14 switching results:
#  left partition: 10968
#  right partition: 3199
#
# Round 15:
#  right partition(after applied F, Key:17861): 18874
#  left partition(after XOR with right, right:18874): 9895
# Initial key: 17861; new key: 17876
# Round 15 switching results:
#  left partition: 18874
#  right partition: 9895
#
# Round 16:
#  right partition(after applied F, Key:17876): 25459
#  left partition(after XOR with right, right:25459): 28445
# Initial key: 17876; new key: 17859
# Round 16 switching results:
#  left partition: 25459
#  right partition: 28445
#
# Final left partition: 28445
# Initial right partition: 25459
#
# Initial key: 17860; new key: 17875
# Initial left partition: 29664
# Initial right partition: 6687
#
# Round 1:
#  right partition(after applied F, Key:17875): 24524
#  left partition(after XOR with right, right:24524): 27135
# Initial key: 17875; new key: 17858
# Round 1 switching results:
#  left partition: 24524
#  right partition: 27135
#
# Round 2:
#  right partition(after applied F, Key:17858): 11325
#  left partition(after XOR with right, right:11325): 13875
# Initial key: 17858; new key: 17873
# Round 2 switching results:
#  left partition: 11325
#  right partition: 13875
#
# Round 3:
#  right partition(after applied F, Key:17873): 29666
#  left partition(after XOR with right, right:29666): 6670
# Initial key: 17873; new key: 17856
# Round 3 switching results:
#  left partition: 29666
#  right partition: 6670
#
# Round 4:
#  right partition(after applied F, Key:17856): 24526
#  left partition(after XOR with right, right:24526): 27116
# Initial key: 17856; new key: 17871
# Round 4 switching results:
#  left partition: 24526
#  right partition: 27116
#
# Round 5:
#  right partition(after applied F, Key:17871): 11299
#  left partition(after XOR with right, right:11299): 13858
# Initial key: 17871; new key: 17886
# Round 5 switching results:
#  left partition: 11299
#  right partition: 13858
#
# Round 6:
#  right partition(after applied F, Key:17886): 29692
#  left partition(after XOR with right, right:29692): 6657
# Initial key: 17886; new key: 17869
# Round 6 switching results:
#  left partition: 29692
#  right partition: 6657
#
# Round 7:
#  right partition(after applied F, Key:17869): 24524
#  left partition(after XOR with right, right:24524): 27133
# Initial key: 17869; new key: 17884
# Round 7 switching results:
#  left partition: 24524
#  right partition: 27133
#
# Round 8:
#  right partition(after applied F, Key:17884): 11297
#  left partition(after XOR with right, right:11297): 13873
# Initial key: 17884; new key: 17867
# Round 8 switching results:
#  left partition: 11297
#  right partition: 13873
#
# Round 9:
#  right partition(after applied F, Key:17867): 29690
#  left partition(after XOR with right, right:29690): 6672
# Initial key: 17867; new key: 17882
# Round 9 switching results:
#  left partition: 29690
#  right partition: 6672
#
# Round 10:
#  right partition(after applied F, Key:17882): 24522
#  left partition(after XOR with right, right:24522): 27114
# Initial key: 17882; new key: 17865
# Round 10 switching results:
#  left partition: 24522
#  right partition: 27114
#
# Round 11:
#  right partition(after applied F, Key:17865): 11299
#  left partition(after XOR with right, right:11299): 13856
# Initial key: 17865; new key: 17880
# Round 11 switching results:
#  left partition: 11299
#  right partition: 13856
#
# Round 12:
#  right partition(after applied F, Key:17880): 29688
#  left partition(after XOR with right, right:29688): 6659
# Initial key: 17880; new key: 17863
# Round 12 switching results:
#  left partition: 29688
#  right partition: 6659
#
# Round 13:
#  right partition(after applied F, Key:17863): 24516
#  left partition(after XOR with right, right:24516): 27131
# Initial key: 17863; new key: 17878
# Round 13 switching results:
#  left partition: 24516
#  right partition: 27131
#
# Round 14:
#  right partition(after applied F, Key:17878): 11309
#  left partition(after XOR with right, right:11309): 13887
# Initial key: 17878; new key: 17861
# Round 14 switching results:
#  left partition: 11309
#  right partition: 13887
#
# Round 15:
#  right partition(after applied F, Key:17861): 29690
#  left partition(after XOR with right, right:29690): 6674
# Initial key: 17861; new key: 17876
# Round 15 switching results:
#  left partition: 29690
#  right partition: 6674
#
# Round 16:
#  right partition(after applied F, Key:17876): 24518
#  left partition(after XOR with right, right:24518): 27112
# Initial key: 17876; new key: 17859
# Round 16 switching results:
#  left partition: 24518
#  right partition: 27112
#
# Final left partition: 27112
# Initial right partition: 24518
#
# Initial key: 17860; new key: 17875
# Initial left partition: 24889
# Initial right partition: 32679
#
# Round 1:
#  right partition(after applied F, Key:17875): 14964
#  left partition(after XOR with right, right:14964): 7838
# Initial key: 17875; new key: 17858
# Round 1 switching results:
#  left partition: 14964
#  right partition: 7838
#
# Round 2:
#  right partition(after applied F, Key:17858): 23388
#  left partition(after XOR with right, right:23388): 9450
# Initial key: 17858; new key: 17873
# Round 2 switching results:
#  left partition: 23388
#  right partition: 9450
#
# Round 3:
#  right partition(after applied F, Key:17873): 24891
#  left partition(after XOR with right, right:24891): 32694
# Initial key: 17873; new key: 17856
# Round 3 switching results:
#  left partition: 24891
#  right partition: 32694
#
# Round 4:
#  right partition(after applied F, Key:17856): 14966
#  left partition(after XOR with right, right:14966): 7821
# Initial key: 17856; new key: 17871
# Round 4 switching results:
#  left partition: 14966
#  right partition: 7821
#
# Round 5:
#  right partition(after applied F, Key:17871): 23362
#  left partition(after XOR with right, right:23362): 9467
# Initial key: 17871; new key: 17886
# Round 5 switching results:
#  left partition: 23362
#  right partition: 9467
#
# Round 6:
#  right partition(after applied F, Key:17886): 24869
#  left partition(after XOR with right, right:24869): 32697
# Initial key: 17886; new key: 17869
# Round 6 switching results:
#  left partition: 24869
#  right partition: 32697
#
# Round 7:
#  right partition(after applied F, Key:17869): 14964
#  left partition(after XOR with right, right:14964): 7836
# Initial key: 17869; new key: 17884
# Round 7 switching results:
#  left partition: 14964
#  right partition: 7836
#
# Round 8:
#  right partition(after applied F, Key:17884): 23360
#  left partition(after XOR with right, right:23360): 9448
# Initial key: 17884; new key: 17867
# Round 8 switching results:
#  left partition: 23360
#  right partition: 9448
#
# Round 9:
#  right partition(after applied F, Key:17867): 24867
#  left partition(after XOR with right, right:24867): 32680
# Initial key: 17867; new key: 17882
# Round 9 switching results:
#  left partition: 24867
#  right partition: 32680
#
# Round 10:
#  right partition(after applied F, Key:17882): 14962
#  left partition(after XOR with right, right:14962): 7819
# Initial key: 17882; new key: 17865
# Round 10 switching results:
#  left partition: 14962
#  right partition: 7819
#
# Round 11:
#  right partition(after applied F, Key:17865): 23362
#  left partition(after XOR with right, right:23362): 9465
# Initial key: 17865; new key: 17880
# Round 11 switching results:
#  left partition: 23362
#  right partition: 9465
#
# Round 12:
#  right partition(after applied F, Key:17880): 24865
#  left partition(after XOR with right, right:24865): 32699
# Initial key: 17880; new key: 17863
# Round 12 switching results:
#  left partition: 24865
#  right partition: 32699
#
# Round 13:
#  right partition(after applied F, Key:17863): 14972
#  left partition(after XOR with right, right:14972): 7834
# Initial key: 17863; new key: 17878
# Round 13 switching results:
#  left partition: 14972
#  right partition: 7834
#
# Round 14:
#  right partition(after applied F, Key:17878): 23372
#  left partition(after XOR with right, right:23372): 9446
# Initial key: 17878; new key: 17861
# Round 14 switching results:
#  left partition: 23372
#  right partition: 9446
#
# Round 15:
#  right partition(after applied F, Key:17861): 24867
#  left partition(after XOR with right, right:24867): 32682
# Initial key: 17861; new key: 17876
# Round 15 switching results:
#  left partition: 24867
#  right partition: 32682
#
# Round 16:
#  right partition(after applied F, Key:17876): 14974
#  left partition(after XOR with right, right:14974): 7817
# Initial key: 17876; new key: 17859
# Round 16 switching results:
#  left partition: 14974
#  right partition: 7817
#
# Final left partition: 7817
# Initial right partition: 14974
#
# Initial key: 17860; new key: 17875
# Initial left partition: 5496
# Initial right partition: 6706
#
# Round 1:
#  right partition(after applied F, Key:17875): 24545
#  left partition(after XOR with right, right:24545): 3914
# Initial key: 17875; new key: 17858
# Round 1 switching results:
#  left partition: 24545
#  right partition: 3914
#
# Round 2:
#  right partition(after applied F, Key:17858): 19080
#  left partition(after XOR with right, right:19080): 20651
# Initial key: 17858; new key: 17873
# Round 2 switching results:
#  left partition: 19080
#  right partition: 20651
#
# Round 3:
#  right partition(after applied F, Key:17873): 5498
#  left partition(after XOR with right, right:5498): 6691
# Initial key: 17873; new key: 17856
# Round 3 switching results:
#  left partition: 5498
#  right partition: 6691
#
# Round 4:
#  right partition(after applied F, Key:17856): 24547
#  left partition(after XOR with right, right:24547): 3929
# Initial key: 17856; new key: 17871
# Round 4 switching results:
#  left partition: 24547
#  right partition: 3929
#
# Round 5:
#  right partition(after applied F, Key:17871): 19094
#  left partition(after XOR with right, right:19094): 20666
# Initial key: 17871; new key: 17886
# Round 5 switching results:
#  left partition: 19094
#  right partition: 20666
#
# Round 6:
#  right partition(after applied F, Key:17886): 5476
#  left partition(after XOR with right, right:5476): 6700
# Initial key: 17886; new key: 17869
# Round 6 switching results:
#  left partition: 5476
#  right partition: 6700
#
# Round 7:
#  right partition(after applied F, Key:17869): 24545
#  left partition(after XOR with right, right:24545): 3912
# Initial key: 17869; new key: 17884
# Round 7 switching results:
#  left partition: 24545
#  right partition: 3912
#
# Round 8:
#  right partition(after applied F, Key:17884): 19092
#  left partition(after XOR with right, right:19092): 20649
# Initial key: 17884; new key: 17867
# Round 8 switching results:
#  left partition: 19092
#  right partition: 20649
#
# Round 9:
#  right partition(after applied F, Key:17867): 5474
#  left partition(after XOR with right, right:5474): 6717
# Initial key: 17867; new key: 17882
# Round 9 switching results:
#  left partition: 5474
#  right partition: 6717
#
# Round 10:
#  right partition(after applied F, Key:17882): 24551
#  left partition(after XOR with right, right:24551): 3935
# Initial key: 17882; new key: 17865
# Round 10 switching results:
#  left partition: 24551
#  right partition: 3935
#
# Round 11:
#  right partition(after applied F, Key:17865): 19094
#  left partition(after XOR with right, right:19094): 20664
# Initial key: 17865; new key: 17880
# Round 11 switching results:
#  left partition: 19094
#  right partition: 20664
#
# Round 12:
#  right partition(after applied F, Key:17880): 5472
#  left partition(after XOR with right, right:5472): 6702
# Initial key: 17880; new key: 17863
# Round 12 switching results:
#  left partition: 5472
#  right partition: 6702
#
# Round 13:
#  right partition(after applied F, Key:17863): 24553
#  left partition(after XOR with right, right:24553): 3918
# Initial key: 17863; new key: 17878
# Round 13 switching results:
#  left partition: 24553
#  right partition: 3918
#
# Round 14:
#  right partition(after applied F, Key:17878): 19096
#  left partition(after XOR with right, right:19096): 20647
# Initial key: 17878; new key: 17861
# Round 14 switching results:
#  left partition: 19096
#  right partition: 20647
#
# Round 15:
#  right partition(after applied F, Key:17861): 5474
#  left partition(after XOR with right, right:5474): 6719
# Initial key: 17861; new key: 17876
# Round 15 switching results:
#  left partition: 5474
#  right partition: 6719
#
# Round 16:
#  right partition(after applied F, Key:17876): 24555
#  left partition(after XOR with right, right:24555): 3933
# Initial key: 17876; new key: 17859
# Round 16 switching results:
#  left partition: 24555
#  right partition: 3933
#
# Final left partition: 3933
# Initial right partition: 24555
#
# Initial key: 17860; new key: 17875
# Initial left partition: 19586
# Initial right partition: 13976
#
# Round 1:
#  right partition(after applied F, Key:17875): 29515
#  left partition(after XOR with right, right:29515): 31258
# Initial key: 17875; new key: 17858
# Round 1 switching results:
#  left partition: 29515
#  right partition: 31258
#
# Round 2:
#  right partition(after applied F, Key:17858): 16344
#  left partition(after XOR with right, right:16344): 2385
# Initial key: 17858; new key: 17873
# Round 2 switching results:
#  left partition: 16344
#  right partition: 2385
#
# Round 3:
#  right partition(after applied F, Key:17873): 19584
#  left partition(after XOR with right, right:19584): 13961
# Initial key: 17873; new key: 17856
# Round 3 switching results:
#  left partition: 19584
#  right partition: 13961
#
# Round 4:
#  right partition(after applied F, Key:17856): 29513
#  left partition(after XOR with right, right:29513): 31241
# Initial key: 17856; new key: 17871
# Round 4 switching results:
#  left partition: 29513
#  right partition: 31241
#
# Round 5:
#  right partition(after applied F, Key:17871): 16326
#  left partition(after XOR with right, right:16326): 2368
# Initial key: 17871; new key: 17886
# Round 5 switching results:
#  left partition: 16326
#  right partition: 2368
#
# Round 6:
#  right partition(after applied F, Key:17886): 19614
#  left partition(after XOR with right, right:19614): 13958
# Initial key: 17886; new key: 17869
# Round 6 switching results:
#  left partition: 19614
#  right partition: 13958
#
# Round 7:
#  right partition(after applied F, Key:17869): 29515
#  left partition(after XOR with right, right:29515): 31256
# Initial key: 17869; new key: 17884
# Round 7 switching results:
#  left partition: 29515
#  right partition: 31256
#
# Round 8:
#  right partition(after applied F, Key:17884): 16324
#  left partition(after XOR with right, right:16324): 2387
# Initial key: 17884; new key: 17867
# Round 8 switching results:
#  left partition: 16324
#  right partition: 2387
#
# Round 9:
#  right partition(after applied F, Key:17867): 19608
#  left partition(after XOR with right, right:19608): 13975
# Initial key: 17867; new key: 17882
# Round 9 switching results:
#  left partition: 19608
#  right partition: 13975
#
# Round 10:
#  right partition(after applied F, Key:17882): 29517
#  left partition(after XOR with right, right:29517): 31247
# Initial key: 17882; new key: 17865
# Round 10 switching results:
#  left partition: 29517
#  right partition: 31247
#
# Round 11:
#  right partition(after applied F, Key:17865): 16326
#  left partition(after XOR with right, right:16326): 2370
# Initial key: 17865; new key: 17880
# Round 11 switching results:
#  left partition: 16326
#  right partition: 2370
#
# Round 12:
#  right partition(after applied F, Key:17880): 19610
#  left partition(after XOR with right, right:19610): 13956
# Initial key: 17880; new key: 17863
# Round 12 switching results:
#  left partition: 19610
#  right partition: 13956
#
# Round 13:
#  right partition(after applied F, Key:17863): 29507
#  left partition(after XOR with right, right:29507): 31262
# Initial key: 17863; new key: 17878
# Round 13 switching results:
#  left partition: 29507
#  right partition: 31262
#
# Round 14:
#  right partition(after applied F, Key:17878): 16328
#  left partition(after XOR with right, right:16328): 2397
# Initial key: 17878; new key: 17861
# Round 14 switching results:
#  left partition: 16328
#  right partition: 2397
#
# Round 15:
#  right partition(after applied F, Key:17861): 19608
#  left partition(after XOR with right, right:19608): 13973
# Initial key: 17861; new key: 17876
# Round 15 switching results:
#  left partition: 19608
#  right partition: 13973
#
# Round 16:
#  right partition(after applied F, Key:17876): 29505
#  left partition(after XOR with right, right:29505): 31245
# Initial key: 17876; new key: 17859
# Round 16 switching results:
#  left partition: 29505
#  right partition: 31245
#
# Final left partition: 31245
# Initial right partition: 29505

# %% [markdown]
# ### Results

# %%
# plaintext
for i in blockList:
    print ([(i[k]) for k in range(len(i))])
# Out:
# ['H', 'e', 'l', 'l']
# ['o', ' ', 'w', 'o']
# ['r', 'l', 'd', '!']
# [' ', 'T', 'h', 'i']
# ['s', ' ', 'i', 's']
# [' ', 'H', 'y', 'l']
# ['m', 'i', ' ', 'a']
# ['n', 'd', ' ', 'L']
# ['o', 'u', 'i', 's']

# %%
# ciphertext
for i in cipher_list:
    print ([chr(i[k]) for k in range(len(i))])
# Out:
# ['\n', 'Ê', '4', 'þ']
# ['c', 'µ', '\x06', 'H']
# ['6', '~', "'", '°']
# ['\x1c', '=', '\n', '\x00']
# ['I', '\xa0', '&', 'ª']
# ['s', 'à', '\x1a', '\x1f']
# ['a', '9', '\x7f', '§']
# ['\x15', 'x', '\x1a', '2']
# ['L', '\x82', '6', '\x98']

# %%
# plaintext
for i in decrypted_list:
    print ([(i[k]) for k in range(len(i))])
# Out:
# ['H', 'e', 'l', 'l']
# ['o', ' ', 'w', 'o']
# ['r', 'l', 'd', '!']
# [' ', 'T', 'h', 'i']
# ['s', ' ', 'i', 's']
# [' ', 'H', 'y', 'l']
# ['m', 'i', ' ', 'a']
# ['n', 'd', ' ', 'L']
# ['o', 'u', 'i', 's']

# %% [markdown]
# © 2024 - Fathi Al Adha Hylmi & Louis Widi Anandaputra
