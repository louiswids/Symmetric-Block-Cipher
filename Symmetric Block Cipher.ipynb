# %% [markdown]
# # Cryptography and Information Security
# ## Symmetric Block Cipher assignment
#
# - Fathi Al Adha Hylmi (22/492195/PA/21008)
# - Louis Widi Anandaputra(22/492218/PA/21090)
#
# We well be constructing a symmetric block cipher for a text message. This method would also work with other data, but we will be implementing it on encrypting strings using the CBC structure (for more than 1 block data) in a feistel structure which uses a finite field arithmetic (addition operation) for a Galois Field(GF).
#
# 1 block wold contain 2^32 data and the finite field arithmetic would use a GF(2^16). The feistel structure rounds can be set as a parameter but we will be using a 16 rounds feistel structure. We also define several functions:
#
# - initialGenKey(length) --> intializing keys for both the key and initial vector (IV). Taking an integer parameter length (bytes)
# - subGenKey(key) --> creating subkeys for the feistel cipher encryption process. Taking an integer parameter (key)
# - reverseSubGenKey(last_key) --> reversing back the subkeys to the original key. Taking an integer parameter (last_key)
# - GFaddition(plain, key) --> Finite Field addition on GF(2^16). Taking integer parameters (plain) and (key)
# <br><br>
# - encrypt_messageCBC(blockList, key, iv, len_of_block, round) --> CBC structure encryption for all blocks. Taking string array parameter (blockList), bytearray parameters (key) and (iv), and integer parameters (len_of_block) and (round)
# - encrypt(plain_block, key) --> initial encryption with IV. Taking string parameter (plain_block) and bytearray parameter (key)
# - feistelEncrypt(plain, key, round) --> feistel structure block encryption. Taking bytearray parameter (plain) and (key), and taking integer parameter (round)
# <br><br>
# - decrypt_cipherCBC(list_cipher, key, iv, round) --> CBC structure decryption for all blocks. Taking bytearray parameters (list_cipher) and (iv), and taking integer parameters (key, round)
# - feistelDecrypt(cipher, key_int, round) --> feistel structure block decryption. Taking bytearray parameter (list) and integer parameters (key_int) and (round)
# - decrypt(cipher, key) --> decryption with IV
# <br><br>
# - breakMessage(message, len_of_blocks) --> breaking data into blocks. Taking string parameter (message) and taking integer parameters (len_of_blocks)
#
# ### reference for code: https://www.youtube.com/watch?v=wwTsRONdAaw
# <br><br>
# <img src = 'https://ctf-wiki.mahaloz.re/crypto/blockcipher/mode/figure/cbc_encryption.png'> <img src = 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Feistel_cipher_diagram_en.svg/300px-Feistel_cipher_diagram_en.svg.png'>

# %% [markdown]
# # Keys and Finite Field Arithmetic

# %%
# %%time
from os import urandom

# Initial key generator
def initialGenKey(length):
    return bytearray(urandom(length))
    
def subGenKey(key):
    # perform an addition by 1 and XOR by 1 and 0
    value = (key + 1) ^ 0x10
    # reset the value to 0 if it exceeds the maximum limit
    shifted_key = value & ((1 << 16) - 1)  # 16 bit limit
    print(f"Initial key: {key}; new key: {shifted_key}")
    return shifted_key
    
def reverseSubGenKey(last_key):
    # perform the inverse XOR operation to recover the value before XOR
    value = (last_key ^ 0x10)-1
    # reset the value to 0 if it exceeds the maximum limit
    key = value & ((1 << 16) - 1)# 16 bit limit
    print(f"Initial key: {last_key}; new key: {key}")
    return key
    
# we will be using a 2^16 finite field addition operation, which will be using XOR operation
def GFaddition(plain, key):
    value = plain ^ key
    value = value & ((1 << 16) - 1)
    return value
# Out:
# CPU times: user 11 µs, sys: 1 µs, total: 12 µs
# Wall time: 13.8 µs

# %% [markdown]
# ## Encryption

# %%
def encrypt_messageCBC(blockList, key, iv, len_of_block, round):
    list_of_ciphers = []
    for i in range(len(blockList)):
        print (f"\nBlock {i}:\n{blockList[i]}\n")
        # performing initial encryption with initial vector
        cipher1 = encrypt(blockList[i], iv)
        # performing the feistel cipher encryption
        cipher2, key_last = feistelEncrypt(cipher1, key, round)
        list_of_ciphers.append(cipher2)
        iv = cipher2
    return list_of_ciphers, key_last

# %%
def encrypt(plain_block, key):
    return bytearray([ord(plain_block[i]) ^ key[i] for i in range(len(plain_block))])

# %%
def feistelEncrypt(plain, key, round):
    # Changing key and plaintext into integers for encryption process
    key_int = int.from_bytes(key, byteorder='big')
    plain = int.from_bytes(plain, byteorder='big')

    # Splitting the bits to half (16 - 16)
    left = plain >> 16
    right = plain & 0xffff
    print(f"Initial left partition: {left}\nInitial right partition: {right}\n")

    # feistel structure
    for k in range ( round):  #rounds
        temp = GFaddition(right, key_int) # Using the Galois Field encryption
        left = left ^ temp
        print(f"Round {k+1}:Round {k+1}:\n right partition(after applied F, Key:{key_int}): {right}\n left partition(after XOR with right, right:{right}): {left}")

        # generating new subkey
        key_int = subGenKey(key_int)

        #switching the left and right data
        temp = right
        right = left
        left = temp
        print(f"Round {k+1} switching results:\n left partition: {left}\n right partition: {right}\n")

    # final switch for the left and right data   
    temp = right
    right = left
    left = temp    
    print(f"Final left partition: {left}\nInitial right partition: {right}\n")
    
    key = key_int
    # making sure the length is still 2^16
    encrypted_block = (left <<16)|right
    # changing back into bytes
    encrypted_block = encrypted_block.to_bytes((encrypted_block.bit_length() + 7) // 8, byteorder='big')
    return encrypted_block, key

# %% [markdown]
# ## Decryption

# %%
def decrypt_cipherCBC(list_cipher, key, iv, round):
    list_of_decrypted_blocks = []
    temp, key_last = feistelDecrypt(list_cipher[0], key, round)
    plain = decrypt(temp, iv)
    list_of_decrypted_blocks.append(plain)
    for i in range(1, len(list_cipher)):
        temp, key_last = feistelDecrypt(list_cipher[i], key, round)
        plain = decrypt(temp, list_cipher[i-1])
        list_of_decrypted_blocks.append(plain)
    return list_of_decrypted_blocks

# %%
# Change this according to the feistel encryption method
def feistelDecrypt(cipher, key_int, round):
    cipher = int.from_bytes(cipher, byteorder='big')
    key_int = reverseSubGenKey(key_int)
    left = cipher >> 16
    right = cipher & 0xffff
    print(f"Initial left partition: {left}\nInitial right partition: {right}\n")
  
    for k in range (round):  #rounds
        temp = GFaddition(right, key_int)
        left = left ^ temp
        
        
        print(f"Round {k+1}:\n right partition(after applied F, Key:{key_int}): {right}\n left partition(after XOR with right, right:{right}): {left}")
        
        key_int = reverseSubGenKey(key_int)
        
        temp = right
        right = left
        left = temp
        print(f"Round {k+1} switching results:\n left partition: {left}\n right partition: {right}\n")

    temp = right
    right = left
    left = temp
    print(f"Final left partition: {left}\nInitial right partition: {right}\n")
    
    key = key_int
    decrypted_block = (left <<16)|right
    decrypted_block = decrypted_block.to_bytes((decrypted_block.bit_length() + 7) // 8, byteorder='big')
    return decrypted_block, key

# %%
# Change this according to the feistel encryption method
def decrypt(cipher, key):
    return [chr(cipher[i] ^ key[i]) for i in range(len(cipher))]

# %% [markdown]
# ## Block Creation

# %%
def breakMessage(message, len_of_blocks):
    list_of_blocks = []
    for i in range (0, len(message), len_of_blocks):
        block = message[i:i+len_of_block]
        if(len(block) == len_of_blocks):
            list_of_blocks.append(block)
        else:
            c = len_of_blocks - len(block)
            for i in range(c):
                block = block + " "
            list_of_blocks.append(block)
    return list_of_blocks

# %% [markdown]
# ## Demo

# %%
# Initialization
text = "Hello world! This is Louis and Hylmi"
len_of_block = 4
len_of_feistel = 2
round = 16
blockList = breakMessage(text, len_of_block)

# %%
key = initialGenKey(len_of_feistel)
iv = initialGenKey(len_of_block)

# %%
print(f"Key: {key}\nIV: {iv}")
# Out:
# Key: bytearray(b'\x8cS')
# IV: bytearray(b'\x0e\x95Qf')

# %%
# encryption
cipher_list, key_last_used= encrypt_messageCBC(blockList, key, iv, len_of_block, round = round)
# Out:
# Block 0:
# Hell
#
# Initial left partition: 18160
# Initial right partition: 15626
#
# Round 1:Round 1:
#  right partition(after applied F, Key:35923): 15626
#  left partition(after XOR with right, right:15626): 63401
# Initial key: 35923; new key: 35908
# Round 1 switching results:
#  left partition: 15626
#  right partition: 63401
#
# Round 2:Round 2:
#  right partition(after applied F, Key:35908): 63401
#  left partition(after XOR with right, right:63401): 18151
# Initial key: 35908; new key: 35925
# Round 2 switching results:
#  left partition: 63401
#  right partition: 18151
#
# Round 3:Round 3:
#  right partition(after applied F, Key:35925): 18151
#  left partition(after XOR with right, right:18151): 15643
# Initial key: 35925; new key: 35910
# Round 3 switching results:
#  left partition: 18151
#  right partition: 15643
#
# Round 4:Round 4:
#  right partition(after applied F, Key:35910): 15643
#  left partition(after XOR with right, right:15643): 63418
# Initial key: 35910; new key: 35927
# Round 4 switching results:
#  left partition: 15643
#  right partition: 63418
#
# Round 5:Round 5:
#  right partition(after applied F, Key:35927): 63418
#  left partition(after XOR with right, right:63418): 18166
# Initial key: 35927; new key: 35912
# Round 5 switching results:
#  left partition: 63418
#  right partition: 18166
#
# Round 6:Round 6:
#  right partition(after applied F, Key:35912): 18166
#  left partition(after XOR with right, right:18166): 15620
# Initial key: 35912; new key: 35929
# Round 6 switching results:
#  left partition: 18166
#  right partition: 15620
#
# Round 7:Round 7:
#  right partition(after applied F, Key:35929): 15620
#  left partition(after XOR with right, right:15620): 63403
# Initial key: 35929; new key: 35914
# Round 7 switching results:
#  left partition: 15620
#  right partition: 63403
#
# Round 8:Round 8:
#  right partition(after applied F, Key:35914): 63403
#  left partition(after XOR with right, right:63403): 18149
# Initial key: 35914; new key: 35931
# Round 8 switching results:
#  left partition: 63403
#  right partition: 18149
#
# Round 9:Round 9:
#  right partition(after applied F, Key:35931): 18149
#  left partition(after XOR with right, right:18149): 15637
# Initial key: 35931; new key: 35916
# Round 9 switching results:
#  left partition: 18149
#  right partition: 15637
#
# Round 10:Round 10:
#  right partition(after applied F, Key:35916): 15637
#  left partition(after XOR with right, right:15637): 63420
# Initial key: 35916; new key: 35933
# Round 10 switching results:
#  left partition: 15637
#  right partition: 63420
#
# Round 11:Round 11:
#  right partition(after applied F, Key:35933): 63420
#  left partition(after XOR with right, right:63420): 18164
# Initial key: 35933; new key: 35918
# Round 11 switching results:
#  left partition: 63420
#  right partition: 18164
#
# Round 12:Round 12:
#  right partition(after applied F, Key:35918): 18164
#  left partition(after XOR with right, right:18164): 15622
# Initial key: 35918; new key: 35935
# Round 12 switching results:
#  left partition: 18164
#  right partition: 15622
#
# Round 13:Round 13:
#  right partition(after applied F, Key:35935): 15622
#  left partition(after XOR with right, right:15622): 63405
# Initial key: 35935; new key: 35952
# Round 13 switching results:
#  left partition: 15622
#  right partition: 63405
#
# Round 14:Round 14:
#  right partition(after applied F, Key:35952): 63405
#  left partition(after XOR with right, right:63405): 18139
# Initial key: 35952; new key: 35937
# Round 14 switching results:
#  left partition: 63405
#  right partition: 18139
#
# Round 15:Round 15:
#  right partition(after applied F, Key:35937): 18139
#  left partition(after XOR with right, right:18139): 15639
# Initial key: 35937; new key: 35954
# Round 15 switching results:
#  left partition: 18139
#  right partition: 15639
#
# Round 16:Round 16:
#  right partition(after applied F, Key:35954): 15639
#  left partition(after XOR with right, right:15639): 63422
# Initial key: 35954; new key: 35939
# Round 16 switching results:
#  left partition: 15639
#  right partition: 63422
#
# Final left partition: 63422
# Initial right partition: 15639
#
#
# Block 1:
# o wo
#
# Initial left partition: 39070
# Initial right partition: 19064
#
# Round 1:Round 1:
#  right partition(after applied F, Key:35923): 19064
#  left partition(after XOR with right, right:19064): 24245
# Initial key: 35923; new key: 35908
# Round 1 switching results:
#  left partition: 19064
#  right partition: 24245
#
# Round 2:Round 2:
#  right partition(after applied F, Key:35908): 24245
#  left partition(after XOR with right, right:24245): 39049
# Initial key: 35908; new key: 35925
# Round 2 switching results:
#  left partition: 24245
#  right partition: 39049
#
# Round 3:Round 3:
#  right partition(after applied F, Key:35925): 39049
#  left partition(after XOR with right, right:39049): 19049
# Initial key: 35925; new key: 35910
# Round 3 switching results:
#  left partition: 39049
#  right partition: 19049
#
# Round 4:Round 4:
#  right partition(after applied F, Key:35910): 19049
#  left partition(after XOR with right, right:19049): 24230
# Initial key: 35910; new key: 35927
# Round 4 switching results:
#  left partition: 19049
#  right partition: 24230
#
# Round 5:Round 5:
#  right partition(after applied F, Key:35927): 24230
#  left partition(after XOR with right, right:24230): 39064
# Initial key: 35927; new key: 35912
# Round 5 switching results:
#  left partition: 24230
#  right partition: 39064
#
# Round 6:Round 6:
#  right partition(after applied F, Key:35912): 39064
#  left partition(after XOR with right, right:39064): 19062
# Initial key: 35912; new key: 35929
# Round 6 switching results:
#  left partition: 39064
#  right partition: 19062
#
# Round 7:Round 7:
#  right partition(after applied F, Key:35929): 19062
#  left partition(after XOR with right, right:19062): 24247
# Initial key: 35929; new key: 35914
# Round 7 switching results:
#  left partition: 19062
#  right partition: 24247
#
# Round 8:Round 8:
#  right partition(after applied F, Key:35914): 24247
#  left partition(after XOR with right, right:24247): 39051
# Initial key: 35914; new key: 35931
# Round 8 switching results:
#  left partition: 24247
#  right partition: 39051
#
# Round 9:Round 9:
#  right partition(after applied F, Key:35931): 39051
#  left partition(after XOR with right, right:39051): 19047
# Initial key: 35931; new key: 35916
# Round 9 switching results:
#  left partition: 39051
#  right partition: 19047
#
# Round 10:Round 10:
#  right partition(after applied F, Key:35916): 19047
#  left partition(after XOR with right, right:19047): 24224
# Initial key: 35916; new key: 35933
# Round 10 switching results:
#  left partition: 19047
#  right partition: 24224
#
# Round 11:Round 11:
#  right partition(after applied F, Key:35933): 24224
#  left partition(after XOR with right, right:24224): 39066
# Initial key: 35933; new key: 35918
# Round 11 switching results:
#  left partition: 24224
#  right partition: 39066
#
# Round 12:Round 12:
#  right partition(after applied F, Key:35918): 39066
#  left partition(after XOR with right, right:39066): 19060
# Initial key: 35918; new key: 35935
# Round 12 switching results:
#  left partition: 39066
#  right partition: 19060
#
# Round 13:Round 13:
#  right partition(after applied F, Key:35935): 19060
#  left partition(after XOR with right, right:19060): 24241
# Initial key: 35935; new key: 35952
# Round 13 switching results:
#  left partition: 19060
#  right partition: 24241
#
# Round 14:Round 14:
#  right partition(after applied F, Key:35952): 24241
#  left partition(after XOR with right, right:24241): 39093
# Initial key: 35952; new key: 35937
# Round 14 switching results:
#  left partition: 24241
#  right partition: 39093
#
# Round 15:Round 15:
#  right partition(after applied F, Key:35937): 39093
#  left partition(after XOR with right, right:39093): 19045
# Initial key: 35937; new key: 35954
# Round 15 switching results:
#  left partition: 39093
#  right partition: 19045
#
# Round 16:Round 16:
#  right partition(after applied F, Key:35954): 19045
#  left partition(after XOR with right, right:19045): 24226
# Initial key: 35954; new key: 35939
# Round 16 switching results:
#  left partition: 19045
#  right partition: 24226
#
# Final left partition: 24226
# Initial right partition: 19045
#
#
# Block 2:
# rld!
#
# Initial left partition: 11470
# Initial right partition: 11844
#
# Round 1:Round 1:
#  right partition(after applied F, Key:35923): 11844
#  left partition(after XOR with right, right:11844): 36569
# Initial key: 35923; new key: 35908
# Round 1 switching results:
#  left partition: 11844
#  right partition: 36569
#
# Round 2:Round 2:
#  right partition(after applied F, Key:35908): 36569
#  left partition(after XOR with right, right:36569): 11481
# Initial key: 35908; new key: 35925
# Round 2 switching results:
#  left partition: 36569
#  right partition: 11481
#
# Round 3:Round 3:
#  right partition(after applied F, Key:35925): 11481
#  left partition(after XOR with right, right:11481): 11861
# Initial key: 35925; new key: 35910
# Round 3 switching results:
#  left partition: 11481
#  right partition: 11861
#
# Round 4:Round 4:
#  right partition(after applied F, Key:35910): 11861
#  left partition(after XOR with right, right:11861): 36554
# Initial key: 35910; new key: 35927
# Round 4 switching results:
#  left partition: 11861
#  right partition: 36554
#
# Round 5:Round 5:
#  right partition(after applied F, Key:35927): 36554
#  left partition(after XOR with right, right:36554): 11464
# Initial key: 35927; new key: 35912
# Round 5 switching results:
#  left partition: 36554
#  right partition: 11464
#
# Round 6:Round 6:
#  right partition(after applied F, Key:35912): 11464
#  left partition(after XOR with right, right:11464): 11850
# Initial key: 35912; new key: 35929
# Round 6 switching results:
#  left partition: 11464
#  right partition: 11850
#
# Round 7:Round 7:
#  right partition(after applied F, Key:35929): 11850
#  left partition(after XOR with right, right:11850): 36571
# Initial key: 35929; new key: 35914
# Round 7 switching results:
#  left partition: 11850
#  right partition: 36571
#
# Round 8:Round 8:
#  right partition(after applied F, Key:35914): 36571
#  left partition(after XOR with right, right:36571): 11483
# Initial key: 35914; new key: 35931
# Round 8 switching results:
#  left partition: 36571
#  right partition: 11483
#
# Round 9:Round 9:
#  right partition(after applied F, Key:35931): 11483
#  left partition(after XOR with right, right:11483): 11867
# Initial key: 35931; new key: 35916
# Round 9 switching results:
#  left partition: 11483
#  right partition: 11867
#
# Round 10:Round 10:
#  right partition(after applied F, Key:35916): 11867
#  left partition(after XOR with right, right:11867): 36556
# Initial key: 35916; new key: 35933
# Round 10 switching results:
#  left partition: 11867
#  right partition: 36556
#
# Round 11:Round 11:
#  right partition(after applied F, Key:35933): 36556
#  left partition(after XOR with right, right:36556): 11466
# Initial key: 35933; new key: 35918
# Round 11 switching results:
#  left partition: 36556
#  right partition: 11466
#
# Round 12:Round 12:
#  right partition(after applied F, Key:35918): 11466
#  left partition(after XOR with right, right:11466): 11848
# Initial key: 35918; new key: 35935
# Round 12 switching results:
#  left partition: 11466
#  right partition: 11848
#
# Round 13:Round 13:
#  right partition(after applied F, Key:35935): 11848
#  left partition(after XOR with right, right:11848): 36573
# Initial key: 35935; new key: 35952
# Round 13 switching results:
#  left partition: 11848
#  right partition: 36573
#
# Round 14:Round 14:
#  right partition(after applied F, Key:35952): 36573
#  left partition(after XOR with right, right:36573): 11493
# Initial key: 35952; new key: 35937
# Round 14 switching results:
#  left partition: 36573
#  right partition: 11493
#
# Round 15:Round 15:
#  right partition(after applied F, Key:35937): 11493
#  left partition(after XOR with right, right:11493): 11865
# Initial key: 35937; new key: 35954
# Round 15 switching results:
#  left partition: 11493
#  right partition: 11865
#
# Round 16:Round 16:
#  right partition(after applied F, Key:35954): 11865
#  left partition(after XOR with right, right:11865): 36558
# Initial key: 35954; new key: 35939
# Round 16 switching results:
#  left partition: 11865
#  right partition: 36558
#
# Final left partition: 36558
# Initial right partition: 11865
#
#
# Block 3:
#  Thi
#
# Initial left partition: 44698
# Initial right partition: 17968
#
# Round 1:Round 1:
#  right partition(after applied F, Key:35923): 17968
#  left partition(after XOR with right, right:17968): 25849
# Initial key: 35923; new key: 35908
# Round 1 switching results:
#  left partition: 17968
#  right partition: 25849
#
# Round 2:Round 2:
#  right partition(after applied F, Key:35908): 25849
#  left partition(after XOR with right, right:25849): 44685
# Initial key: 35908; new key: 35925
# Round 2 switching results:
#  left partition: 25849
#  right partition: 44685
#
# Round 3:Round 3:
#  right partition(after applied F, Key:35925): 44685
#  left partition(after XOR with right, right:44685): 17953
# Initial key: 35925; new key: 35910
# Round 3 switching results:
#  left partition: 44685
#  right partition: 17953
#
# Round 4:Round 4:
#  right partition(after applied F, Key:35910): 17953
#  left partition(after XOR with right, right:17953): 25834
# Initial key: 35910; new key: 35927
# Round 4 switching results:
#  left partition: 17953
#  right partition: 25834
#
# Round 5:Round 5:
#  right partition(after applied F, Key:35927): 25834
#  left partition(after XOR with right, right:25834): 44700
# Initial key: 35927; new key: 35912
# Round 5 switching results:
#  left partition: 25834
#  right partition: 44700
#
# Round 6:Round 6:
#  right partition(after applied F, Key:35912): 44700
#  left partition(after XOR with right, right:44700): 17982
# Initial key: 35912; new key: 35929
# Round 6 switching results:
#  left partition: 44700
#  right partition: 17982
#
# Round 7:Round 7:
#  right partition(after applied F, Key:35929): 17982
#  left partition(after XOR with right, right:17982): 25851
# Initial key: 35929; new key: 35914
# Round 7 switching results:
#  left partition: 17982
#  right partition: 25851
#
# Round 8:Round 8:
#  right partition(after applied F, Key:35914): 25851
#  left partition(after XOR with right, right:25851): 44687
# Initial key: 35914; new key: 35931
# Round 8 switching results:
#  left partition: 25851
#  right partition: 44687
#
# Round 9:Round 9:
#  right partition(after applied F, Key:35931): 44687
#  left partition(after XOR with right, right:44687): 17967
# Initial key: 35931; new key: 35916
# Round 9 switching results:
#  left partition: 44687
#  right partition: 17967
#
# Round 10:Round 10:
#  right partition(after applied F, Key:35916): 17967
#  left partition(after XOR with right, right:17967): 25836
# Initial key: 35916; new key: 35933
# Round 10 switching results:
#  left partition: 17967
#  right partition: 25836
#
# Round 11:Round 11:
#  right partition(after applied F, Key:35933): 25836
#  left partition(after XOR with right, right:25836): 44702
# Initial key: 35933; new key: 35918
# Round 11 switching results:
#  left partition: 25836
#  right partition: 44702
#
# Round 12:Round 12:
#  right partition(after applied F, Key:35918): 44702
#  left partition(after XOR with right, right:44702): 17980
# Initial key: 35918; new key: 35935
# Round 12 switching results:
#  left partition: 44702
#  right partition: 17980
#
# Round 13:Round 13:
#  right partition(after applied F, Key:35935): 17980
#  left partition(after XOR with right, right:17980): 25853
# Initial key: 35935; new key: 35952
# Round 13 switching results:
#  left partition: 17980
#  right partition: 25853
#
# Round 14:Round 14:
#  right partition(after applied F, Key:35952): 25853
#  left partition(after XOR with right, right:25853): 44721
# Initial key: 35952; new key: 35937
# Round 14 switching results:
#  left partition: 25853
#  right partition: 44721
#
# Round 15:Round 15:
#  right partition(after applied F, Key:35937): 44721
#  left partition(after XOR with right, right:44721): 17965
# Initial key: 35937; new key: 35954
# Round 15 switching results:
#  left partition: 44721
#  right partition: 17965
#
# Round 16:Round 16:
#  right partition(after applied F, Key:35954): 17965
#  left partition(after XOR with right, right:17965): 25838
# Initial key: 35954; new key: 35939
# Round 16 switching results:
#  left partition: 17965
#  right partition: 25838
#
# Final left partition: 25838
# Initial right partition: 17965
#
#
# Block 4:
# s is
#
# Initial left partition: 6094
# Initial right partition: 12126
#
# Round 1:Round 1:
#  right partition(after applied F, Key:35923): 12126
#  left partition(after XOR with right, right:12126): 46275
# Initial key: 35923; new key: 35908
# Round 1 switching results:
#  left partition: 12126
#  right partition: 46275
#
# Round 2:Round 2:
#  right partition(after applied F, Key:35908): 46275
#  left partition(after XOR with right, right:46275): 6105
# Initial key: 35908; new key: 35925
# Round 2 switching results:
#  left partition: 46275
#  right partition: 6105
#
# Round 3:Round 3:
#  right partition(after applied F, Key:35925): 6105
#  left partition(after XOR with right, right:6105): 12111
# Initial key: 35925; new key: 35910
# Round 3 switching results:
#  left partition: 6105
#  right partition: 12111
#
# Round 4:Round 4:
#  right partition(after applied F, Key:35910): 12111
#  left partition(after XOR with right, right:12111): 46288
# Initial key: 35910; new key: 35927
# Round 4 switching results:
#  left partition: 12111
#  right partition: 46288
#
# Round 5:Round 5:
#  right partition(after applied F, Key:35927): 46288
#  left partition(after XOR with right, right:46288): 6088
# Initial key: 35927; new key: 35912
# Round 5 switching results:
#  left partition: 46288
#  right partition: 6088
#
# Round 6:Round 6:
#  right partition(after applied F, Key:35912): 6088
#  left partition(after XOR with right, right:6088): 12112
# Initial key: 35912; new key: 35929
# Round 6 switching results:
#  left partition: 6088
#  right partition: 12112
#
# Round 7:Round 7:
#  right partition(after applied F, Key:35929): 12112
#  left partition(after XOR with right, right:12112): 46273
# Initial key: 35929; new key: 35914
# Round 7 switching results:
#  left partition: 12112
#  right partition: 46273
#
# Round 8:Round 8:
#  right partition(after applied F, Key:35914): 46273
#  left partition(after XOR with right, right:46273): 6107
# Initial key: 35914; new key: 35931
# Round 8 switching results:
#  left partition: 46273
#  right partition: 6107
#
# Round 9:Round 9:
#  right partition(after applied F, Key:35931): 6107
#  left partition(after XOR with right, right:6107): 12097
# Initial key: 35931; new key: 35916
# Round 9 switching results:
#  left partition: 6107
#  right partition: 12097
#
# Round 10:Round 10:
#  right partition(after applied F, Key:35916): 12097
#  left partition(after XOR with right, right:12097): 46294
# Initial key: 35916; new key: 35933
# Round 10 switching results:
#  left partition: 12097
#  right partition: 46294
#
# Round 11:Round 11:
#  right partition(after applied F, Key:35933): 46294
#  left partition(after XOR with right, right:46294): 6090
# Initial key: 35933; new key: 35918
# Round 11 switching results:
#  left partition: 46294
#  right partition: 6090
#
# Round 12:Round 12:
#  right partition(after applied F, Key:35918): 6090
#  left partition(after XOR with right, right:6090): 12114
# Initial key: 35918; new key: 35935
# Round 12 switching results:
#  left partition: 6090
#  right partition: 12114
#
# Round 13:Round 13:
#  right partition(after applied F, Key:35935): 12114
#  left partition(after XOR with right, right:12114): 46279
# Initial key: 35935; new key: 35952
# Round 13 switching results:
#  left partition: 12114
#  right partition: 46279
#
# Round 14:Round 14:
#  right partition(after applied F, Key:35952): 46279
#  left partition(after XOR with right, right:46279): 6117
# Initial key: 35952; new key: 35937
# Round 14 switching results:
#  left partition: 46279
#  right partition: 6117
#
# Round 15:Round 15:
#  right partition(after applied F, Key:35937): 6117
#  left partition(after XOR with right, right:6117): 12099
# Initial key: 35937; new key: 35954
# Round 15 switching results:
#  left partition: 6117
#  right partition: 12099
#
# Round 16:Round 16:
#  right partition(after applied F, Key:35954): 12099
#  left partition(after XOR with right, right:12099): 46292
# Initial key: 35954; new key: 35939
# Round 16 switching results:
#  left partition: 12099
#  right partition: 46292
#
# Final left partition: 46292
# Initial right partition: 12099
#
#
# Block 5:
#  Lou
#
# Initial left partition: 38040
# Initial right partition: 16438
#
# Round 1:Round 1:
#  right partition(after applied F, Key:35923): 16438
#  left partition(after XOR with right, right:16438): 22781
# Initial key: 35923; new key: 35908
# Round 1 switching results:
#  left partition: 16438
#  right partition: 22781
#
# Round 2:Round 2:
#  right partition(after applied F, Key:35908): 22781
#  left partition(after XOR with right, right:22781): 38031
# Initial key: 35908; new key: 35925
# Round 2 switching results:
#  left partition: 22781
#  right partition: 38031
#
# Round 3:Round 3:
#  right partition(after applied F, Key:35925): 38031
#  left partition(after XOR with right, right:38031): 16423
# Initial key: 35925; new key: 35910
# Round 3 switching results:
#  left partition: 38031
#  right partition: 16423
#
# Round 4:Round 4:
#  right partition(after applied F, Key:35910): 16423
#  left partition(after XOR with right, right:16423): 22766
# Initial key: 35910; new key: 35927
# Round 4 switching results:
#  left partition: 16423
#  right partition: 22766
#
# Round 5:Round 5:
#  right partition(after applied F, Key:35927): 22766
#  left partition(after XOR with right, right:22766): 38046
# Initial key: 35927; new key: 35912
# Round 5 switching results:
#  left partition: 22766
#  right partition: 38046
#
# Round 6:Round 6:
#  right partition(after applied F, Key:35912): 38046
#  left partition(after XOR with right, right:38046): 16440
# Initial key: 35912; new key: 35929
# Round 6 switching results:
#  left partition: 38046
#  right partition: 16440
#
# Round 7:Round 7:
#  right partition(after applied F, Key:35929): 16440
#  left partition(after XOR with right, right:16440): 22783
# Initial key: 35929; new key: 35914
# Round 7 switching results:
#  left partition: 16440
#  right partition: 22783
#
# Round 8:Round 8:
#  right partition(after applied F, Key:35914): 22783
#  left partition(after XOR with right, right:22783): 38029
# Initial key: 35914; new key: 35931
# Round 8 switching results:
#  left partition: 22783
#  right partition: 38029
#
# Round 9:Round 9:
#  right partition(after applied F, Key:35931): 38029
#  left partition(after XOR with right, right:38029): 16425
# Initial key: 35931; new key: 35916
# Round 9 switching results:
#  left partition: 38029
#  right partition: 16425
#
# Round 10:Round 10:
#  right partition(after applied F, Key:35916): 16425
#  left partition(after XOR with right, right:16425): 22760
# Initial key: 35916; new key: 35933
# Round 10 switching results:
#  left partition: 16425
#  right partition: 22760
#
# Round 11:Round 11:
#  right partition(after applied F, Key:35933): 22760
#  left partition(after XOR with right, right:22760): 38044
# Initial key: 35933; new key: 35918
# Round 11 switching results:
#  left partition: 22760
#  right partition: 38044
#
# Round 12:Round 12:
#  right partition(after applied F, Key:35918): 38044
#  left partition(after XOR with right, right:38044): 16442
# Initial key: 35918; new key: 35935
# Round 12 switching results:
#  left partition: 38044
#  right partition: 16442
#
# Round 13:Round 13:
#  right partition(after applied F, Key:35935): 16442
#  left partition(after XOR with right, right:16442): 22777
# Initial key: 35935; new key: 35952
# Round 13 switching results:
#  left partition: 16442
#  right partition: 22777
#
# Round 14:Round 14:
#  right partition(after applied F, Key:35952): 22777
#  left partition(after XOR with right, right:22777): 38067
# Initial key: 35952; new key: 35937
# Round 14 switching results:
#  left partition: 22777
#  right partition: 38067
#
# Round 15:Round 15:
#  right partition(after applied F, Key:35937): 38067
#  left partition(after XOR with right, right:38067): 16427
# Initial key: 35937; new key: 35954
# Round 15 switching results:
#  left partition: 38067
#  right partition: 16427
#
# Round 16:Round 16:
#  right partition(after applied F, Key:35954): 16427
#  left partition(after XOR with right, right:16427): 22762
# Initial key: 35954; new key: 35939
# Round 16 switching results:
#  left partition: 16427
#  right partition: 22762
#
# Final left partition: 22762
# Initial right partition: 16427
#
#
# Block 6:
# is a
#
# Initial left partition: 12697
# Initial right partition: 24650
#
# Round 1:Round 1:
#  right partition(after applied F, Key:35923): 24650
#  left partition(after XOR with right, right:24650): 56704
# Initial key: 35923; new key: 35908
# Round 1 switching results:
#  left partition: 24650
#  right partition: 56704
#
# Round 2:Round 2:
#  right partition(after applied F, Key:35908): 56704
#  left partition(after XOR with right, right:56704): 12686
# Initial key: 35908; new key: 35925
# Round 2 switching results:
#  left partition: 56704
#  right partition: 12686
#
# Round 3:Round 3:
#  right partition(after applied F, Key:35925): 12686
#  left partition(after XOR with right, right:12686): 24667
# Initial key: 35925; new key: 35910
# Round 3 switching results:
#  left partition: 12686
#  right partition: 24667
#
# Round 4:Round 4:
#  right partition(after applied F, Key:35910): 24667
#  left partition(after XOR with right, right:24667): 56723
# Initial key: 35910; new key: 35927
# Round 4 switching results:
#  left partition: 24667
#  right partition: 56723
#
# Round 5:Round 5:
#  right partition(after applied F, Key:35927): 56723
#  left partition(after XOR with right, right:56723): 12703
# Initial key: 35927; new key: 35912
# Round 5 switching results:
#  left partition: 56723
#  right partition: 12703
#
# Round 6:Round 6:
#  right partition(after applied F, Key:35912): 12703
#  left partition(after XOR with right, right:12703): 24644
# Initial key: 35912; new key: 35929
# Round 6 switching results:
#  left partition: 12703
#  right partition: 24644
#
# Round 7:Round 7:
#  right partition(after applied F, Key:35929): 24644
#  left partition(after XOR with right, right:24644): 56706
# Initial key: 35929; new key: 35914
# Round 7 switching results:
#  left partition: 24644
#  right partition: 56706
#
# Round 8:Round 8:
#  right partition(after applied F, Key:35914): 56706
#  left partition(after XOR with right, right:56706): 12684
# Initial key: 35914; new key: 35931
# Round 8 switching results:
#  left partition: 56706
#  right partition: 12684
#
# Round 9:Round 9:
#  right partition(after applied F, Key:35931): 12684
#  left partition(after XOR with right, right:12684): 24661
# Initial key: 35931; new key: 35916
# Round 9 switching results:
#  left partition: 12684
#  right partition: 24661
#
# Round 10:Round 10:
#  right partition(after applied F, Key:35916): 24661
#  left partition(after XOR with right, right:24661): 56725
# Initial key: 35916; new key: 35933
# Round 10 switching results:
#  left partition: 24661
#  right partition: 56725
#
# Round 11:Round 11:
#  right partition(after applied F, Key:35933): 56725
#  left partition(after XOR with right, right:56725): 12701
# Initial key: 35933; new key: 35918
# Round 11 switching results:
#  left partition: 56725
#  right partition: 12701
#
# Round 12:Round 12:
#  right partition(after applied F, Key:35918): 12701
#  left partition(after XOR with right, right:12701): 24646
# Initial key: 35918; new key: 35935
# Round 12 switching results:
#  left partition: 12701
#  right partition: 24646
#
# Round 13:Round 13:
#  right partition(after applied F, Key:35935): 24646
#  left partition(after XOR with right, right:24646): 56708
# Initial key: 35935; new key: 35952
# Round 13 switching results:
#  left partition: 24646
#  right partition: 56708
#
# Round 14:Round 14:
#  right partition(after applied F, Key:35952): 56708
#  left partition(after XOR with right, right:56708): 12722
# Initial key: 35952; new key: 35937
# Round 14 switching results:
#  left partition: 56708
#  right partition: 12722
#
# Round 15:Round 15:
#  right partition(after applied F, Key:35937): 12722
#  left partition(after XOR with right, right:12722): 24663
# Initial key: 35937; new key: 35954
# Round 15 switching results:
#  left partition: 12722
#  right partition: 24663
#
# Round 16:Round 16:
#  right partition(after applied F, Key:35954): 24663
#  left partition(after XOR with right, right:24663): 56727
# Initial key: 35954; new key: 35939
# Round 16 switching results:
#  left partition: 24663
#  right partition: 56727
#
# Final left partition: 56727
# Initial right partition: 24663
#
#
# Block 7:
# nd H
#
# Initial left partition: 46067
# Initial right partition: 16415
#
# Round 1:Round 1:
#  right partition(after applied F, Key:35923): 16415
#  left partition(after XOR with right, right:16415): 32703
# Initial key: 35923; new key: 35908
# Round 1 switching results:
#  left partition: 16415
#  right partition: 32703
#
# Round 2:Round 2:
#  right partition(after applied F, Key:35908): 32703
#  left partition(after XOR with right, right:32703): 46052
# Initial key: 35908; new key: 35925
# Round 2 switching results:
#  left partition: 32703
#  right partition: 46052
#
# Round 3:Round 3:
#  right partition(after applied F, Key:35925): 46052
#  left partition(after XOR with right, right:46052): 16398
# Initial key: 35925; new key: 35910
# Round 3 switching results:
#  left partition: 46052
#  right partition: 16398
#
# Round 4:Round 4:
#  right partition(after applied F, Key:35910): 16398
#  left partition(after XOR with right, right:16398): 32684
# Initial key: 35910; new key: 35927
# Round 4 switching results:
#  left partition: 16398
#  right partition: 32684
#
# Round 5:Round 5:
#  right partition(after applied F, Key:35927): 32684
#  left partition(after XOR with right, right:32684): 46069
# Initial key: 35927; new key: 35912
# Round 5 switching results:
#  left partition: 32684
#  right partition: 46069
#
# Round 6:Round 6:
#  right partition(after applied F, Key:35912): 46069
#  left partition(after XOR with right, right:46069): 16401
# Initial key: 35912; new key: 35929
# Round 6 switching results:
#  left partition: 46069
#  right partition: 16401
#
# Round 7:Round 7:
#  right partition(after applied F, Key:35929): 16401
#  left partition(after XOR with right, right:16401): 32701
# Initial key: 35929; new key: 35914
# Round 7 switching results:
#  left partition: 16401
#  right partition: 32701
#
# Round 8:Round 8:
#  right partition(after applied F, Key:35914): 32701
#  left partition(after XOR with right, right:32701): 46054
# Initial key: 35914; new key: 35931
# Round 8 switching results:
#  left partition: 32701
#  right partition: 46054
#
# Round 9:Round 9:
#  right partition(after applied F, Key:35931): 46054
#  left partition(after XOR with right, right:46054): 16384
# Initial key: 35931; new key: 35916
# Round 9 switching results:
#  left partition: 46054
#  right partition: 16384
#
# Round 10:Round 10:
#  right partition(after applied F, Key:35916): 16384
#  left partition(after XOR with right, right:16384): 32682
# Initial key: 35916; new key: 35933
# Round 10 switching results:
#  left partition: 16384
#  right partition: 32682
#
# Round 11:Round 11:
#  right partition(after applied F, Key:35933): 32682
#  left partition(after XOR with right, right:32682): 46071
# Initial key: 35933; new key: 35918
# Round 11 switching results:
#  left partition: 32682
#  right partition: 46071
#
# Round 12:Round 12:
#  right partition(after applied F, Key:35918): 46071
#  left partition(after XOR with right, right:46071): 16403
# Initial key: 35918; new key: 35935
# Round 12 switching results:
#  left partition: 46071
#  right partition: 16403
#
# Round 13:Round 13:
#  right partition(after applied F, Key:35935): 16403
#  left partition(after XOR with right, right:16403): 32699
# Initial key: 35935; new key: 35952
# Round 13 switching results:
#  left partition: 16403
#  right partition: 32699
#
# Round 14:Round 14:
#  right partition(after applied F, Key:35952): 32699
#  left partition(after XOR with right, right:32699): 46040
# Initial key: 35952; new key: 35937
# Round 14 switching results:
#  left partition: 32699
#  right partition: 46040
#
# Round 15:Round 15:
#  right partition(after applied F, Key:35937): 46040
#  left partition(after XOR with right, right:46040): 16386
# Initial key: 35937; new key: 35954
# Round 15 switching results:
#  left partition: 46040
#  right partition: 16386
#
# Round 16:Round 16:
#  right partition(after applied F, Key:35954): 16386
#  left partition(after XOR with right, right:16386): 32680
# Initial key: 35954; new key: 35939
# Round 16 switching results:
#  left partition: 16386
#  right partition: 32680
#
# Final left partition: 32680
# Initial right partition: 16386
#
#
# Block 8:
# ylmi
#
# Initial left partition: 1732
# Initial right partition: 11627
#
# Round 1:Round 1:
#  right partition(after applied F, Key:35923): 11627
#  left partition(after XOR with right, right:11627): 43004
# Initial key: 35923; new key: 35908
# Round 1 switching results:
#  left partition: 11627
#  right partition: 43004
#
# Round 2:Round 2:
#  right partition(after applied F, Key:35908): 43004
#  left partition(after XOR with right, right:43004): 1747
# Initial key: 35908; new key: 35925
# Round 2 switching results:
#  left partition: 43004
#  right partition: 1747
#
# Round 3:Round 3:
#  right partition(after applied F, Key:35925): 1747
#  left partition(after XOR with right, right:1747): 11642
# Initial key: 35925; new key: 35910
# Round 3 switching results:
#  left partition: 1747
#  right partition: 11642
#
# Round 4:Round 4:
#  right partition(after applied F, Key:35910): 11642
#  left partition(after XOR with right, right:11642): 42991
# Initial key: 35910; new key: 35927
# Round 4 switching results:
#  left partition: 11642
#  right partition: 42991
#
# Round 5:Round 5:
#  right partition(after applied F, Key:35927): 42991
#  left partition(after XOR with right, right:42991): 1730
# Initial key: 35927; new key: 35912
# Round 5 switching results:
#  left partition: 42991
#  right partition: 1730
#
# Round 6:Round 6:
#  right partition(after applied F, Key:35912): 1730
#  left partition(after XOR with right, right:1730): 11621
# Initial key: 35912; new key: 35929
# Round 6 switching results:
#  left partition: 1730
#  right partition: 11621
#
# Round 7:Round 7:
#  right partition(after applied F, Key:35929): 11621
#  left partition(after XOR with right, right:11621): 43006
# Initial key: 35929; new key: 35914
# Round 7 switching results:
#  left partition: 11621
#  right partition: 43006
#
# Round 8:Round 8:
#  right partition(after applied F, Key:35914): 43006
#  left partition(after XOR with right, right:43006): 1745
# Initial key: 35914; new key: 35931
# Round 8 switching results:
#  left partition: 43006
#  right partition: 1745
#
# Round 9:Round 9:
#  right partition(after applied F, Key:35931): 1745
#  left partition(after XOR with right, right:1745): 11636
# Initial key: 35931; new key: 35916
# Round 9 switching results:
#  left partition: 1745
#  right partition: 11636
#
# Round 10:Round 10:
#  right partition(after applied F, Key:35916): 11636
#  left partition(after XOR with right, right:11636): 42985
# Initial key: 35916; new key: 35933
# Round 10 switching results:
#  left partition: 11636
#  right partition: 42985
#
# Round 11:Round 11:
#  right partition(after applied F, Key:35933): 42985
#  left partition(after XOR with right, right:42985): 1728
# Initial key: 35933; new key: 35918
# Round 11 switching results:
#  left partition: 42985
#  right partition: 1728
#
# Round 12:Round 12:
#  right partition(after applied F, Key:35918): 1728
#  left partition(after XOR with right, right:1728): 11623
# Initial key: 35918; new key: 35935
# Round 12 switching results:
#  left partition: 1728
#  right partition: 11623
#
# Round 13:Round 13:
#  right partition(after applied F, Key:35935): 11623
#  left partition(after XOR with right, right:11623): 43000
# Initial key: 35935; new key: 35952
# Round 13 switching results:
#  left partition: 11623
#  right partition: 43000
#
# Round 14:Round 14:
#  right partition(after applied F, Key:35952): 43000
#  left partition(after XOR with right, right:43000): 1775
# Initial key: 35952; new key: 35937
# Round 14 switching results:
#  left partition: 43000
#  right partition: 1775
#
# Round 15:Round 15:
#  right partition(after applied F, Key:35937): 1775
#  left partition(after XOR with right, right:1775): 11638
# Initial key: 35937; new key: 35954
# Round 15 switching results:
#  left partition: 1775
#  right partition: 11638
#
# Round 16:Round 16:
#  right partition(after applied F, Key:35954): 11638
#  left partition(after XOR with right, right:11638): 42987
# Initial key: 35954; new key: 35939
# Round 16 switching results:
#  left partition: 11638
#  right partition: 42987
#
# Final left partition: 42987
# Initial right partition: 11638

# %%
# decryption
decrypted_list = decrypt_cipherCBC(cipher_list, key_last_used, iv, round)
# Out:
# Initial key: 35939; new key: 35954
# Initial left partition: 63422
# Initial right partition: 15639
#
# Round 1:
#  right partition(after applied F, Key:35954): 15639
#  left partition(after XOR with right, right:15639): 18139
# Initial key: 35954; new key: 35937
# Round 1 switching results:
#  left partition: 15639
#  right partition: 18139
#
# Round 2:
#  right partition(after applied F, Key:35937): 18139
#  left partition(after XOR with right, right:18139): 63405
# Initial key: 35937; new key: 35952
# Round 2 switching results:
#  left partition: 18139
#  right partition: 63405
#
# Round 3:
#  right partition(after applied F, Key:35952): 63405
#  left partition(after XOR with right, right:63405): 15622
# Initial key: 35952; new key: 35935
# Round 3 switching results:
#  left partition: 63405
#  right partition: 15622
#
# Round 4:
#  right partition(after applied F, Key:35935): 15622
#  left partition(after XOR with right, right:15622): 18164
# Initial key: 35935; new key: 35918
# Round 4 switching results:
#  left partition: 15622
#  right partition: 18164
#
# Round 5:
#  right partition(after applied F, Key:35918): 18164
#  left partition(after XOR with right, right:18164): 63420
# Initial key: 35918; new key: 35933
# Round 5 switching results:
#  left partition: 18164
#  right partition: 63420
#
# Round 6:
#  right partition(after applied F, Key:35933): 63420
#  left partition(after XOR with right, right:63420): 15637
# Initial key: 35933; new key: 35916
# Round 6 switching results:
#  left partition: 63420
#  right partition: 15637
#
# Round 7:
#  right partition(after applied F, Key:35916): 15637
#  left partition(after XOR with right, right:15637): 18149
# Initial key: 35916; new key: 35931
# Round 7 switching results:
#  left partition: 15637
#  right partition: 18149
#
# Round 8:
#  right partition(after applied F, Key:35931): 18149
#  left partition(after XOR with right, right:18149): 63403
# Initial key: 35931; new key: 35914
# Round 8 switching results:
#  left partition: 18149
#  right partition: 63403
#
# Round 9:
#  right partition(after applied F, Key:35914): 63403
#  left partition(after XOR with right, right:63403): 15620
# Initial key: 35914; new key: 35929
# Round 9 switching results:
#  left partition: 63403
#  right partition: 15620
#
# Round 10:
#  right partition(after applied F, Key:35929): 15620
#  left partition(after XOR with right, right:15620): 18166
# Initial key: 35929; new key: 35912
# Round 10 switching results:
#  left partition: 15620
#  right partition: 18166
#
# Round 11:
#  right partition(after applied F, Key:35912): 18166
#  left partition(after XOR with right, right:18166): 63418
# Initial key: 35912; new key: 35927
# Round 11 switching results:
#  left partition: 18166
#  right partition: 63418
#
# Round 12:
#  right partition(after applied F, Key:35927): 63418
#  left partition(after XOR with right, right:63418): 15643
# Initial key: 35927; new key: 35910
# Round 12 switching results:
#  left partition: 63418
#  right partition: 15643
#
# Round 13:
#  right partition(after applied F, Key:35910): 15643
#  left partition(after XOR with right, right:15643): 18151
# Initial key: 35910; new key: 35925
# Round 13 switching results:
#  left partition: 15643
#  right partition: 18151
#
# Round 14:
#  right partition(after applied F, Key:35925): 18151
#  left partition(after XOR with right, right:18151): 63401
# Initial key: 35925; new key: 35908
# Round 14 switching results:
#  left partition: 18151
#  right partition: 63401
#
# Round 15:
#  right partition(after applied F, Key:35908): 63401
#  left partition(after XOR with right, right:63401): 15626
# Initial key: 35908; new key: 35923
# Round 15 switching results:
#  left partition: 63401
#  right partition: 15626
#
# Round 16:
#  right partition(after applied F, Key:35923): 15626
#  left partition(after XOR with right, right:15626): 18160
# Initial key: 35923; new key: 35906
# Round 16 switching results:
#  left partition: 15626
#  right partition: 18160
#
# Final left partition: 18160
# Initial right partition: 15626
#
# Initial key: 35939; new key: 35954
# Initial left partition: 24226
# Initial right partition: 19045
#
# Round 1:
#  right partition(after applied F, Key:35954): 19045
#  left partition(after XOR with right, right:19045): 39093
# Initial key: 35954; new key: 35937
# Round 1 switching results:
#  left partition: 19045
#  right partition: 39093
#
# Round 2:
#  right partition(after applied F, Key:35937): 39093
#  left partition(after XOR with right, right:39093): 24241
# Initial key: 35937; new key: 35952
# Round 2 switching results:
#  left partition: 39093
#  right partition: 24241
#
# Round 3:
#  right partition(after applied F, Key:35952): 24241
#  left partition(after XOR with right, right:24241): 19060
# Initial key: 35952; new key: 35935
# Round 3 switching results:
#  left partition: 24241
#  right partition: 19060
#
# Round 4:
#  right partition(after applied F, Key:35935): 19060
#  left partition(after XOR with right, right:19060): 39066
# Initial key: 35935; new key: 35918
# Round 4 switching results:
#  left partition: 19060
#  right partition: 39066
#
# Round 5:
#  right partition(after applied F, Key:35918): 39066
#  left partition(after XOR with right, right:39066): 24224
# Initial key: 35918; new key: 35933
# Round 5 switching results:
#  left partition: 39066
#  right partition: 24224
#
# Round 6:
#  right partition(after applied F, Key:35933): 24224
#  left partition(after XOR with right, right:24224): 19047
# Initial key: 35933; new key: 35916
# Round 6 switching results:
#  left partition: 24224
#  right partition: 19047
#
# Round 7:
#  right partition(after applied F, Key:35916): 19047
#  left partition(after XOR with right, right:19047): 39051
# Initial key: 35916; new key: 35931
# Round 7 switching results:
#  left partition: 19047
#  right partition: 39051
#
# Round 8:
#  right partition(after applied F, Key:35931): 39051
#  left partition(after XOR with right, right:39051): 24247
# Initial key: 35931; new key: 35914
# Round 8 switching results:
#  left partition: 39051
#  right partition: 24247
#
# Round 9:
#  right partition(after applied F, Key:35914): 24247
#  left partition(after XOR with right, right:24247): 19062
# Initial key: 35914; new key: 35929
# Round 9 switching results:
#  left partition: 24247
#  right partition: 19062
#
# Round 10:
#  right partition(after applied F, Key:35929): 19062
#  left partition(after XOR with right, right:19062): 39064
# Initial key: 35929; new key: 35912
# Round 10 switching results:
#  left partition: 19062
#  right partition: 39064
#
# Round 11:
#  right partition(after applied F, Key:35912): 39064
#  left partition(after XOR with right, right:39064): 24230
# Initial key: 35912; new key: 35927
# Round 11 switching results:
#  left partition: 39064
#  right partition: 24230
#
# Round 12:
#  right partition(after applied F, Key:35927): 24230
#  left partition(after XOR with right, right:24230): 19049
# Initial key: 35927; new key: 35910
# Round 12 switching results:
#  left partition: 24230
#  right partition: 19049
#
# Round 13:
#  right partition(after applied F, Key:35910): 19049
#  left partition(after XOR with right, right:19049): 39049
# Initial key: 35910; new key: 35925
# Round 13 switching results:
#  left partition: 19049
#  right partition: 39049
#
# Round 14:
#  right partition(after applied F, Key:35925): 39049
#  left partition(after XOR with right, right:39049): 24245
# Initial key: 35925; new key: 35908
# Round 14 switching results:
#  left partition: 39049
#  right partition: 24245
#
# Round 15:
#  right partition(after applied F, Key:35908): 24245
#  left partition(after XOR with right, right:24245): 19064
# Initial key: 35908; new key: 35923
# Round 15 switching results:
#  left partition: 24245
#  right partition: 19064
#
# Round 16:
#  right partition(after applied F, Key:35923): 19064
#  left partition(after XOR with right, right:19064): 39070
# Initial key: 35923; new key: 35906
# Round 16 switching results:
#  left partition: 19064
#  right partition: 39070
#
# Final left partition: 39070
# Initial right partition: 19064
#
# Initial key: 35939; new key: 35954
# Initial left partition: 36558
# Initial right partition: 11865
#
# Round 1:
#  right partition(after applied F, Key:35954): 11865
#  left partition(after XOR with right, right:11865): 11493
# Initial key: 35954; new key: 35937
# Round 1 switching results:
#  left partition: 11865
#  right partition: 11493
#
# Round 2:
#  right partition(after applied F, Key:35937): 11493
#  left partition(after XOR with right, right:11493): 36573
# Initial key: 35937; new key: 35952
# Round 2 switching results:
#  left partition: 11493
#  right partition: 36573
#
# Round 3:
#  right partition(after applied F, Key:35952): 36573
#  left partition(after XOR with right, right:36573): 11848
# Initial key: 35952; new key: 35935
# Round 3 switching results:
#  left partition: 36573
#  right partition: 11848
#
# Round 4:
#  right partition(after applied F, Key:35935): 11848
#  left partition(after XOR with right, right:11848): 11466
# Initial key: 35935; new key: 35918
# Round 4 switching results:
#  left partition: 11848
#  right partition: 11466
#
# Round 5:
#  right partition(after applied F, Key:35918): 11466
#  left partition(after XOR with right, right:11466): 36556
# Initial key: 35918; new key: 35933
# Round 5 switching results:
#  left partition: 11466
#  right partition: 36556
#
# Round 6:
#  right partition(after applied F, Key:35933): 36556
#  left partition(after XOR with right, right:36556): 11867
# Initial key: 35933; new key: 35916
# Round 6 switching results:
#  left partition: 36556
#  right partition: 11867
#
# Round 7:
#  right partition(after applied F, Key:35916): 11867
#  left partition(after XOR with right, right:11867): 11483
# Initial key: 35916; new key: 35931
# Round 7 switching results:
#  left partition: 11867
#  right partition: 11483
#
# Round 8:
#  right partition(after applied F, Key:35931): 11483
#  left partition(after XOR with right, right:11483): 36571
# Initial key: 35931; new key: 35914
# Round 8 switching results:
#  left partition: 11483
#  right partition: 36571
#
# Round 9:
#  right partition(after applied F, Key:35914): 36571
#  left partition(after XOR with right, right:36571): 11850
# Initial key: 35914; new key: 35929
# Round 9 switching results:
#  left partition: 36571
#  right partition: 11850
#
# Round 10:
#  right partition(after applied F, Key:35929): 11850
#  left partition(after XOR with right, right:11850): 11464
# Initial key: 35929; new key: 35912
# Round 10 switching results:
#  left partition: 11850
#  right partition: 11464
#
# Round 11:
#  right partition(after applied F, Key:35912): 11464
#  left partition(after XOR with right, right:11464): 36554
# Initial key: 35912; new key: 35927
# Round 11 switching results:
#  left partition: 11464
#  right partition: 36554
#
# Round 12:
#  right partition(after applied F, Key:35927): 36554
#  left partition(after XOR with right, right:36554): 11861
# Initial key: 35927; new key: 35910
# Round 12 switching results:
#  left partition: 36554
#  right partition: 11861
#
# Round 13:
#  right partition(after applied F, Key:35910): 11861
#  left partition(after XOR with right, right:11861): 11481
# Initial key: 35910; new key: 35925
# Round 13 switching results:
#  left partition: 11861
#  right partition: 11481
#
# Round 14:
#  right partition(after applied F, Key:35925): 11481
#  left partition(after XOR with right, right:11481): 36569
# Initial key: 35925; new key: 35908
# Round 14 switching results:
#  left partition: 11481
#  right partition: 36569
#
# Round 15:
#  right partition(after applied F, Key:35908): 36569
#  left partition(after XOR with right, right:36569): 11844
# Initial key: 35908; new key: 35923
# Round 15 switching results:
#  left partition: 36569
#  right partition: 11844
#
# Round 16:
#  right partition(after applied F, Key:35923): 11844
#  left partition(after XOR with right, right:11844): 11470
# Initial key: 35923; new key: 35906
# Round 16 switching results:
#  left partition: 11844
#  right partition: 11470
#
# Final left partition: 11470
# Initial right partition: 11844
#
# Initial key: 35939; new key: 35954
# Initial left partition: 25838
# Initial right partition: 17965
#
# Round 1:
#  right partition(after applied F, Key:35954): 17965
#  left partition(after XOR with right, right:17965): 44721
# Initial key: 35954; new key: 35937
# Round 1 switching results:
#  left partition: 17965
#  right partition: 44721
#
# Round 2:
#  right partition(after applied F, Key:35937): 44721
#  left partition(after XOR with right, right:44721): 25853
# Initial key: 35937; new key: 35952
# Round 2 switching results:
#  left partition: 44721
#  right partition: 25853
#
# Round 3:
#  right partition(after applied F, Key:35952): 25853
#  left partition(after XOR with right, right:25853): 17980
# Initial key: 35952; new key: 35935
# Round 3 switching results:
#  left partition: 25853
#  right partition: 17980
#
# Round 4:
#  right partition(after applied F, Key:35935): 17980
#  left partition(after XOR with right, right:17980): 44702
# Initial key: 35935; new key: 35918
# Round 4 switching results:
#  left partition: 17980
#  right partition: 44702
#
# Round 5:
#  right partition(after applied F, Key:35918): 44702
#  left partition(after XOR with right, right:44702): 25836
# Initial key: 35918; new key: 35933
# Round 5 switching results:
#  left partition: 44702
#  right partition: 25836
#
# Round 6:
#  right partition(after applied F, Key:35933): 25836
#  left partition(after XOR with right, right:25836): 17967
# Initial key: 35933; new key: 35916
# Round 6 switching results:
#  left partition: 25836
#  right partition: 17967
#
# Round 7:
#  right partition(after applied F, Key:35916): 17967
#  left partition(after XOR with right, right:17967): 44687
# Initial key: 35916; new key: 35931
# Round 7 switching results:
#  left partition: 17967
#  right partition: 44687
#
# Round 8:
#  right partition(after applied F, Key:35931): 44687
#  left partition(after XOR with right, right:44687): 25851
# Initial key: 35931; new key: 35914
# Round 8 switching results:
#  left partition: 44687
#  right partition: 25851
#
# Round 9:
#  right partition(after applied F, Key:35914): 25851
#  left partition(after XOR with right, right:25851): 17982
# Initial key: 35914; new key: 35929
# Round 9 switching results:
#  left partition: 25851
#  right partition: 17982
#
# Round 10:
#  right partition(after applied F, Key:35929): 17982
#  left partition(after XOR with right, right:17982): 44700
# Initial key: 35929; new key: 35912
# Round 10 switching results:
#  left partition: 17982
#  right partition: 44700
#
# Round 11:
#  right partition(after applied F, Key:35912): 44700
#  left partition(after XOR with right, right:44700): 25834
# Initial key: 35912; new key: 35927
# Round 11 switching results:
#  left partition: 44700
#  right partition: 25834
#
# Round 12:
#  right partition(after applied F, Key:35927): 25834
#  left partition(after XOR with right, right:25834): 17953
# Initial key: 35927; new key: 35910
# Round 12 switching results:
#  left partition: 25834
#  right partition: 17953
#
# Round 13:
#  right partition(after applied F, Key:35910): 17953
#  left partition(after XOR with right, right:17953): 44685
# Initial key: 35910; new key: 35925
# Round 13 switching results:
#  left partition: 17953
#  right partition: 44685
#
# Round 14:
#  right partition(after applied F, Key:35925): 44685
#  left partition(after XOR with right, right:44685): 25849
# Initial key: 35925; new key: 35908
# Round 14 switching results:
#  left partition: 44685
#  right partition: 25849
#
# Round 15:
#  right partition(after applied F, Key:35908): 25849
#  left partition(after XOR with right, right:25849): 17968
# Initial key: 35908; new key: 35923
# Round 15 switching results:
#  left partition: 25849
#  right partition: 17968
#
# Round 16:
#  right partition(after applied F, Key:35923): 17968
#  left partition(after XOR with right, right:17968): 44698
# Initial key: 35923; new key: 35906
# Round 16 switching results:
#  left partition: 17968
#  right partition: 44698
#
# Final left partition: 44698
# Initial right partition: 17968
#
# Initial key: 35939; new key: 35954
# Initial left partition: 46292
# Initial right partition: 12099
#
# Round 1:
#  right partition(after applied F, Key:35954): 12099
#  left partition(after XOR with right, right:12099): 6117
# Initial key: 35954; new key: 35937
# Round 1 switching results:
#  left partition: 12099
#  right partition: 6117
#
# Round 2:
#  right partition(after applied F, Key:35937): 6117
#  left partition(after XOR with right, right:6117): 46279
# Initial key: 35937; new key: 35952
# Round 2 switching results:
#  left partition: 6117
#  right partition: 46279
#
# Round 3:
#  right partition(after applied F, Key:35952): 46279
#  left partition(after XOR with right, right:46279): 12114
# Initial key: 35952; new key: 35935
# Round 3 switching results:
#  left partition: 46279
#  right partition: 12114
#
# Round 4:
#  right partition(after applied F, Key:35935): 12114
#  left partition(after XOR with right, right:12114): 6090
# Initial key: 35935; new key: 35918
# Round 4 switching results:
#  left partition: 12114
#  right partition: 6090
#
# Round 5:
#  right partition(after applied F, Key:35918): 6090
#  left partition(after XOR with right, right:6090): 46294
# Initial key: 35918; new key: 35933
# Round 5 switching results:
#  left partition: 6090
#  right partition: 46294
#
# Round 6:
#  right partition(after applied F, Key:35933): 46294
#  left partition(after XOR with right, right:46294): 12097
# Initial key: 35933; new key: 35916
# Round 6 switching results:
#  left partition: 46294
#  right partition: 12097
#
# Round 7:
#  right partition(after applied F, Key:35916): 12097
#  left partition(after XOR with right, right:12097): 6107
# Initial key: 35916; new key: 35931
# Round 7 switching results:
#  left partition: 12097
#  right partition: 6107
#
# Round 8:
#  right partition(after applied F, Key:35931): 6107
#  left partition(after XOR with right, right:6107): 46273
# Initial key: 35931; new key: 35914
# Round 8 switching results:
#  left partition: 6107
#  right partition: 46273
#
# Round 9:
#  right partition(after applied F, Key:35914): 46273
#  left partition(after XOR with right, right:46273): 12112
# Initial key: 35914; new key: 35929
# Round 9 switching results:
#  left partition: 46273
#  right partition: 12112
#
# Round 10:
#  right partition(after applied F, Key:35929): 12112
#  left partition(after XOR with right, right:12112): 6088
# Initial key: 35929; new key: 35912
# Round 10 switching results:
#  left partition: 12112
#  right partition: 6088
#
# Round 11:
#  right partition(after applied F, Key:35912): 6088
#  left partition(after XOR with right, right:6088): 46288
# Initial key: 35912; new key: 35927
# Round 11 switching results:
#  left partition: 6088
#  right partition: 46288
#
# Round 12:
#  right partition(after applied F, Key:35927): 46288
#  left partition(after XOR with right, right:46288): 12111
# Initial key: 35927; new key: 35910
# Round 12 switching results:
#  left partition: 46288
#  right partition: 12111
#
# Round 13:
#  right partition(after applied F, Key:35910): 12111
#  left partition(after XOR with right, right:12111): 6105
# Initial key: 35910; new key: 35925
# Round 13 switching results:
#  left partition: 12111
#  right partition: 6105
#
# Round 14:
#  right partition(after applied F, Key:35925): 6105
#  left partition(after XOR with right, right:6105): 46275
# Initial key: 35925; new key: 35908
# Round 14 switching results:
#  left partition: 6105
#  right partition: 46275
#
# Round 15:
#  right partition(after applied F, Key:35908): 46275
#  left partition(after XOR with right, right:46275): 12126
# Initial key: 35908; new key: 35923
# Round 15 switching results:
#  left partition: 46275
#  right partition: 12126
#
# Round 16:
#  right partition(after applied F, Key:35923): 12126
#  left partition(after XOR with right, right:12126): 6094
# Initial key: 35923; new key: 35906
# Round 16 switching results:
#  left partition: 12126
#  right partition: 6094
#
# Final left partition: 6094
# Initial right partition: 12126
#
# Initial key: 35939; new key: 35954
# Initial left partition: 22762
# Initial right partition: 16427
#
# Round 1:
#  right partition(after applied F, Key:35954): 16427
#  left partition(after XOR with right, right:16427): 38067
# Initial key: 35954; new key: 35937
# Round 1 switching results:
#  left partition: 16427
#  right partition: 38067
#
# Round 2:
#  right partition(after applied F, Key:35937): 38067
#  left partition(after XOR with right, right:38067): 22777
# Initial key: 35937; new key: 35952
# Round 2 switching results:
#  left partition: 38067
#  right partition: 22777
#
# Round 3:
#  right partition(after applied F, Key:35952): 22777
#  left partition(after XOR with right, right:22777): 16442
# Initial key: 35952; new key: 35935
# Round 3 switching results:
#  left partition: 22777
#  right partition: 16442
#
# Round 4:
#  right partition(after applied F, Key:35935): 16442
#  left partition(after XOR with right, right:16442): 38044
# Initial key: 35935; new key: 35918
# Round 4 switching results:
#  left partition: 16442
#  right partition: 38044
#
# Round 5:
#  right partition(after applied F, Key:35918): 38044
#  left partition(after XOR with right, right:38044): 22760
# Initial key: 35918; new key: 35933
# Round 5 switching results:
#  left partition: 38044
#  right partition: 22760
#
# Round 6:
#  right partition(after applied F, Key:35933): 22760
#  left partition(after XOR with right, right:22760): 16425
# Initial key: 35933; new key: 35916
# Round 6 switching results:
#  left partition: 22760
#  right partition: 16425
#
# Round 7:
#  right partition(after applied F, Key:35916): 16425
#  left partition(after XOR with right, right:16425): 38029
# Initial key: 35916; new key: 35931
# Round 7 switching results:
#  left partition: 16425
#  right partition: 38029
#
# Round 8:
#  right partition(after applied F, Key:35931): 38029
#  left partition(after XOR with right, right:38029): 22783
# Initial key: 35931; new key: 35914
# Round 8 switching results:
#  left partition: 38029
#  right partition: 22783
#
# Round 9:
#  right partition(after applied F, Key:35914): 22783
#  left partition(after XOR with right, right:22783): 16440
# Initial key: 35914; new key: 35929
# Round 9 switching results:
#  left partition: 22783
#  right partition: 16440
#
# Round 10:
#  right partition(after applied F, Key:35929): 16440
#  left partition(after XOR with right, right:16440): 38046
# Initial key: 35929; new key: 35912
# Round 10 switching results:
#  left partition: 16440
#  right partition: 38046
#
# Round 11:
#  right partition(after applied F, Key:35912): 38046
#  left partition(after XOR with right, right:38046): 22766
# Initial key: 35912; new key: 35927
# Round 11 switching results:
#  left partition: 38046
#  right partition: 22766
#
# Round 12:
#  right partition(after applied F, Key:35927): 22766
#  left partition(after XOR with right, right:22766): 16423
# Initial key: 35927; new key: 35910
# Round 12 switching results:
#  left partition: 22766
#  right partition: 16423
#
# Round 13:
#  right partition(after applied F, Key:35910): 16423
#  left partition(after XOR with right, right:16423): 38031
# Initial key: 35910; new key: 35925
# Round 13 switching results:
#  left partition: 16423
#  right partition: 38031
#
# Round 14:
#  right partition(after applied F, Key:35925): 38031
#  left partition(after XOR with right, right:38031): 22781
# Initial key: 35925; new key: 35908
# Round 14 switching results:
#  left partition: 38031
#  right partition: 22781
#
# Round 15:
#  right partition(after applied F, Key:35908): 22781
#  left partition(after XOR with right, right:22781): 16438
# Initial key: 35908; new key: 35923
# Round 15 switching results:
#  left partition: 22781
#  right partition: 16438
#
# Round 16:
#  right partition(after applied F, Key:35923): 16438
#  left partition(after XOR with right, right:16438): 38040
# Initial key: 35923; new key: 35906
# Round 16 switching results:
#  left partition: 16438
#  right partition: 38040
#
# Final left partition: 38040
# Initial right partition: 16438
#
# Initial key: 35939; new key: 35954
# Initial left partition: 56727
# Initial right partition: 24663
#
# Round 1:
#  right partition(after applied F, Key:35954): 24663
#  left partition(after XOR with right, right:24663): 12722
# Initial key: 35954; new key: 35937
# Round 1 switching results:
#  left partition: 24663
#  right partition: 12722
#
# Round 2:
#  right partition(after applied F, Key:35937): 12722
#  left partition(after XOR with right, right:12722): 56708
# Initial key: 35937; new key: 35952
# Round 2 switching results:
#  left partition: 12722
#  right partition: 56708
#
# Round 3:
#  right partition(after applied F, Key:35952): 56708
#  left partition(after XOR with right, right:56708): 24646
# Initial key: 35952; new key: 35935
# Round 3 switching results:
#  left partition: 56708
#  right partition: 24646
#
# Round 4:
#  right partition(after applied F, Key:35935): 24646
#  left partition(after XOR with right, right:24646): 12701
# Initial key: 35935; new key: 35918
# Round 4 switching results:
#  left partition: 24646
#  right partition: 12701
#
# Round 5:
#  right partition(after applied F, Key:35918): 12701
#  left partition(after XOR with right, right:12701): 56725
# Initial key: 35918; new key: 35933
# Round 5 switching results:
#  left partition: 12701
#  right partition: 56725
#
# Round 6:
#  right partition(after applied F, Key:35933): 56725
#  left partition(after XOR with right, right:56725): 24661
# Initial key: 35933; new key: 35916
# Round 6 switching results:
#  left partition: 56725
#  right partition: 24661
#
# Round 7:
#  right partition(after applied F, Key:35916): 24661
#  left partition(after XOR with right, right:24661): 12684
# Initial key: 35916; new key: 35931
# Round 7 switching results:
#  left partition: 24661
#  right partition: 12684
#
# Round 8:
#  right partition(after applied F, Key:35931): 12684
#  left partition(after XOR with right, right:12684): 56706
# Initial key: 35931; new key: 35914
# Round 8 switching results:
#  left partition: 12684
#  right partition: 56706
#
# Round 9:
#  right partition(after applied F, Key:35914): 56706
#  left partition(after XOR with right, right:56706): 24644
# Initial key: 35914; new key: 35929
# Round 9 switching results:
#  left partition: 56706
#  right partition: 24644
#
# Round 10:
#  right partition(after applied F, Key:35929): 24644
#  left partition(after XOR with right, right:24644): 12703
# Initial key: 35929; new key: 35912
# Round 10 switching results:
#  left partition: 24644
#  right partition: 12703
#
# Round 11:
#  right partition(after applied F, Key:35912): 12703
#  left partition(after XOR with right, right:12703): 56723
# Initial key: 35912; new key: 35927
# Round 11 switching results:
#  left partition: 12703
#  right partition: 56723
#
# Round 12:
#  right partition(after applied F, Key:35927): 56723
#  left partition(after XOR with right, right:56723): 24667
# Initial key: 35927; new key: 35910
# Round 12 switching results:
#  left partition: 56723
#  right partition: 24667
#
# Round 13:
#  right partition(after applied F, Key:35910): 24667
#  left partition(after XOR with right, right:24667): 12686
# Initial key: 35910; new key: 35925
# Round 13 switching results:
#  left partition: 24667
#  right partition: 12686
#
# Round 14:
#  right partition(after applied F, Key:35925): 12686
#  left partition(after XOR with right, right:12686): 56704
# Initial key: 35925; new key: 35908
# Round 14 switching results:
#  left partition: 12686
#  right partition: 56704
#
# Round 15:
#  right partition(after applied F, Key:35908): 56704
#  left partition(after XOR with right, right:56704): 24650
# Initial key: 35908; new key: 35923
# Round 15 switching results:
#  left partition: 56704
#  right partition: 24650
#
# Round 16:
#  right partition(after applied F, Key:35923): 24650
#  left partition(after XOR with right, right:24650): 12697
# Initial key: 35923; new key: 35906
# Round 16 switching results:
#  left partition: 24650
#  right partition: 12697
#
# Final left partition: 12697
# Initial right partition: 24650
#
# Initial key: 35939; new key: 35954
# Initial left partition: 32680
# Initial right partition: 16386
#
# Round 1:
#  right partition(after applied F, Key:35954): 16386
#  left partition(after XOR with right, right:16386): 46040
# Initial key: 35954; new key: 35937
# Round 1 switching results:
#  left partition: 16386
#  right partition: 46040
#
# Round 2:
#  right partition(after applied F, Key:35937): 46040
#  left partition(after XOR with right, right:46040): 32699
# Initial key: 35937; new key: 35952
# Round 2 switching results:
#  left partition: 46040
#  right partition: 32699
#
# Round 3:
#  right partition(after applied F, Key:35952): 32699
#  left partition(after XOR with right, right:32699): 16403
# Initial key: 35952; new key: 35935
# Round 3 switching results:
#  left partition: 32699
#  right partition: 16403
#
# Round 4:
#  right partition(after applied F, Key:35935): 16403
#  left partition(after XOR with right, right:16403): 46071
# Initial key: 35935; new key: 35918
# Round 4 switching results:
#  left partition: 16403
#  right partition: 46071
#
# Round 5:
#  right partition(after applied F, Key:35918): 46071
#  left partition(after XOR with right, right:46071): 32682
# Initial key: 35918; new key: 35933
# Round 5 switching results:
#  left partition: 46071
#  right partition: 32682
#
# Round 6:
#  right partition(after applied F, Key:35933): 32682
#  left partition(after XOR with right, right:32682): 16384
# Initial key: 35933; new key: 35916
# Round 6 switching results:
#  left partition: 32682
#  right partition: 16384
#
# Round 7:
#  right partition(after applied F, Key:35916): 16384
#  left partition(after XOR with right, right:16384): 46054
# Initial key: 35916; new key: 35931
# Round 7 switching results:
#  left partition: 16384
#  right partition: 46054
#
# Round 8:
#  right partition(after applied F, Key:35931): 46054
#  left partition(after XOR with right, right:46054): 32701
# Initial key: 35931; new key: 35914
# Round 8 switching results:
#  left partition: 46054
#  right partition: 32701
#
# Round 9:
#  right partition(after applied F, Key:35914): 32701
#  left partition(after XOR with right, right:32701): 16401
# Initial key: 35914; new key: 35929
# Round 9 switching results:
#  left partition: 32701
#  right partition: 16401
#
# Round 10:
#  right partition(after applied F, Key:35929): 16401
#  left partition(after XOR with right, right:16401): 46069
# Initial key: 35929; new key: 35912
# Round 10 switching results:
#  left partition: 16401
#  right partition: 46069
#
# Round 11:
#  right partition(after applied F, Key:35912): 46069
#  left partition(after XOR with right, right:46069): 32684
# Initial key: 35912; new key: 35927
# Round 11 switching results:
#  left partition: 46069
#  right partition: 32684
#
# Round 12:
#  right partition(after applied F, Key:35927): 32684
#  left partition(after XOR with right, right:32684): 16398
# Initial key: 35927; new key: 35910
# Round 12 switching results:
#  left partition: 32684
#  right partition: 16398
#
# Round 13:
#  right partition(after applied F, Key:35910): 16398
#  left partition(after XOR with right, right:16398): 46052
# Initial key: 35910; new key: 35925
# Round 13 switching results:
#  left partition: 16398
#  right partition: 46052
#
# Round 14:
#  right partition(after applied F, Key:35925): 46052
#  left partition(after XOR with right, right:46052): 32703
# Initial key: 35925; new key: 35908
# Round 14 switching results:
#  left partition: 46052
#  right partition: 32703
#
# Round 15:
#  right partition(after applied F, Key:35908): 32703
#  left partition(after XOR with right, right:32703): 16415
# Initial key: 35908; new key: 35923
# Round 15 switching results:
#  left partition: 32703
#  right partition: 16415
#
# Round 16:
#  right partition(after applied F, Key:35923): 16415
#  left partition(after XOR with right, right:16415): 46067
# Initial key: 35923; new key: 35906
# Round 16 switching results:
#  left partition: 16415
#  right partition: 46067
#
# Final left partition: 46067
# Initial right partition: 16415
#
# Initial key: 35939; new key: 35954
# Initial left partition: 42987
# Initial right partition: 11638
#
# Round 1:
#  right partition(after applied F, Key:35954): 11638
#  left partition(after XOR with right, right:11638): 1775
# Initial key: 35954; new key: 35937
# Round 1 switching results:
#  left partition: 11638
#  right partition: 1775
#
# Round 2:
#  right partition(after applied F, Key:35937): 1775
#  left partition(after XOR with right, right:1775): 43000
# Initial key: 35937; new key: 35952
# Round 2 switching results:
#  left partition: 1775
#  right partition: 43000
#
# Round 3:
#  right partition(after applied F, Key:35952): 43000
#  left partition(after XOR with right, right:43000): 11623
# Initial key: 35952; new key: 35935
# Round 3 switching results:
#  left partition: 43000
#  right partition: 11623
#
# Round 4:
#  right partition(after applied F, Key:35935): 11623
#  left partition(after XOR with right, right:11623): 1728
# Initial key: 35935; new key: 35918
# Round 4 switching results:
#  left partition: 11623
#  right partition: 1728
#
# Round 5:
#  right partition(after applied F, Key:35918): 1728
#  left partition(after XOR with right, right:1728): 42985
# Initial key: 35918; new key: 35933
# Round 5 switching results:
#  left partition: 1728
#  right partition: 42985
#
# Round 6:
#  right partition(after applied F, Key:35933): 42985
#  left partition(after XOR with right, right:42985): 11636
# Initial key: 35933; new key: 35916
# Round 6 switching results:
#  left partition: 42985
#  right partition: 11636
#
# Round 7:
#  right partition(after applied F, Key:35916): 11636
#  left partition(after XOR with right, right:11636): 1745
# Initial key: 35916; new key: 35931
# Round 7 switching results:
#  left partition: 11636
#  right partition: 1745
#
# Round 8:
#  right partition(after applied F, Key:35931): 1745
#  left partition(after XOR with right, right:1745): 43006
# Initial key: 35931; new key: 35914
# Round 8 switching results:
#  left partition: 1745
#  right partition: 43006
#
# Round 9:
#  right partition(after applied F, Key:35914): 43006
#  left partition(after XOR with right, right:43006): 11621
# Initial key: 35914; new key: 35929
# Round 9 switching results:
#  left partition: 43006
#  right partition: 11621
#
# Round 10:
#  right partition(after applied F, Key:35929): 11621
#  left partition(after XOR with right, right:11621): 1730
# Initial key: 35929; new key: 35912
# Round 10 switching results:
#  left partition: 11621
#  right partition: 1730
#
# Round 11:
#  right partition(after applied F, Key:35912): 1730
#  left partition(after XOR with right, right:1730): 42991
# Initial key: 35912; new key: 35927
# Round 11 switching results:
#  left partition: 1730
#  right partition: 42991
#
# Round 12:
#  right partition(after applied F, Key:35927): 42991
#  left partition(after XOR with right, right:42991): 11642
# Initial key: 35927; new key: 35910
# Round 12 switching results:
#  left partition: 42991
#  right partition: 11642
#
# Round 13:
#  right partition(after applied F, Key:35910): 11642
#  left partition(after XOR with right, right:11642): 1747
# Initial key: 35910; new key: 35925
# Round 13 switching results:
#  left partition: 11642
#  right partition: 1747
#
# Round 14:
#  right partition(after applied F, Key:35925): 1747
#  left partition(after XOR with right, right:1747): 43004
# Initial key: 35925; new key: 35908
# Round 14 switching results:
#  left partition: 1747
#  right partition: 43004
#
# Round 15:
#  right partition(after applied F, Key:35908): 43004
#  left partition(after XOR with right, right:43004): 11627
# Initial key: 35908; new key: 35923
# Round 15 switching results:
#  left partition: 43004
#  right partition: 11627
#
# Round 16:
#  right partition(after applied F, Key:35923): 11627
#  left partition(after XOR with right, right:11627): 1732
# Initial key: 35923; new key: 35906
# Round 16 switching results:
#  left partition: 11627
#  right partition: 1732
#
# Final left partition: 1732
# Initial right partition: 11627

# %% [markdown]
# ### Results

# %%
# plaintext
for i in blockList:
    print ([(i[k]) for k in range(len(i))])
# Out:
# ['H', 'e', 'l', 'l']
# ['o', ' ', 'w', 'o']
# ['r', 'l', 'd', '!']
# [' ', 'T', 'h', 'i']
# ['s', ' ', 'i', 's']
# [' ', 'L', 'o', 'u']
# ['i', 's', ' ', 'a']
# ['n', 'd', ' ', 'H']
# ['y', 'l', 'm', 'i']

# %%
# ciphertext
for i in cipher_list:
    print ([chr(i[k]) for k in range(len(i))])
a = [chr(i[k]) for k in range(len(i))]
# Out:
# ['÷', '¾', '=', '\x17']
# ['^', '¢', 'J', 'e']
# ['\x8e', 'Î', '.', 'Y']
# ['d', 'î', 'F', '-']
# ['´', 'Ô', '/', 'C']
# ['X', 'ê', '@', '+']
# ['Ý', '\x97', '`', 'W']
# ['\x7f', '¨', '@', '\x02']
# ['§', 'ë', '-', 'v']

# %%
# plaintext
for i in decrypted_list:
    print ([(i[k]) for k in range(len(i))])
# Out:
# ['H', 'e', 'l', 'l']
# ['o', ' ', 'w', 'o']
# ['r', 'l', 'd', '!']
# [' ', 'T', 'h', 'i']
# ['s', ' ', 'i', 's']
# [' ', 'L', 'o', 'u']
# ['i', 's', ' ', 'a']
# ['n', 'd', ' ', 'H']
# ['y', 'l', 'm', 'i']

# %% [markdown]
# © 2024 - Fathi Al Adha Hylmi & Louis Widi Anandaputra
