# %% [markdown]
# # Cryptography and Information Security
# ## Symmetric Block Cipher assignment
#
# - Fathi Al Adha Hylmi (22/492195/PA/21008)
# - Louis Widi Anandaputra(22/492218/PA/21090)
#
# We well be constructing a symmetric block cipher for a text message. This method would also work with other data, but we will be implementing it on encrypting strings using the CBC structure (for more than 1 block data) in a feistel structure which uses a finite field arithmetic (addition operation) for a Galois Field(GF).
#
# 1 block wold contain 2^32 data and the finite field arithmetic would use a GF(2^16). The feistel structure rounds can be set as a parameter but we will be using a 16 rounds feistel structure. We also define several functions:
#
# - initialGenKey(length) --> intializing keys for both the key and initial vector (IV). Taking an integer parameter length (bytes)
# - subGenKey(key) --> creating subkeys for the feistel cipher encryption process. Taking an integer parameter (key)
# - reverseSubGenKey(last_key) --> reversing back the subkeys to the original key. Taking an integer parameter (last_key)
# - GFaddition(plain, key) --> Finite Field addition on GF(2^16). Taking integer parameters (plain) and (key)
# <br><br>
# - encrypt_messageCBC(blockList, key, iv, len_of_block, round) --> CBC structure encryption for all blocks. Taking string array parameter (blockList), bytearray parameters (key) and (iv), and integer parameters (len_of_block) and (round)
# - encrypt(plain_block, key) --> initial encryption with IV. Taking string parameter (plain_block) and bytearray parameter (key)
# - feistelEncrypt(plain, key, round) --> feistel structure block encryption. Taking bytearray parameter (plain) and (key), and taking integer parameter (round)
# <br><br>
# - decrypt_cipherCBC(list_cipher, key, iv, round) --> CBC structure decryption for all blocks. Taking bytearray parameters (list_cipher) and (iv), and taking integer parameters (key, round)
# - feistelDecrypt(cipher, key_int, round) --> feistel structure block decryption. Taking bytearray parameter (list) and integer parameters (key_int) and (round)
# - decrypt(cipher, key) --> decryption with IV
# <br><br>
# - breakMessage(message, len_of_blocks) --> breaking data into blocks. Taking string parameter (message) and taking integer parameters (len_of_blocks)
#
# ### reference for code: https://www.youtube.com/watch?v=wwTsRONdAaw
# <br><br>
# <img src = 'https://ctf-wiki.mahaloz.re/crypto/blockcipher/mode/figure/cbc_encryption.png'> <img src = 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Feistel_cipher_diagram_en.svg/300px-Feistel_cipher_diagram_en.svg.png'>
#
# ## Hashing and HMAC
# We will be using

# %% [markdown]
# ## Keys and Finite Field Arithmetic

# %%
from os import urandom

# Initial key generator
def initialGenKey(length):
    return bytearray(urandom(length))
    
def subGenKey(key):
    # perform an addition by 1 and XOR by 1 and 0
    value = (key + 1) ^ 0x10
    # reset the value to 0 if it exceeds the maximum limit
    shifted_key = value & ((1 << 16) - 1)  # 16 bit limit
    print(f"Initial key: {key}; new key: {shifted_key}")
    return shifted_key
    
def reverseSubGenKey(last_key):
    # perform the inverse XOR operation to recover the value before XOR
    value = (last_key ^ 0x10)-1
    # reset the value to 0 if it exceeds the maximum limit
    key = value & ((1 << 16) - 1)# 16 bit limit
    print(f"Initial key: {last_key}; new key: {key}")
    return key
    
# we will be using a 2^16 finite field addition operation, which will be using XOR operation
def GFaddition(plain, key):
    value = plain ^ key
    value = value & ((1 << 16) - 1)
    return value

# %% [markdown]
# ## Encryption

# %%
def encrypt_messageCBC(blockList, key, iv, len_of_block, round):
    list_of_ciphers = []
    for i in range(len(blockList)):
        print (f"\nBlock {i}:\n{blockList[i]}\n")
        # performing initial encryption with initial vector
        cipher1 = encrypt(blockList[i], iv)
        # performing the feistel cipher encryption
        cipher2, key_last = feistelEncrypt(cipher1, key, round)
        list_of_ciphers.append(cipher2)
        iv = cipher2
    return list_of_ciphers, key_last

# %%
def encrypt(plain_block, key):
    return bytearray([ord(plain_block[i]) ^ key[i] for i in range(len(plain_block))])

# %%
def feistelEncrypt(plain, key, round):
    # Changing key and plaintext into integers for encryption process
    key_int = int.from_bytes(key, byteorder='big')
    plain = int.from_bytes(plain, byteorder='big')

    # Splitting the bits to half (16 - 16)
    left = plain >> 16
    right = plain & 0xffff
    print(f"Initial left partition: {left}\nInitial right partition: {right}\n")

    # feistel structure
    for k in range ( round):  #rounds
        temp = GFaddition(right, key_int) # Using the Galois Field encryption
        left = left ^ temp
        print(f"Round {k+1}:Round {k+1}:\n right partition(after applied F, Key:{key_int}): {right}\n left partition(after XOR with right, right:{right}): {left}")

        # generating new subkey
        key_int = subGenKey(key_int)

        #switching the left and right data
        temp = right
        right = left
        left = temp
        print(f"Round {k+1} switching results:\n left partition: {left}\n right partition: {right}\n")

    # final switch for the left and right data   
    temp = right
    right = left
    left = temp    
    print(f"Final left partition: {left}\nInitial right partition: {right}\n")
    
    key = key_int
    # making sure the length is still 2^16
    encrypted_block = (left <<16)|right
    # changing back into bytes
    encrypted_block = encrypted_block.to_bytes((encrypted_block.bit_length() + 7) // 8, byteorder='big')
    return encrypted_block, key

# %% [markdown]
# ## Decryption

# %%
def decrypt_cipherCBC(list_cipher, key, iv, round):
    list_of_decrypted_blocks = []
    temp, key_last = feistelDecrypt(list_cipher[0], key, round)
    plain = decrypt(temp, iv)
    list_of_decrypted_blocks.append(plain)
    for i in range(1, len(list_cipher)):
        temp, key_last = feistelDecrypt(list_cipher[i], key, round)
        plain = decrypt(temp, list_cipher[i-1])
        list_of_decrypted_blocks.append(plain)
    return list_of_decrypted_blocks

# %%
def feistelDecrypt(cipher, key_int, round):
    cipher = int.from_bytes(cipher, byteorder='big')
    key_int = reverseSubGenKey(key_int)
    left = cipher >> 16
    right = cipher & 0xffff
    print(f"Initial left partition: {left}\nInitial right partition: {right}\n")
  
    for k in range (round):  #rounds
        temp = GFaddition(right, key_int)
        left = left ^ temp
        
        
        print(f"Round {k+1}:\n right partition(after applied F, Key:{key_int}): {right}\n left partition(after XOR with right, right:{right}): {left}")
        
        key_int = reverseSubGenKey(key_int)
        
        temp = right
        right = left
        left = temp
        print(f"Round {k+1} switching results:\n left partition: {left}\n right partition: {right}\n")

    temp = right
    right = left
    left = temp
    print(f"Final left partition: {left}\nInitial right partition: {right}\n")
    
    key = key_int
    decrypted_block = (left <<16)|right
    decrypted_block = decrypted_block.to_bytes((decrypted_block.bit_length() + 7) // 8, byteorder='big')
    return decrypted_block, key

# %%
def decrypt(cipher, key):
    return [chr(cipher[i] ^ key[i]) for i in range(len(cipher))]

# %% [markdown]
# ## Block Creation

# %%
def breakMessage(message, len_of_blocks):
    list_of_blocks = []
    for i in range (0, len(message), len_of_blocks):
        block = message[i:i+len_of_block]
        if(len(block) == len_of_blocks):
            list_of_blocks.append(block)
        else:
            c = len_of_blocks - len(block)
            for i in range(c):
                block = block + " "
            list_of_blocks.append(block)
    return list_of_blocks

def breakMessage_hash(message, len_of_blocks):
    if isinstance(message, str):
        message = message.encode()
    list_of_blocks = []
    for i in range(0, len(message), len_of_blocks):
        block = message[i:i + len_of_blocks]
        if len(block) == len_of_blocks:
            list_of_blocks.append(block)
        else:
            c = len_of_blocks - len(block)
            block += b' ' * c
            list_of_blocks.append(block)
    return list_of_blocks

# %% [markdown]
# ## Hash and Message Authentication

# %%
def bitwise_rotate_left(val, r_bits, max_bits): 
    """
    val : value to be rotated
    r_bits = number of rotation step
    max_bits = maximum bit rotations
    """
    return (val << r_bits%max_bits) & (2**max_bits-1) | ((val & (2**max_bits-1)) >> (max_bits-(r_bits%max_bits)))

def hashFunction(message, len_of_block, key, iv, hmac_outer = False):
    """
    message : plaintext (string if not for outer hash in hmac, block array for outer hash in hmac)
    len_of_block: n bytes of block length
    key : key for XOR with Initial Value
    IV: Initial Value for XOR with key
    """
    blockList = message
    if hmac_outer == False:
        blockList = breakMessage_hash(message, len_of_block)
        blockList = [int.from_bytes(i, byteorder = 'big') for i in blockList]
    
    # Start of Rotated XOR
    block = iv^key
    for m in blockList:
        
        temp = bitwise_rotate_left(block, 1, (8*(len_of_block)))
        block = m ^ temp 
    
    return block

def HMAC(message, key, len_of_block, iv):
    """
    message : plaintext (string if not for outer hash in hmac, block array for outer hash in hmac)
    len_of_block: n bytes of block length
    key : key for operation with outer and inner padding in hash function
    IV: Initial Value for XOR with key in hash function
    """
    key = int.from_bytes(key, byteorder = 'big')
    iv = int.from_bytes(iv, byteorder = 'big')

        
    o_key_pad = key ^ 0x5C
    i_key_pad = key ^ 0x36

    inner_hash = hashFunction(message, len_of_block, i_key_pad, iv) # NOTE for testing, make the hmac_outer = True
    print("inner_hash:",bin(inner_hash))
    inner_hash = [inner_hash]
    hmac_output = hashFunction(inner_hash, len_of_block, o_key_pad, iv, hmac_outer = True)

    return hmac_output

# %% [markdown]
# ## Demo

# %%
# Initialization
text = "Hello world! This is Louis and Hylmi."
len_of_block = 4
len_of_feistel = 2
len_of_block_hmac = 2
round = 16
blockList = breakMessage(text, len_of_block)

# %%
key = initialGenKey(len_of_feistel)
iv = initialGenKey(len_of_block)

key_hmac = initialGenKey(len_of_block_hmac)
iv_hmac = initialGenKey(len_of_block_hmac)

# %%
print(f"Key: {key}\nIV: {iv}\nKey HMAC: {key_hmac}\nIV HMAC: {iv_hmac}")
# Out:
# Key: bytearray(b'1n')
# IV: bytearray(b'\xf5\x14\x0c\x1b')
# Key HMAC: bytearray(b'\xd8J')
# IV HMAC: bytearray(b'\xd3r')

# %%
key = bytearray(b'1n')
iv =  bytearray(b'\xf5\x14\x0c\x1b')
key_hmac = bytearray(b'\xd8J')
iv_hmac = bytearray(b'\xd3r')

# %%
# %%time
# encryption
cipher_list, key_last_used= encrypt_messageCBC(blockList, key, iv, len_of_block, round = round)
# Out:
# Block 0:
# Hell
#
# Initial left partition: 48497
# Initial right partition: 24695
#
# Round 1:Round 1:
#  right partition(after applied F, Key:12654): 24695
#  left partition(after XOR with right, right:24695): 60520
# Initial key: 12654; new key: 12671
# Round 1 switching results:
#  left partition: 24695
#  right partition: 60520
#
# Round 2:Round 2:
#  right partition(after applied F, Key:12671): 60520
#  left partition(after XOR with right, right:60520): 48480
# Initial key: 12671; new key: 12688
# Round 2 switching results:
#  left partition: 60520
#  right partition: 48480
#
# Round 3:Round 3:
#  right partition(after applied F, Key:12688): 48480
#  left partition(after XOR with right, right:48480): 24728
# Initial key: 12688; new key: 12673
# Round 3 switching results:
#  left partition: 48480
#  right partition: 24728
#
# Round 4:Round 4:
#  right partition(after applied F, Key:12673): 24728
#  left partition(after XOR with right, right:24728): 60537
# Initial key: 12673; new key: 12690
# Round 4 switching results:
#  left partition: 24728
#  right partition: 60537
#
# Round 5:Round 5:
#  right partition(after applied F, Key:12690): 60537
#  left partition(after XOR with right, right:60537): 48499
# Initial key: 12690; new key: 12675
# Round 5 switching results:
#  left partition: 60537
#  right partition: 48499
#
# Round 6:Round 6:
#  right partition(after applied F, Key:12675): 48499
#  left partition(after XOR with right, right:48499): 24713
# Initial key: 12675; new key: 12692
# Round 6 switching results:
#  left partition: 48499
#  right partition: 24713
#
# Round 7:Round 7:
#  right partition(after applied F, Key:12692): 24713
#  left partition(after XOR with right, right:24713): 60526
# Initial key: 12692; new key: 12677
# Round 7 switching results:
#  left partition: 24713
#  right partition: 60526
#
# Round 8:Round 8:
#  right partition(after applied F, Key:12677): 60526
#  left partition(after XOR with right, right:60526): 48482
# Initial key: 12677; new key: 12694
# Round 8 switching results:
#  left partition: 60526
#  right partition: 48482
#
# Round 9:Round 9:
#  right partition(after applied F, Key:12694): 48482
#  left partition(after XOR with right, right:48482): 24730
# Initial key: 12694; new key: 12679
# Round 9 switching results:
#  left partition: 48482
#  right partition: 24730
#
# Round 10:Round 10:
#  right partition(after applied F, Key:12679): 24730
#  left partition(after XOR with right, right:24730): 60543
# Initial key: 12679; new key: 12696
# Round 10 switching results:
#  left partition: 24730
#  right partition: 60543
#
# Round 11:Round 11:
#  right partition(after applied F, Key:12696): 60543
#  left partition(after XOR with right, right:60543): 48509
# Initial key: 12696; new key: 12681
# Round 11 switching results:
#  left partition: 60543
#  right partition: 48509
#
# Round 12:Round 12:
#  right partition(after applied F, Key:12681): 48509
#  left partition(after XOR with right, right:48509): 24715
# Initial key: 12681; new key: 12698
# Round 12 switching results:
#  left partition: 48509
#  right partition: 24715
#
# Round 13:Round 13:
#  right partition(after applied F, Key:12698): 24715
#  left partition(after XOR with right, right:24715): 60524
# Initial key: 12698; new key: 12683
# Round 13 switching results:
#  left partition: 24715
#  right partition: 60524
#
# Round 14:Round 14:
#  right partition(after applied F, Key:12683): 60524
#  left partition(after XOR with right, right:60524): 48492
# Initial key: 12683; new key: 12700
# Round 14 switching results:
#  left partition: 60524
#  right partition: 48492
#
# Round 15:Round 15:
#  right partition(after applied F, Key:12700): 48492
#  left partition(after XOR with right, right:48492): 24732
# Initial key: 12700; new key: 12685
# Round 15 switching results:
#  left partition: 48492
#  right partition: 24732
#
# Round 16:Round 16:
#  right partition(after applied F, Key:12685): 24732
#  left partition(after XOR with right, right:24732): 60541
# Initial key: 12685; new key: 12702
# Round 16 switching results:
#  left partition: 24732
#  right partition: 60541
#
# Final left partition: 60541
# Initial right partition: 24732
#
#
# Block 1:
# o wo
#
# Initial left partition: 33629
# Initial right partition: 6131
#
# Round 1:Round 1:
#  right partition(after applied F, Key:12654): 6131
#  left partition(after XOR with right, right:6131): 42432
# Initial key: 12654; new key: 12671
# Round 1 switching results:
#  left partition: 6131
#  right partition: 42432
#
# Round 2:Round 2:
#  right partition(after applied F, Key:12671): 42432
#  left partition(after XOR with right, right:42432): 33612
# Initial key: 12671; new key: 12688
# Round 2 switching results:
#  left partition: 42432
#  right partition: 33612
#
# Round 3:Round 3:
#  right partition(after applied F, Key:12688): 33612
#  left partition(after XOR with right, right:33612): 5916
# Initial key: 12688; new key: 12673
# Round 3 switching results:
#  left partition: 33612
#  right partition: 5916
#
# Round 4:Round 4:
#  right partition(after applied F, Key:12673): 5916
#  left partition(after XOR with right, right:5916): 42449
# Initial key: 12673; new key: 12690
# Round 4 switching results:
#  left partition: 5916
#  right partition: 42449
#
# Round 5:Round 5:
#  right partition(after applied F, Key:12690): 42449
#  left partition(after XOR with right, right:42449): 33631
# Initial key: 12690; new key: 12675
# Round 5 switching results:
#  left partition: 42449
#  right partition: 33631
#
# Round 6:Round 6:
#  right partition(after applied F, Key:12675): 33631
#  left partition(after XOR with right, right:33631): 5901
# Initial key: 12675; new key: 12692
# Round 6 switching results:
#  left partition: 33631
#  right partition: 5901
#
# Round 7:Round 7:
#  right partition(after applied F, Key:12692): 5901
#  left partition(after XOR with right, right:5901): 42438
# Initial key: 12692; new key: 12677
# Round 7 switching results:
#  left partition: 5901
#  right partition: 42438
#
# Round 8:Round 8:
#  right partition(after applied F, Key:12677): 42438
#  left partition(after XOR with right, right:42438): 33614
# Initial key: 12677; new key: 12694
# Round 8 switching results:
#  left partition: 42438
#  right partition: 33614
#
# Round 9:Round 9:
#  right partition(after applied F, Key:12694): 33614
#  left partition(after XOR with right, right:33614): 5918
# Initial key: 12694; new key: 12679
# Round 9 switching results:
#  left partition: 33614
#  right partition: 5918
#
# Round 10:Round 10:
#  right partition(after applied F, Key:12679): 5918
#  left partition(after XOR with right, right:5918): 42455
# Initial key: 12679; new key: 12696
# Round 10 switching results:
#  left partition: 5918
#  right partition: 42455
#
# Round 11:Round 11:
#  right partition(after applied F, Key:12696): 42455
#  left partition(after XOR with right, right:42455): 33617
# Initial key: 12696; new key: 12681
# Round 11 switching results:
#  left partition: 42455
#  right partition: 33617
#
# Round 12:Round 12:
#  right partition(after applied F, Key:12681): 33617
#  left partition(after XOR with right, right:33617): 5903
# Initial key: 12681; new key: 12698
# Round 12 switching results:
#  left partition: 33617
#  right partition: 5903
#
# Round 13:Round 13:
#  right partition(after applied F, Key:12698): 5903
#  left partition(after XOR with right, right:5903): 42436
# Initial key: 12698; new key: 12683
# Round 13 switching results:
#  left partition: 5903
#  right partition: 42436
#
# Round 14:Round 14:
#  right partition(after applied F, Key:12683): 42436
#  left partition(after XOR with right, right:42436): 33600
# Initial key: 12683; new key: 12700
# Round 14 switching results:
#  left partition: 42436
#  right partition: 33600
#
# Round 15:Round 15:
#  right partition(after applied F, Key:12700): 33600
#  left partition(after XOR with right, right:33600): 5912
# Initial key: 12700; new key: 12685
# Round 15 switching results:
#  left partition: 33600
#  right partition: 5912
#
# Round 16:Round 16:
#  right partition(after applied F, Key:12685): 5912
#  left partition(after XOR with right, right:5912): 42453
# Initial key: 12685; new key: 12702
# Round 16 switching results:
#  left partition: 5912
#  right partition: 42453
#
# Final left partition: 42453
# Initial right partition: 5912
#
#
# Block 2:
# rld!
#
# Initial left partition: 55225
# Initial right partition: 29497
#
# Round 1:Round 1:
#  right partition(after applied F, Key:12654): 29497
#  left partition(after XOR with right, right:29497): 38382
# Initial key: 12654; new key: 12671
# Round 1 switching results:
#  left partition: 29497
#  right partition: 38382
#
# Round 2:Round 2:
#  right partition(after applied F, Key:12671): 38382
#  left partition(after XOR with right, right:38382): 55208
# Initial key: 12671; new key: 12688
# Round 2 switching results:
#  left partition: 38382
#  right partition: 55208
#
# Round 3:Round 3:
#  right partition(after applied F, Key:12688): 55208
#  left partition(after XOR with right, right:55208): 29654
# Initial key: 12688; new key: 12673
# Round 3 switching results:
#  left partition: 55208
#  right partition: 29654
#
# Round 4:Round 4:
#  right partition(after applied F, Key:12673): 29654
#  left partition(after XOR with right, right:29654): 38399
# Initial key: 12673; new key: 12690
# Round 4 switching results:
#  left partition: 29654
#  right partition: 38399
#
# Round 5:Round 5:
#  right partition(after applied F, Key:12690): 38399
#  left partition(after XOR with right, right:38399): 55227
# Initial key: 12690; new key: 12675
# Round 5 switching results:
#  left partition: 38399
#  right partition: 55227
#
# Round 6:Round 6:
#  right partition(after applied F, Key:12675): 55227
#  left partition(after XOR with right, right:55227): 29639
# Initial key: 12675; new key: 12692
# Round 6 switching results:
#  left partition: 55227
#  right partition: 29639
#
# Round 7:Round 7:
#  right partition(after applied F, Key:12692): 29639
#  left partition(after XOR with right, right:29639): 38376
# Initial key: 12692; new key: 12677
# Round 7 switching results:
#  left partition: 29639
#  right partition: 38376
#
# Round 8:Round 8:
#  right partition(after applied F, Key:12677): 38376
#  left partition(after XOR with right, right:38376): 55210
# Initial key: 12677; new key: 12694
# Round 8 switching results:
#  left partition: 38376
#  right partition: 55210
#
# Round 9:Round 9:
#  right partition(after applied F, Key:12694): 55210
#  left partition(after XOR with right, right:55210): 29652
# Initial key: 12694; new key: 12679
# Round 9 switching results:
#  left partition: 55210
#  right partition: 29652
#
# Round 10:Round 10:
#  right partition(after applied F, Key:12679): 29652
#  left partition(after XOR with right, right:29652): 38393
# Initial key: 12679; new key: 12696
# Round 10 switching results:
#  left partition: 29652
#  right partition: 38393
#
# Round 11:Round 11:
#  right partition(after applied F, Key:12696): 38393
#  left partition(after XOR with right, right:38393): 55221
# Initial key: 12696; new key: 12681
# Round 11 switching results:
#  left partition: 38393
#  right partition: 55221
#
# Round 12:Round 12:
#  right partition(after applied F, Key:12681): 55221
#  left partition(after XOR with right, right:55221): 29637
# Initial key: 12681; new key: 12698
# Round 12 switching results:
#  left partition: 55221
#  right partition: 29637
#
# Round 13:Round 13:
#  right partition(after applied F, Key:12698): 29637
#  left partition(after XOR with right, right:29637): 38378
# Initial key: 12698; new key: 12683
# Round 13 switching results:
#  left partition: 29637
#  right partition: 38378
#
# Round 14:Round 14:
#  right partition(after applied F, Key:12683): 38378
#  left partition(after XOR with right, right:38378): 55204
# Initial key: 12683; new key: 12700
# Round 14 switching results:
#  left partition: 38378
#  right partition: 55204
#
# Round 15:Round 15:
#  right partition(after applied F, Key:12700): 55204
#  left partition(after XOR with right, right:55204): 29650
# Initial key: 12700; new key: 12685
# Round 15 switching results:
#  left partition: 55204
#  right partition: 29650
#
# Round 16:Round 16:
#  right partition(after applied F, Key:12685): 29650
#  left partition(after XOR with right, right:29650): 38395
# Initial key: 12685; new key: 12702
# Round 16 switching results:
#  left partition: 29650
#  right partition: 38395
#
# Final left partition: 38395
# Initial right partition: 29650
#
#
# Block 3:
#  Thi
#
# Initial left partition: 46511
# Initial right partition: 7099
#
# Round 1:Round 1:
#  right partition(after applied F, Key:12654): 7099
#  left partition(after XOR with right, right:7099): 40826
# Initial key: 12654; new key: 12671
# Round 1 switching results:
#  left partition: 7099
#  right partition: 40826
#
# Round 2:Round 2:
#  right partition(after applied F, Key:12671): 40826
#  left partition(after XOR with right, right:40826): 46526
# Initial key: 12671; new key: 12688
# Round 2 switching results:
#  left partition: 40826
#  right partition: 46526
#
# Round 3:Round 3:
#  right partition(after applied F, Key:12688): 46526
#  left partition(after XOR with right, right:46526): 6996
# Initial key: 12688; new key: 12673
# Round 3 switching results:
#  left partition: 46526
#  right partition: 6996
#
# Round 4:Round 4:
#  right partition(after applied F, Key:12673): 6996
#  left partition(after XOR with right, right:6996): 40811
# Initial key: 12673; new key: 12690
# Round 4 switching results:
#  left partition: 6996
#  right partition: 40811
#
# Round 5:Round 5:
#  right partition(after applied F, Key:12690): 40811
#  left partition(after XOR with right, right:40811): 46509
# Initial key: 12690; new key: 12675
# Round 5 switching results:
#  left partition: 40811
#  right partition: 46509
#
# Round 6:Round 6:
#  right partition(after applied F, Key:12675): 46509
#  left partition(after XOR with right, right:46509): 6981
# Initial key: 12675; new key: 12692
# Round 6 switching results:
#  left partition: 46509
#  right partition: 6981
#
# Round 7:Round 7:
#  right partition(after applied F, Key:12692): 6981
#  left partition(after XOR with right, right:6981): 40828
# Initial key: 12692; new key: 12677
# Round 7 switching results:
#  left partition: 6981
#  right partition: 40828
#
# Round 8:Round 8:
#  right partition(after applied F, Key:12677): 40828
#  left partition(after XOR with right, right:40828): 46524
# Initial key: 12677; new key: 12694
# Round 8 switching results:
#  left partition: 40828
#  right partition: 46524
#
# Round 9:Round 9:
#  right partition(after applied F, Key:12694): 46524
#  left partition(after XOR with right, right:46524): 6998
# Initial key: 12694; new key: 12679
# Round 9 switching results:
#  left partition: 46524
#  right partition: 6998
#
# Round 10:Round 10:
#  right partition(after applied F, Key:12679): 6998
#  left partition(after XOR with right, right:6998): 40813
# Initial key: 12679; new key: 12696
# Round 10 switching results:
#  left partition: 6998
#  right partition: 40813
#
# Round 11:Round 11:
#  right partition(after applied F, Key:12696): 40813
#  left partition(after XOR with right, right:40813): 46499
# Initial key: 12696; new key: 12681
# Round 11 switching results:
#  left partition: 40813
#  right partition: 46499
#
# Round 12:Round 12:
#  right partition(after applied F, Key:12681): 46499
#  left partition(after XOR with right, right:46499): 6983
# Initial key: 12681; new key: 12698
# Round 12 switching results:
#  left partition: 46499
#  right partition: 6983
#
# Round 13:Round 13:
#  right partition(after applied F, Key:12698): 6983
#  left partition(after XOR with right, right:6983): 40830
# Initial key: 12698; new key: 12683
# Round 13 switching results:
#  left partition: 6983
#  right partition: 40830
#
# Round 14:Round 14:
#  right partition(after applied F, Key:12683): 40830
#  left partition(after XOR with right, right:40830): 46514
# Initial key: 12683; new key: 12700
# Round 14 switching results:
#  left partition: 40830
#  right partition: 46514
#
# Round 15:Round 15:
#  right partition(after applied F, Key:12700): 46514
#  left partition(after XOR with right, right:46514): 6992
# Initial key: 12700; new key: 12685
# Round 15 switching results:
#  left partition: 46514
#  right partition: 6992
#
# Round 16:Round 16:
#  right partition(after applied F, Key:12685): 6992
#  left partition(after XOR with right, right:6992): 40815
# Initial key: 12685; new key: 12702
# Round 16 switching results:
#  left partition: 6992
#  right partition: 40815
#
# Final left partition: 40815
# Initial right partition: 6992
#
#
# Block 4:
# s is
#
# Initial left partition: 60495
# Initial right partition: 29219
#
# Round 1:Round 1:
#  right partition(after applied F, Key:12654): 29219
#  left partition(after XOR with right, right:29219): 44802
# Initial key: 12654; new key: 12671
# Round 1 switching results:
#  left partition: 29219
#  right partition: 44802
#
# Round 2:Round 2:
#  right partition(after applied F, Key:12671): 44802
#  left partition(after XOR with right, right:44802): 60510
# Initial key: 12671; new key: 12688
# Round 2 switching results:
#  left partition: 44802
#  right partition: 60510
#
# Round 3:Round 3:
#  right partition(after applied F, Key:12688): 60510
#  left partition(after XOR with right, right:60510): 29388
# Initial key: 12688; new key: 12673
# Round 3 switching results:
#  left partition: 60510
#  right partition: 29388
#
# Round 4:Round 4:
#  right partition(after applied F, Key:12673): 29388
#  left partition(after XOR with right, right:29388): 44819
# Initial key: 12673; new key: 12690
# Round 4 switching results:
#  left partition: 29388
#  right partition: 44819
#
# Round 5:Round 5:
#  right partition(after applied F, Key:12690): 44819
#  left partition(after XOR with right, right:44819): 60493
# Initial key: 12690; new key: 12675
# Round 5 switching results:
#  left partition: 44819
#  right partition: 60493
#
# Round 6:Round 6:
#  right partition(after applied F, Key:12675): 60493
#  left partition(after XOR with right, right:60493): 29405
# Initial key: 12675; new key: 12692
# Round 6 switching results:
#  left partition: 60493
#  right partition: 29405
#
# Round 7:Round 7:
#  right partition(after applied F, Key:12692): 29405
#  left partition(after XOR with right, right:29405): 44804
# Initial key: 12692; new key: 12677
# Round 7 switching results:
#  left partition: 29405
#  right partition: 44804
#
# Round 8:Round 8:
#  right partition(after applied F, Key:12677): 44804
#  left partition(after XOR with right, right:44804): 60508
# Initial key: 12677; new key: 12694
# Round 8 switching results:
#  left partition: 44804
#  right partition: 60508
#
# Round 9:Round 9:
#  right partition(after applied F, Key:12694): 60508
#  left partition(after XOR with right, right:60508): 29390
# Initial key: 12694; new key: 12679
# Round 9 switching results:
#  left partition: 60508
#  right partition: 29390
#
# Round 10:Round 10:
#  right partition(after applied F, Key:12679): 29390
#  left partition(after XOR with right, right:29390): 44821
# Initial key: 12679; new key: 12696
# Round 10 switching results:
#  left partition: 29390
#  right partition: 44821
#
# Round 11:Round 11:
#  right partition(after applied F, Key:12696): 44821
#  left partition(after XOR with right, right:44821): 60483
# Initial key: 12696; new key: 12681
# Round 11 switching results:
#  left partition: 44821
#  right partition: 60483
#
# Round 12:Round 12:
#  right partition(after applied F, Key:12681): 60483
#  left partition(after XOR with right, right:60483): 29407
# Initial key: 12681; new key: 12698
# Round 12 switching results:
#  left partition: 60483
#  right partition: 29407
#
# Round 13:Round 13:
#  right partition(after applied F, Key:12698): 29407
#  left partition(after XOR with right, right:29407): 44806
# Initial key: 12698; new key: 12683
# Round 13 switching results:
#  left partition: 29407
#  right partition: 44806
#
# Round 14:Round 14:
#  right partition(after applied F, Key:12683): 44806
#  left partition(after XOR with right, right:44806): 60498
# Initial key: 12683; new key: 12700
# Round 14 switching results:
#  left partition: 44806
#  right partition: 60498
#
# Round 15:Round 15:
#  right partition(after applied F, Key:12700): 60498
#  left partition(after XOR with right, right:60498): 29384
# Initial key: 12700; new key: 12685
# Round 15 switching results:
#  left partition: 60498
#  right partition: 29384
#
# Round 16:Round 16:
#  right partition(after applied F, Key:12685): 29384
#  left partition(after XOR with right, right:29384): 44823
# Initial key: 12685; new key: 12702
# Round 16 switching results:
#  left partition: 29384
#  right partition: 44823
#
# Final left partition: 44823
# Initial right partition: 29384
#
#
# Block 5:
#  Lou
#
# Initial left partition: 36699
# Initial right partition: 7613
#
# Round 1:Round 1:
#  right partition(after applied F, Key:12654): 7613
#  left partition(after XOR with right, right:7613): 41864
# Initial key: 12654; new key: 12671
# Round 1 switching results:
#  left partition: 7613
#  right partition: 41864
#
# Round 2:Round 2:
#  right partition(after applied F, Key:12671): 41864
#  left partition(after XOR with right, right:41864): 36682
# Initial key: 12671; new key: 12688
# Round 2 switching results:
#  left partition: 41864
#  right partition: 36682
#
# Round 3:Round 3:
#  right partition(after applied F, Key:12688): 36682
#  left partition(after XOR with right, right:36682): 7506
# Initial key: 12688; new key: 12673
# Round 3 switching results:
#  left partition: 36682
#  right partition: 7506
#
# Round 4:Round 4:
#  right partition(after applied F, Key:12673): 7506
#  left partition(after XOR with right, right:7506): 41881
# Initial key: 12673; new key: 12690
# Round 4 switching results:
#  left partition: 7506
#  right partition: 41881
#
# Round 5:Round 5:
#  right partition(after applied F, Key:12690): 41881
#  left partition(after XOR with right, right:41881): 36697
# Initial key: 12690; new key: 12675
# Round 5 switching results:
#  left partition: 41881
#  right partition: 36697
#
# Round 6:Round 6:
#  right partition(after applied F, Key:12675): 36697
#  left partition(after XOR with right, right:36697): 7491
# Initial key: 12675; new key: 12692
# Round 6 switching results:
#  left partition: 36697
#  right partition: 7491
#
# Round 7:Round 7:
#  right partition(after applied F, Key:12692): 7491
#  left partition(after XOR with right, right:7491): 41870
# Initial key: 12692; new key: 12677
# Round 7 switching results:
#  left partition: 7491
#  right partition: 41870
#
# Round 8:Round 8:
#  right partition(after applied F, Key:12677): 41870
#  left partition(after XOR with right, right:41870): 36680
# Initial key: 12677; new key: 12694
# Round 8 switching results:
#  left partition: 41870
#  right partition: 36680
#
# Round 9:Round 9:
#  right partition(after applied F, Key:12694): 36680
#  left partition(after XOR with right, right:36680): 7504
# Initial key: 12694; new key: 12679
# Round 9 switching results:
#  left partition: 36680
#  right partition: 7504
#
# Round 10:Round 10:
#  right partition(after applied F, Key:12679): 7504
#  left partition(after XOR with right, right:7504): 41887
# Initial key: 12679; new key: 12696
# Round 10 switching results:
#  left partition: 7504
#  right partition: 41887
#
# Round 11:Round 11:
#  right partition(after applied F, Key:12696): 41887
#  left partition(after XOR with right, right:41887): 36695
# Initial key: 12696; new key: 12681
# Round 11 switching results:
#  left partition: 41887
#  right partition: 36695
#
# Round 12:Round 12:
#  right partition(after applied F, Key:12681): 36695
#  left partition(after XOR with right, right:36695): 7489
# Initial key: 12681; new key: 12698
# Round 12 switching results:
#  left partition: 36695
#  right partition: 7489
#
# Round 13:Round 13:
#  right partition(after applied F, Key:12698): 7489
#  left partition(after XOR with right, right:7489): 41868
# Initial key: 12698; new key: 12683
# Round 13 switching results:
#  left partition: 7489
#  right partition: 41868
#
# Round 14:Round 14:
#  right partition(after applied F, Key:12683): 41868
#  left partition(after XOR with right, right:41868): 36678
# Initial key: 12683; new key: 12700
# Round 14 switching results:
#  left partition: 41868
#  right partition: 36678
#
# Round 15:Round 15:
#  right partition(after applied F, Key:12700): 36678
#  left partition(after XOR with right, right:36678): 7510
# Initial key: 12700; new key: 12685
# Round 15 switching results:
#  left partition: 36678
#  right partition: 7510
#
# Round 16:Round 16:
#  right partition(after applied F, Key:12685): 7510
#  left partition(after XOR with right, right:7510): 41885
# Initial key: 12685; new key: 12702
# Round 16 switching results:
#  left partition: 7510
#  right partition: 41885
#
# Final left partition: 41885
# Initial right partition: 7510
#
#
# Block 6:
# is a
#
# Initial left partition: 51950
# Initial right partition: 15671
#
# Round 1:Round 1:
#  right partition(after applied F, Key:12654): 15671
#  left partition(after XOR with right, right:15671): 50871
# Initial key: 12654; new key: 12671
# Round 1 switching results:
#  left partition: 15671
#  right partition: 50871
#
# Round 2:Round 2:
#  right partition(after applied F, Key:12671): 50871
#  left partition(after XOR with right, right:50871): 51967
# Initial key: 12671; new key: 12688
# Round 2 switching results:
#  left partition: 50871
#  right partition: 51967
#
# Round 3:Round 3:
#  right partition(after applied F, Key:12688): 51967
#  left partition(after XOR with right, right:51967): 15832
# Initial key: 12688; new key: 12673
# Round 3 switching results:
#  left partition: 51967
#  right partition: 15832
#
# Round 4:Round 4:
#  right partition(after applied F, Key:12673): 15832
#  left partition(after XOR with right, right:15832): 50854
# Initial key: 12673; new key: 12690
# Round 4 switching results:
#  left partition: 15832
#  right partition: 50854
#
# Round 5:Round 5:
#  right partition(after applied F, Key:12690): 50854
#  left partition(after XOR with right, right:50854): 51948
# Initial key: 12690; new key: 12675
# Round 5 switching results:
#  left partition: 50854
#  right partition: 51948
#
# Round 6:Round 6:
#  right partition(after applied F, Key:12675): 51948
#  left partition(after XOR with right, right:51948): 15817
# Initial key: 12675; new key: 12692
# Round 6 switching results:
#  left partition: 51948
#  right partition: 15817
#
# Round 7:Round 7:
#  right partition(after applied F, Key:12692): 15817
#  left partition(after XOR with right, right:15817): 50865
# Initial key: 12692; new key: 12677
# Round 7 switching results:
#  left partition: 15817
#  right partition: 50865
#
# Round 8:Round 8:
#  right partition(after applied F, Key:12677): 50865
#  left partition(after XOR with right, right:50865): 51965
# Initial key: 12677; new key: 12694
# Round 8 switching results:
#  left partition: 50865
#  right partition: 51965
#
# Round 9:Round 9:
#  right partition(after applied F, Key:12694): 51965
#  left partition(after XOR with right, right:51965): 15834
# Initial key: 12694; new key: 12679
# Round 9 switching results:
#  left partition: 51965
#  right partition: 15834
#
# Round 10:Round 10:
#  right partition(after applied F, Key:12679): 15834
#  left partition(after XOR with right, right:15834): 50848
# Initial key: 12679; new key: 12696
# Round 10 switching results:
#  left partition: 15834
#  right partition: 50848
#
# Round 11:Round 11:
#  right partition(after applied F, Key:12696): 50848
#  left partition(after XOR with right, right:50848): 51938
# Initial key: 12696; new key: 12681
# Round 11 switching results:
#  left partition: 50848
#  right partition: 51938
#
# Round 12:Round 12:
#  right partition(after applied F, Key:12681): 51938
#  left partition(after XOR with right, right:51938): 15819
# Initial key: 12681; new key: 12698
# Round 12 switching results:
#  left partition: 51938
#  right partition: 15819
#
# Round 13:Round 13:
#  right partition(after applied F, Key:12698): 15819
#  left partition(after XOR with right, right:15819): 50867
# Initial key: 12698; new key: 12683
# Round 13 switching results:
#  left partition: 15819
#  right partition: 50867
#
# Round 14:Round 14:
#  right partition(after applied F, Key:12683): 50867
#  left partition(after XOR with right, right:50867): 51955
# Initial key: 12683; new key: 12700
# Round 14 switching results:
#  left partition: 50867
#  right partition: 51955
#
# Round 15:Round 15:
#  right partition(after applied F, Key:12700): 51955
#  left partition(after XOR with right, right:51955): 15836
# Initial key: 12700; new key: 12685
# Round 15 switching results:
#  left partition: 51955
#  right partition: 15836
#
# Round 16:Round 16:
#  right partition(after applied F, Key:12685): 15836
#  left partition(after XOR with right, right:15836): 50850
# Initial key: 12685; new key: 12702
# Round 16 switching results:
#  left partition: 15836
#  right partition: 50850
#
# Final left partition: 50850
# Initial right partition: 15836
#
#
# Block 7:
# nd H
#
# Initial left partition: 43206
# Initial right partition: 7572
#
# Round 1:Round 1:
#  right partition(after applied F, Key:12654): 7572
#  left partition(after XOR with right, right:7572): 33852
# Initial key: 12654; new key: 12671
# Round 1 switching results:
#  left partition: 7572
#  right partition: 33852
#
# Round 2:Round 2:
#  right partition(after applied F, Key:12671): 33852
#  left partition(after XOR with right, right:33852): 43223
# Initial key: 12671; new key: 12688
# Round 2 switching results:
#  left partition: 33852
#  right partition: 43223
#
# Round 3:Round 3:
#  right partition(after applied F, Key:12688): 43223
#  left partition(after XOR with right, right:43223): 7547
# Initial key: 12688; new key: 12673
# Round 3 switching results:
#  left partition: 43223
#  right partition: 7547
#
# Round 4:Round 4:
#  right partition(after applied F, Key:12673): 7547
#  left partition(after XOR with right, right:7547): 33837
# Initial key: 12673; new key: 12690
# Round 4 switching results:
#  left partition: 7547
#  right partition: 33837
#
# Round 5:Round 5:
#  right partition(after applied F, Key:12690): 33837
#  left partition(after XOR with right, right:33837): 43204
# Initial key: 12690; new key: 12675
# Round 5 switching results:
#  left partition: 33837
#  right partition: 43204
#
# Round 6:Round 6:
#  right partition(after applied F, Key:12675): 43204
#  left partition(after XOR with right, right:43204): 7530
# Initial key: 12675; new key: 12692
# Round 6 switching results:
#  left partition: 43204
#  right partition: 7530
#
# Round 7:Round 7:
#  right partition(after applied F, Key:12692): 7530
#  left partition(after XOR with right, right:7530): 33850
# Initial key: 12692; new key: 12677
# Round 7 switching results:
#  left partition: 7530
#  right partition: 33850
#
# Round 8:Round 8:
#  right partition(after applied F, Key:12677): 33850
#  left partition(after XOR with right, right:33850): 43221
# Initial key: 12677; new key: 12694
# Round 8 switching results:
#  left partition: 33850
#  right partition: 43221
#
# Round 9:Round 9:
#  right partition(after applied F, Key:12694): 43221
#  left partition(after XOR with right, right:43221): 7545
# Initial key: 12694; new key: 12679
# Round 9 switching results:
#  left partition: 43221
#  right partition: 7545
#
# Round 10:Round 10:
#  right partition(after applied F, Key:12679): 7545
#  left partition(after XOR with right, right:7545): 33835
# Initial key: 12679; new key: 12696
# Round 10 switching results:
#  left partition: 7545
#  right partition: 33835
#
# Round 11:Round 11:
#  right partition(after applied F, Key:12696): 33835
#  left partition(after XOR with right, right:33835): 43210
# Initial key: 12696; new key: 12681
# Round 11 switching results:
#  left partition: 33835
#  right partition: 43210
#
# Round 12:Round 12:
#  right partition(after applied F, Key:12681): 43210
#  left partition(after XOR with right, right:43210): 7528
# Initial key: 12681; new key: 12698
# Round 12 switching results:
#  left partition: 43210
#  right partition: 7528
#
# Round 13:Round 13:
#  right partition(after applied F, Key:12698): 7528
#  left partition(after XOR with right, right:7528): 33848
# Initial key: 12698; new key: 12683
# Round 13 switching results:
#  left partition: 7528
#  right partition: 33848
#
# Round 14:Round 14:
#  right partition(after applied F, Key:12683): 33848
#  left partition(after XOR with right, right:33848): 43227
# Initial key: 12683; new key: 12700
# Round 14 switching results:
#  left partition: 33848
#  right partition: 43227
#
# Round 15:Round 15:
#  right partition(after applied F, Key:12700): 43227
#  left partition(after XOR with right, right:43227): 7551
# Initial key: 12700; new key: 12685
# Round 15 switching results:
#  left partition: 43227
#  right partition: 7551
#
# Round 16:Round 16:
#  right partition(after applied F, Key:12685): 7551
#  left partition(after XOR with right, right:7551): 33833
# Initial key: 12685; new key: 12702
# Round 16 switching results:
#  left partition: 7551
#  right partition: 33833
#
# Final left partition: 33833
# Initial right partition: 7551
#
#
# Block 8:
# ylmi
#
# Initial left partition: 64837
# Initial right partition: 28694
#
# Round 1:Round 1:
#  right partition(after applied F, Key:12654): 28694
#  left partition(after XOR with right, right:28694): 48189
# Initial key: 12654; new key: 12671
# Round 1 switching results:
#  left partition: 28694
#  right partition: 48189
#
# Round 2:Round 2:
#  right partition(after applied F, Key:12671): 48189
#  left partition(after XOR with right, right:48189): 64852
# Initial key: 12671; new key: 12688
# Round 2 switching results:
#  left partition: 48189
#  right partition: 64852
#
# Round 3:Round 3:
#  right partition(after applied F, Key:12688): 64852
#  left partition(after XOR with right, right:64852): 28921
# Initial key: 12688; new key: 12673
# Round 3 switching results:
#  left partition: 64852
#  right partition: 28921
#
# Round 4:Round 4:
#  right partition(after applied F, Key:12673): 28921
#  left partition(after XOR with right, right:28921): 48172
# Initial key: 12673; new key: 12690
# Round 4 switching results:
#  left partition: 28921
#  right partition: 48172
#
# Round 5:Round 5:
#  right partition(after applied F, Key:12690): 48172
#  left partition(after XOR with right, right:48172): 64839
# Initial key: 12690; new key: 12675
# Round 5 switching results:
#  left partition: 48172
#  right partition: 64839
#
# Round 6:Round 6:
#  right partition(after applied F, Key:12675): 64839
#  left partition(after XOR with right, right:64839): 28904
# Initial key: 12675; new key: 12692
# Round 6 switching results:
#  left partition: 64839
#  right partition: 28904
#
# Round 7:Round 7:
#  right partition(after applied F, Key:12692): 28904
#  left partition(after XOR with right, right:28904): 48187
# Initial key: 12692; new key: 12677
# Round 7 switching results:
#  left partition: 28904
#  right partition: 48187
#
# Round 8:Round 8:
#  right partition(after applied F, Key:12677): 48187
#  left partition(after XOR with right, right:48187): 64854
# Initial key: 12677; new key: 12694
# Round 8 switching results:
#  left partition: 48187
#  right partition: 64854
#
# Round 9:Round 9:
#  right partition(after applied F, Key:12694): 64854
#  left partition(after XOR with right, right:64854): 28923
# Initial key: 12694; new key: 12679
# Round 9 switching results:
#  left partition: 64854
#  right partition: 28923
#
# Round 10:Round 10:
#  right partition(after applied F, Key:12679): 28923
#  left partition(after XOR with right, right:28923): 48170
# Initial key: 12679; new key: 12696
# Round 10 switching results:
#  left partition: 28923
#  right partition: 48170
#
# Round 11:Round 11:
#  right partition(after applied F, Key:12696): 48170
#  left partition(after XOR with right, right:48170): 64841
# Initial key: 12696; new key: 12681
# Round 11 switching results:
#  left partition: 48170
#  right partition: 64841
#
# Round 12:Round 12:
#  right partition(after applied F, Key:12681): 64841
#  left partition(after XOR with right, right:64841): 28906
# Initial key: 12681; new key: 12698
# Round 12 switching results:
#  left partition: 64841
#  right partition: 28906
#
# Round 13:Round 13:
#  right partition(after applied F, Key:12698): 28906
#  left partition(after XOR with right, right:28906): 48185
# Initial key: 12698; new key: 12683
# Round 13 switching results:
#  left partition: 28906
#  right partition: 48185
#
# Round 14:Round 14:
#  right partition(after applied F, Key:12683): 48185
#  left partition(after XOR with right, right:48185): 64856
# Initial key: 12683; new key: 12700
# Round 14 switching results:
#  left partition: 48185
#  right partition: 64856
#
# Round 15:Round 15:
#  right partition(after applied F, Key:12700): 64856
#  left partition(after XOR with right, right:64856): 28925
# Initial key: 12700; new key: 12685
# Round 15 switching results:
#  left partition: 64856
#  right partition: 28925
#
# Round 16:Round 16:
#  right partition(after applied F, Key:12685): 28925
#  left partition(after XOR with right, right:28925): 48168
# Initial key: 12685; new key: 12702
# Round 16 switching results:
#  left partition: 28925
#  right partition: 48168
#
# Final left partition: 48168
# Initial right partition: 28925
#
#
# Block 9:
# .
#
# Initial left partition: 37384
# Initial right partition: 20701
#
# Round 1:Round 1:
#  right partition(after applied F, Key:12654): 20701
#  left partition(after XOR with right, right:20701): 62395
# Initial key: 12654; new key: 12671
# Round 1 switching results:
#  left partition: 20701
#  right partition: 62395
#
# Round 2:Round 2:
#  right partition(after applied F, Key:12671): 62395
#  left partition(after XOR with right, right:62395): 37401
# Initial key: 12671; new key: 12688
# Round 2 switching results:
#  left partition: 62395
#  right partition: 37401
#
# Round 3:Round 3:
#  right partition(after applied F, Key:12688): 37401
#  left partition(after XOR with right, right:37401): 20530
# Initial key: 12688; new key: 12673
# Round 3 switching results:
#  left partition: 37401
#  right partition: 20530
#
# Round 4:Round 4:
#  right partition(after applied F, Key:12673): 20530
#  left partition(after XOR with right, right:20530): 62378
# Initial key: 12673; new key: 12690
# Round 4 switching results:
#  left partition: 20530
#  right partition: 62378
#
# Round 5:Round 5:
#  right partition(after applied F, Key:12690): 62378
#  left partition(after XOR with right, right:62378): 37386
# Initial key: 12690; new key: 12675
# Round 5 switching results:
#  left partition: 62378
#  right partition: 37386
#
# Round 6:Round 6:
#  right partition(after applied F, Key:12675): 37386
#  left partition(after XOR with right, right:37386): 20515
# Initial key: 12675; new key: 12692
# Round 6 switching results:
#  left partition: 37386
#  right partition: 20515
#
# Round 7:Round 7:
#  right partition(after applied F, Key:12692): 20515
#  left partition(after XOR with right, right:20515): 62397
# Initial key: 12692; new key: 12677
# Round 7 switching results:
#  left partition: 20515
#  right partition: 62397
#
# Round 8:Round 8:
#  right partition(after applied F, Key:12677): 62397
#  left partition(after XOR with right, right:62397): 37403
# Initial key: 12677; new key: 12694
# Round 8 switching results:
#  left partition: 62397
#  right partition: 37403
#
# Round 9:Round 9:
#  right partition(after applied F, Key:12694): 37403
#  left partition(after XOR with right, right:37403): 20528
# Initial key: 12694; new key: 12679
# Round 9 switching results:
#  left partition: 37403
#  right partition: 20528
#
# Round 10:Round 10:
#  right partition(after applied F, Key:12679): 20528
#  left partition(after XOR with right, right:20528): 62380
# Initial key: 12679; new key: 12696
# Round 10 switching results:
#  left partition: 20528
#  right partition: 62380
#
# Round 11:Round 11:
#  right partition(after applied F, Key:12696): 62380
#  left partition(after XOR with right, right:62380): 37380
# Initial key: 12696; new key: 12681
# Round 11 switching results:
#  left partition: 62380
#  right partition: 37380
#
# Round 12:Round 12:
#  right partition(after applied F, Key:12681): 37380
#  left partition(after XOR with right, right:37380): 20513
# Initial key: 12681; new key: 12698
# Round 12 switching results:
#  left partition: 37380
#  right partition: 20513
#
# Round 13:Round 13:
#  right partition(after applied F, Key:12698): 20513
#  left partition(after XOR with right, right:20513): 62399
# Initial key: 12698; new key: 12683
# Round 13 switching results:
#  left partition: 20513
#  right partition: 62399
#
# Round 14:Round 14:
#  right partition(after applied F, Key:12683): 62399
#  left partition(after XOR with right, right:62399): 37397
# Initial key: 12683; new key: 12700
# Round 14 switching results:
#  left partition: 62399
#  right partition: 37397
#
# Round 15:Round 15:
#  right partition(after applied F, Key:12700): 37397
#  left partition(after XOR with right, right:37397): 20534
# Initial key: 12700; new key: 12685
# Round 15 switching results:
#  left partition: 37397
#  right partition: 20534
#
# Round 16:Round 16:
#  right partition(after applied F, Key:12685): 20534
#  left partition(after XOR with right, right:20534): 62382
# Initial key: 12685; new key: 12702
# Round 16 switching results:
#  left partition: 20534
#  right partition: 62382
#
# Final left partition: 62382
# Initial right partition: 20534
#
# CPU times: user 6.64 ms, sys: 351 µs, total: 6.99 ms
# Wall time: 6.92 ms

# %%
# %%time
# decryption
decrypted_list = decrypt_cipherCBC(cipher_list, key_last_used, iv, round)
# Out:
# Initial key: 12702; new key: 12685
# Initial left partition: 60541
# Initial right partition: 24732
#
# Round 1:
#  right partition(after applied F, Key:12685): 24732
#  left partition(after XOR with right, right:24732): 48492
# Initial key: 12685; new key: 12700
# Round 1 switching results:
#  left partition: 24732
#  right partition: 48492
#
# Round 2:
#  right partition(after applied F, Key:12700): 48492
#  left partition(after XOR with right, right:48492): 60524
# Initial key: 12700; new key: 12683
# Round 2 switching results:
#  left partition: 48492
#  right partition: 60524
#
# Round 3:
#  right partition(after applied F, Key:12683): 60524
#  left partition(after XOR with right, right:60524): 24715
# Initial key: 12683; new key: 12698
# Round 3 switching results:
#  left partition: 60524
#  right partition: 24715
#
# Round 4:
#  right partition(after applied F, Key:12698): 24715
#  left partition(after XOR with right, right:24715): 48509
# Initial key: 12698; new key: 12681
# Round 4 switching results:
#  left partition: 24715
#  right partition: 48509
#
# Round 5:
#  right partition(after applied F, Key:12681): 48509
#  left partition(after XOR with right, right:48509): 60543
# Initial key: 12681; new key: 12696
# Round 5 switching results:
#  left partition: 48509
#  right partition: 60543
#
# Round 6:
#  right partition(after applied F, Key:12696): 60543
#  left partition(after XOR with right, right:60543): 24730
# Initial key: 12696; new key: 12679
# Round 6 switching results:
#  left partition: 60543
#  right partition: 24730
#
# Round 7:
#  right partition(after applied F, Key:12679): 24730
#  left partition(after XOR with right, right:24730): 48482
# Initial key: 12679; new key: 12694
# Round 7 switching results:
#  left partition: 24730
#  right partition: 48482
#
# Round 8:
#  right partition(after applied F, Key:12694): 48482
#  left partition(after XOR with right, right:48482): 60526
# Initial key: 12694; new key: 12677
# Round 8 switching results:
#  left partition: 48482
#  right partition: 60526
#
# Round 9:
#  right partition(after applied F, Key:12677): 60526
#  left partition(after XOR with right, right:60526): 24713
# Initial key: 12677; new key: 12692
# Round 9 switching results:
#  left partition: 60526
#  right partition: 24713
#
# Round 10:
#  right partition(after applied F, Key:12692): 24713
#  left partition(after XOR with right, right:24713): 48499
# Initial key: 12692; new key: 12675
# Round 10 switching results:
#  left partition: 24713
#  right partition: 48499
#
# Round 11:
#  right partition(after applied F, Key:12675): 48499
#  left partition(after XOR with right, right:48499): 60537
# Initial key: 12675; new key: 12690
# Round 11 switching results:
#  left partition: 48499
#  right partition: 60537
#
# Round 12:
#  right partition(after applied F, Key:12690): 60537
#  left partition(after XOR with right, right:60537): 24728
# Initial key: 12690; new key: 12673
# Round 12 switching results:
#  left partition: 60537
#  right partition: 24728
#
# Round 13:
#  right partition(after applied F, Key:12673): 24728
#  left partition(after XOR with right, right:24728): 48480
# Initial key: 12673; new key: 12688
# Round 13 switching results:
#  left partition: 24728
#  right partition: 48480
#
# Round 14:
#  right partition(after applied F, Key:12688): 48480
#  left partition(after XOR with right, right:48480): 60520
# Initial key: 12688; new key: 12671
# Round 14 switching results:
#  left partition: 48480
#  right partition: 60520
#
# Round 15:
#  right partition(after applied F, Key:12671): 60520
#  left partition(after XOR with right, right:60520): 24695
# Initial key: 12671; new key: 12654
# Round 15 switching results:
#  left partition: 60520
#  right partition: 24695
#
# Round 16:
#  right partition(after applied F, Key:12654): 24695
#  left partition(after XOR with right, right:24695): 48497
# Initial key: 12654; new key: 12669
# Round 16 switching results:
#  left partition: 24695
#  right partition: 48497
#
# Final left partition: 48497
# Initial right partition: 24695
#
# Initial key: 12702; new key: 12685
# Initial left partition: 42453
# Initial right partition: 5912
#
# Round 1:
#  right partition(after applied F, Key:12685): 5912
#  left partition(after XOR with right, right:5912): 33600
# Initial key: 12685; new key: 12700
# Round 1 switching results:
#  left partition: 5912
#  right partition: 33600
#
# Round 2:
#  right partition(after applied F, Key:12700): 33600
#  left partition(after XOR with right, right:33600): 42436
# Initial key: 12700; new key: 12683
# Round 2 switching results:
#  left partition: 33600
#  right partition: 42436
#
# Round 3:
#  right partition(after applied F, Key:12683): 42436
#  left partition(after XOR with right, right:42436): 5903
# Initial key: 12683; new key: 12698
# Round 3 switching results:
#  left partition: 42436
#  right partition: 5903
#
# Round 4:
#  right partition(after applied F, Key:12698): 5903
#  left partition(after XOR with right, right:5903): 33617
# Initial key: 12698; new key: 12681
# Round 4 switching results:
#  left partition: 5903
#  right partition: 33617
#
# Round 5:
#  right partition(after applied F, Key:12681): 33617
#  left partition(after XOR with right, right:33617): 42455
# Initial key: 12681; new key: 12696
# Round 5 switching results:
#  left partition: 33617
#  right partition: 42455
#
# Round 6:
#  right partition(after applied F, Key:12696): 42455
#  left partition(after XOR with right, right:42455): 5918
# Initial key: 12696; new key: 12679
# Round 6 switching results:
#  left partition: 42455
#  right partition: 5918
#
# Round 7:
#  right partition(after applied F, Key:12679): 5918
#  left partition(after XOR with right, right:5918): 33614
# Initial key: 12679; new key: 12694
# Round 7 switching results:
#  left partition: 5918
#  right partition: 33614
#
# Round 8:
#  right partition(after applied F, Key:12694): 33614
#  left partition(after XOR with right, right:33614): 42438
# Initial key: 12694; new key: 12677
# Round 8 switching results:
#  left partition: 33614
#  right partition: 42438
#
# Round 9:
#  right partition(after applied F, Key:12677): 42438
#  left partition(after XOR with right, right:42438): 5901
# Initial key: 12677; new key: 12692
# Round 9 switching results:
#  left partition: 42438
#  right partition: 5901
#
# Round 10:
#  right partition(after applied F, Key:12692): 5901
#  left partition(after XOR with right, right:5901): 33631
# Initial key: 12692; new key: 12675
# Round 10 switching results:
#  left partition: 5901
#  right partition: 33631
#
# Round 11:
#  right partition(after applied F, Key:12675): 33631
#  left partition(after XOR with right, right:33631): 42449
# Initial key: 12675; new key: 12690
# Round 11 switching results:
#  left partition: 33631
#  right partition: 42449
#
# Round 12:
#  right partition(after applied F, Key:12690): 42449
#  left partition(after XOR with right, right:42449): 5916
# Initial key: 12690; new key: 12673
# Round 12 switching results:
#  left partition: 42449
#  right partition: 5916
#
# Round 13:
#  right partition(after applied F, Key:12673): 5916
#  left partition(after XOR with right, right:5916): 33612
# Initial key: 12673; new key: 12688
# Round 13 switching results:
#  left partition: 5916
#  right partition: 33612
#
# Round 14:
#  right partition(after applied F, Key:12688): 33612
#  left partition(after XOR with right, right:33612): 42432
# Initial key: 12688; new key: 12671
# Round 14 switching results:
#  left partition: 33612
#  right partition: 42432
#
# Round 15:
#  right partition(after applied F, Key:12671): 42432
#  left partition(after XOR with right, right:42432): 6131
# Initial key: 12671; new key: 12654
# Round 15 switching results:
#  left partition: 42432
#  right partition: 6131
#
# Round 16:
#  right partition(after applied F, Key:12654): 6131
#  left partition(after XOR with right, right:6131): 33629
# Initial key: 12654; new key: 12669
# Round 16 switching results:
#  left partition: 6131
#  right partition: 33629
#
# Final left partition: 33629
# Initial right partition: 6131
#
# Initial key: 12702; new key: 12685
# Initial left partition: 38395
# Initial right partition: 29650
#
# Round 1:
#  right partition(after applied F, Key:12685): 29650
#  left partition(after XOR with right, right:29650): 55204
# Initial key: 12685; new key: 12700
# Round 1 switching results:
#  left partition: 29650
#  right partition: 55204
#
# Round 2:
#  right partition(after applied F, Key:12700): 55204
#  left partition(after XOR with right, right:55204): 38378
# Initial key: 12700; new key: 12683
# Round 2 switching results:
#  left partition: 55204
#  right partition: 38378
#
# Round 3:
#  right partition(after applied F, Key:12683): 38378
#  left partition(after XOR with right, right:38378): 29637
# Initial key: 12683; new key: 12698
# Round 3 switching results:
#  left partition: 38378
#  right partition: 29637
#
# Round 4:
#  right partition(after applied F, Key:12698): 29637
#  left partition(after XOR with right, right:29637): 55221
# Initial key: 12698; new key: 12681
# Round 4 switching results:
#  left partition: 29637
#  right partition: 55221
#
# Round 5:
#  right partition(after applied F, Key:12681): 55221
#  left partition(after XOR with right, right:55221): 38393
# Initial key: 12681; new key: 12696
# Round 5 switching results:
#  left partition: 55221
#  right partition: 38393
#
# Round 6:
#  right partition(after applied F, Key:12696): 38393
#  left partition(after XOR with right, right:38393): 29652
# Initial key: 12696; new key: 12679
# Round 6 switching results:
#  left partition: 38393
#  right partition: 29652
#
# Round 7:
#  right partition(after applied F, Key:12679): 29652
#  left partition(after XOR with right, right:29652): 55210
# Initial key: 12679; new key: 12694
# Round 7 switching results:
#  left partition: 29652
#  right partition: 55210
#
# Round 8:
#  right partition(after applied F, Key:12694): 55210
#  left partition(after XOR with right, right:55210): 38376
# Initial key: 12694; new key: 12677
# Round 8 switching results:
#  left partition: 55210
#  right partition: 38376
#
# Round 9:
#  right partition(after applied F, Key:12677): 38376
#  left partition(after XOR with right, right:38376): 29639
# Initial key: 12677; new key: 12692
# Round 9 switching results:
#  left partition: 38376
#  right partition: 29639
#
# Round 10:
#  right partition(after applied F, Key:12692): 29639
#  left partition(after XOR with right, right:29639): 55227
# Initial key: 12692; new key: 12675
# Round 10 switching results:
#  left partition: 29639
#  right partition: 55227
#
# Round 11:
#  right partition(after applied F, Key:12675): 55227
#  left partition(after XOR with right, right:55227): 38399
# Initial key: 12675; new key: 12690
# Round 11 switching results:
#  left partition: 55227
#  right partition: 38399
#
# Round 12:
#  right partition(after applied F, Key:12690): 38399
#  left partition(after XOR with right, right:38399): 29654
# Initial key: 12690; new key: 12673
# Round 12 switching results:
#  left partition: 38399
#  right partition: 29654
#
# Round 13:
#  right partition(after applied F, Key:12673): 29654
#  left partition(after XOR with right, right:29654): 55208
# Initial key: 12673; new key: 12688
# Round 13 switching results:
#  left partition: 29654
#  right partition: 55208
#
# Round 14:
#  right partition(after applied F, Key:12688): 55208
#  left partition(after XOR with right, right:55208): 38382
# Initial key: 12688; new key: 12671
# Round 14 switching results:
#  left partition: 55208
#  right partition: 38382
#
# Round 15:
#  right partition(after applied F, Key:12671): 38382
#  left partition(after XOR with right, right:38382): 29497
# Initial key: 12671; new key: 12654
# Round 15 switching results:
#  left partition: 38382
#  right partition: 29497
#
# Round 16:
#  right partition(after applied F, Key:12654): 29497
#  left partition(after XOR with right, right:29497): 55225
# Initial key: 12654; new key: 12669
# Round 16 switching results:
#  left partition: 29497
#  right partition: 55225
#
# Final left partition: 55225
# Initial right partition: 29497
#
# Initial key: 12702; new key: 12685
# Initial left partition: 40815
# Initial right partition: 6992
#
# Round 1:
#  right partition(after applied F, Key:12685): 6992
#  left partition(after XOR with right, right:6992): 46514
# Initial key: 12685; new key: 12700
# Round 1 switching results:
#  left partition: 6992
#  right partition: 46514
#
# Round 2:
#  right partition(after applied F, Key:12700): 46514
#  left partition(after XOR with right, right:46514): 40830
# Initial key: 12700; new key: 12683
# Round 2 switching results:
#  left partition: 46514
#  right partition: 40830
#
# Round 3:
#  right partition(after applied F, Key:12683): 40830
#  left partition(after XOR with right, right:40830): 6983
# Initial key: 12683; new key: 12698
# Round 3 switching results:
#  left partition: 40830
#  right partition: 6983
#
# Round 4:
#  right partition(after applied F, Key:12698): 6983
#  left partition(after XOR with right, right:6983): 46499
# Initial key: 12698; new key: 12681
# Round 4 switching results:
#  left partition: 6983
#  right partition: 46499
#
# Round 5:
#  right partition(after applied F, Key:12681): 46499
#  left partition(after XOR with right, right:46499): 40813
# Initial key: 12681; new key: 12696
# Round 5 switching results:
#  left partition: 46499
#  right partition: 40813
#
# Round 6:
#  right partition(after applied F, Key:12696): 40813
#  left partition(after XOR with right, right:40813): 6998
# Initial key: 12696; new key: 12679
# Round 6 switching results:
#  left partition: 40813
#  right partition: 6998
#
# Round 7:
#  right partition(after applied F, Key:12679): 6998
#  left partition(after XOR with right, right:6998): 46524
# Initial key: 12679; new key: 12694
# Round 7 switching results:
#  left partition: 6998
#  right partition: 46524
#
# Round 8:
#  right partition(after applied F, Key:12694): 46524
#  left partition(after XOR with right, right:46524): 40828
# Initial key: 12694; new key: 12677
# Round 8 switching results:
#  left partition: 46524
#  right partition: 40828
#
# Round 9:
#  right partition(after applied F, Key:12677): 40828
#  left partition(after XOR with right, right:40828): 6981
# Initial key: 12677; new key: 12692
# Round 9 switching results:
#  left partition: 40828
#  right partition: 6981
#
# Round 10:
#  right partition(after applied F, Key:12692): 6981
#  left partition(after XOR with right, right:6981): 46509
# Initial key: 12692; new key: 12675
# Round 10 switching results:
#  left partition: 6981
#  right partition: 46509
#
# Round 11:
#  right partition(after applied F, Key:12675): 46509
#  left partition(after XOR with right, right:46509): 40811
# Initial key: 12675; new key: 12690
# Round 11 switching results:
#  left partition: 46509
#  right partition: 40811
#
# Round 12:
#  right partition(after applied F, Key:12690): 40811
#  left partition(after XOR with right, right:40811): 6996
# Initial key: 12690; new key: 12673
# Round 12 switching results:
#  left partition: 40811
#  right partition: 6996
#
# Round 13:
#  right partition(after applied F, Key:12673): 6996
#  left partition(after XOR with right, right:6996): 46526
# Initial key: 12673; new key: 12688
# Round 13 switching results:
#  left partition: 6996
#  right partition: 46526
#
# Round 14:
#  right partition(after applied F, Key:12688): 46526
#  left partition(after XOR with right, right:46526): 40826
# Initial key: 12688; new key: 12671
# Round 14 switching results:
#  left partition: 46526
#  right partition: 40826
#
# Round 15:
#  right partition(after applied F, Key:12671): 40826
#  left partition(after XOR with right, right:40826): 7099
# Initial key: 12671; new key: 12654
# Round 15 switching results:
#  left partition: 40826
#  right partition: 7099
#
# Round 16:
#  right partition(after applied F, Key:12654): 7099
#  left partition(after XOR with right, right:7099): 46511
# Initial key: 12654; new key: 12669
# Round 16 switching results:
#  left partition: 7099
#  right partition: 46511
#
# Final left partition: 46511
# Initial right partition: 7099
#
# Initial key: 12702; new key: 12685
# Initial left partition: 44823
# Initial right partition: 29384
#
# Round 1:
#  right partition(after applied F, Key:12685): 29384
#  left partition(after XOR with right, right:29384): 60498
# Initial key: 12685; new key: 12700
# Round 1 switching results:
#  left partition: 29384
#  right partition: 60498
#
# Round 2:
#  right partition(after applied F, Key:12700): 60498
#  left partition(after XOR with right, right:60498): 44806
# Initial key: 12700; new key: 12683
# Round 2 switching results:
#  left partition: 60498
#  right partition: 44806
#
# Round 3:
#  right partition(after applied F, Key:12683): 44806
#  left partition(after XOR with right, right:44806): 29407
# Initial key: 12683; new key: 12698
# Round 3 switching results:
#  left partition: 44806
#  right partition: 29407
#
# Round 4:
#  right partition(after applied F, Key:12698): 29407
#  left partition(after XOR with right, right:29407): 60483
# Initial key: 12698; new key: 12681
# Round 4 switching results:
#  left partition: 29407
#  right partition: 60483
#
# Round 5:
#  right partition(after applied F, Key:12681): 60483
#  left partition(after XOR with right, right:60483): 44821
# Initial key: 12681; new key: 12696
# Round 5 switching results:
#  left partition: 60483
#  right partition: 44821
#
# Round 6:
#  right partition(after applied F, Key:12696): 44821
#  left partition(after XOR with right, right:44821): 29390
# Initial key: 12696; new key: 12679
# Round 6 switching results:
#  left partition: 44821
#  right partition: 29390
#
# Round 7:
#  right partition(after applied F, Key:12679): 29390
#  left partition(after XOR with right, right:29390): 60508
# Initial key: 12679; new key: 12694
# Round 7 switching results:
#  left partition: 29390
#  right partition: 60508
#
# Round 8:
#  right partition(after applied F, Key:12694): 60508
#  left partition(after XOR with right, right:60508): 44804
# Initial key: 12694; new key: 12677
# Round 8 switching results:
#  left partition: 60508
#  right partition: 44804
#
# Round 9:
#  right partition(after applied F, Key:12677): 44804
#  left partition(after XOR with right, right:44804): 29405
# Initial key: 12677; new key: 12692
# Round 9 switching results:
#  left partition: 44804
#  right partition: 29405
#
# Round 10:
#  right partition(after applied F, Key:12692): 29405
#  left partition(after XOR with right, right:29405): 60493
# Initial key: 12692; new key: 12675
# Round 10 switching results:
#  left partition: 29405
#  right partition: 60493
#
# Round 11:
#  right partition(after applied F, Key:12675): 60493
#  left partition(after XOR with right, right:60493): 44819
# Initial key: 12675; new key: 12690
# Round 11 switching results:
#  left partition: 60493
#  right partition: 44819
#
# Round 12:
#  right partition(after applied F, Key:12690): 44819
#  left partition(after XOR with right, right:44819): 29388
# Initial key: 12690; new key: 12673
# Round 12 switching results:
#  left partition: 44819
#  right partition: 29388
#
# Round 13:
#  right partition(after applied F, Key:12673): 29388
#  left partition(after XOR with right, right:29388): 60510
# Initial key: 12673; new key: 12688
# Round 13 switching results:
#  left partition: 29388
#  right partition: 60510
#
# Round 14:
#  right partition(after applied F, Key:12688): 60510
#  left partition(after XOR with right, right:60510): 44802
# Initial key: 12688; new key: 12671
# Round 14 switching results:
#  left partition: 60510
#  right partition: 44802
#
# Round 15:
#  right partition(after applied F, Key:12671): 44802
#  left partition(after XOR with right, right:44802): 29219
# Initial key: 12671; new key: 12654
# Round 15 switching results:
#  left partition: 44802
#  right partition: 29219
#
# Round 16:
#  right partition(after applied F, Key:12654): 29219
#  left partition(after XOR with right, right:29219): 60495
# Initial key: 12654; new key: 12669
# Round 16 switching results:
#  left partition: 29219
#  right partition: 60495
#
# Final left partition: 60495
# Initial right partition: 29219
#
# Initial key: 12702; new key: 12685
# Initial left partition: 41885
# Initial right partition: 7510
#
# Round 1:
#  right partition(after applied F, Key:12685): 7510
#  left partition(after XOR with right, right:7510): 36678
# Initial key: 12685; new key: 12700
# Round 1 switching results:
#  left partition: 7510
#  right partition: 36678
#
# Round 2:
#  right partition(after applied F, Key:12700): 36678
#  left partition(after XOR with right, right:36678): 41868
# Initial key: 12700; new key: 12683
# Round 2 switching results:
#  left partition: 36678
#  right partition: 41868
#
# Round 3:
#  right partition(after applied F, Key:12683): 41868
#  left partition(after XOR with right, right:41868): 7489
# Initial key: 12683; new key: 12698
# Round 3 switching results:
#  left partition: 41868
#  right partition: 7489
#
# Round 4:
#  right partition(after applied F, Key:12698): 7489
#  left partition(after XOR with right, right:7489): 36695
# Initial key: 12698; new key: 12681
# Round 4 switching results:
#  left partition: 7489
#  right partition: 36695
#
# Round 5:
#  right partition(after applied F, Key:12681): 36695
#  left partition(after XOR with right, right:36695): 41887
# Initial key: 12681; new key: 12696
# Round 5 switching results:
#  left partition: 36695
#  right partition: 41887
#
# Round 6:
#  right partition(after applied F, Key:12696): 41887
#  left partition(after XOR with right, right:41887): 7504
# Initial key: 12696; new key: 12679
# Round 6 switching results:
#  left partition: 41887
#  right partition: 7504
#
# Round 7:
#  right partition(after applied F, Key:12679): 7504
#  left partition(after XOR with right, right:7504): 36680
# Initial key: 12679; new key: 12694
# Round 7 switching results:
#  left partition: 7504
#  right partition: 36680
#
# Round 8:
#  right partition(after applied F, Key:12694): 36680
#  left partition(after XOR with right, right:36680): 41870
# Initial key: 12694; new key: 12677
# Round 8 switching results:
#  left partition: 36680
#  right partition: 41870
#
# Round 9:
#  right partition(after applied F, Key:12677): 41870
#  left partition(after XOR with right, right:41870): 7491
# Initial key: 12677; new key: 12692
# Round 9 switching results:
#  left partition: 41870
#  right partition: 7491
#
# Round 10:
#  right partition(after applied F, Key:12692): 7491
#  left partition(after XOR with right, right:7491): 36697
# Initial key: 12692; new key: 12675
# Round 10 switching results:
#  left partition: 7491
#  right partition: 36697
#
# Round 11:
#  right partition(after applied F, Key:12675): 36697
#  left partition(after XOR with right, right:36697): 41881
# Initial key: 12675; new key: 12690
# Round 11 switching results:
#  left partition: 36697
#  right partition: 41881
#
# Round 12:
#  right partition(after applied F, Key:12690): 41881
#  left partition(after XOR with right, right:41881): 7506
# Initial key: 12690; new key: 12673
# Round 12 switching results:
#  left partition: 41881
#  right partition: 7506
#
# Round 13:
#  right partition(after applied F, Key:12673): 7506
#  left partition(after XOR with right, right:7506): 36682
# Initial key: 12673; new key: 12688
# Round 13 switching results:
#  left partition: 7506
#  right partition: 36682
#
# Round 14:
#  right partition(after applied F, Key:12688): 36682
#  left partition(after XOR with right, right:36682): 41864
# Initial key: 12688; new key: 12671
# Round 14 switching results:
#  left partition: 36682
#  right partition: 41864
#
# Round 15:
#  right partition(after applied F, Key:12671): 41864
#  left partition(after XOR with right, right:41864): 7613
# Initial key: 12671; new key: 12654
# Round 15 switching results:
#  left partition: 41864
#  right partition: 7613
#
# Round 16:
#  right partition(after applied F, Key:12654): 7613
#  left partition(after XOR with right, right:7613): 36699
# Initial key: 12654; new key: 12669
# Round 16 switching results:
#  left partition: 7613
#  right partition: 36699
#
# Final left partition: 36699
# Initial right partition: 7613
#
# Initial key: 12702; new key: 12685
# Initial left partition: 50850
# Initial right partition: 15836
#
# Round 1:
#  right partition(after applied F, Key:12685): 15836
#  left partition(after XOR with right, right:15836): 51955
# Initial key: 12685; new key: 12700
# Round 1 switching results:
#  left partition: 15836
#  right partition: 51955
#
# Round 2:
#  right partition(after applied F, Key:12700): 51955
#  left partition(after XOR with right, right:51955): 50867
# Initial key: 12700; new key: 12683
# Round 2 switching results:
#  left partition: 51955
#  right partition: 50867
#
# Round 3:
#  right partition(after applied F, Key:12683): 50867
#  left partition(after XOR with right, right:50867): 15819
# Initial key: 12683; new key: 12698
# Round 3 switching results:
#  left partition: 50867
#  right partition: 15819
#
# Round 4:
#  right partition(after applied F, Key:12698): 15819
#  left partition(after XOR with right, right:15819): 51938
# Initial key: 12698; new key: 12681
# Round 4 switching results:
#  left partition: 15819
#  right partition: 51938
#
# Round 5:
#  right partition(after applied F, Key:12681): 51938
#  left partition(after XOR with right, right:51938): 50848
# Initial key: 12681; new key: 12696
# Round 5 switching results:
#  left partition: 51938
#  right partition: 50848
#
# Round 6:
#  right partition(after applied F, Key:12696): 50848
#  left partition(after XOR with right, right:50848): 15834
# Initial key: 12696; new key: 12679
# Round 6 switching results:
#  left partition: 50848
#  right partition: 15834
#
# Round 7:
#  right partition(after applied F, Key:12679): 15834
#  left partition(after XOR with right, right:15834): 51965
# Initial key: 12679; new key: 12694
# Round 7 switching results:
#  left partition: 15834
#  right partition: 51965
#
# Round 8:
#  right partition(after applied F, Key:12694): 51965
#  left partition(after XOR with right, right:51965): 50865
# Initial key: 12694; new key: 12677
# Round 8 switching results:
#  left partition: 51965
#  right partition: 50865
#
# Round 9:
#  right partition(after applied F, Key:12677): 50865
#  left partition(after XOR with right, right:50865): 15817
# Initial key: 12677; new key: 12692
# Round 9 switching results:
#  left partition: 50865
#  right partition: 15817
#
# Round 10:
#  right partition(after applied F, Key:12692): 15817
#  left partition(after XOR with right, right:15817): 51948
# Initial key: 12692; new key: 12675
# Round 10 switching results:
#  left partition: 15817
#  right partition: 51948
#
# Round 11:
#  right partition(after applied F, Key:12675): 51948
#  left partition(after XOR with right, right:51948): 50854
# Initial key: 12675; new key: 12690
# Round 11 switching results:
#  left partition: 51948
#  right partition: 50854
#
# Round 12:
#  right partition(after applied F, Key:12690): 50854
#  left partition(after XOR with right, right:50854): 15832
# Initial key: 12690; new key: 12673
# Round 12 switching results:
#  left partition: 50854
#  right partition: 15832
#
# Round 13:
#  right partition(after applied F, Key:12673): 15832
#  left partition(after XOR with right, right:15832): 51967
# Initial key: 12673; new key: 12688
# Round 13 switching results:
#  left partition: 15832
#  right partition: 51967
#
# Round 14:
#  right partition(after applied F, Key:12688): 51967
#  left partition(after XOR with right, right:51967): 50871
# Initial key: 12688; new key: 12671
# Round 14 switching results:
#  left partition: 51967
#  right partition: 50871
#
# Round 15:
#  right partition(after applied F, Key:12671): 50871
#  left partition(after XOR with right, right:50871): 15671
# Initial key: 12671; new key: 12654
# Round 15 switching results:
#  left partition: 50871
#  right partition: 15671
#
# Round 16:
#  right partition(after applied F, Key:12654): 15671
#  left partition(after XOR with right, right:15671): 51950
# Initial key: 12654; new key: 12669
# Round 16 switching results:
#  left partition: 15671
#  right partition: 51950
#
# Final left partition: 51950
# Initial right partition: 15671
#
# Initial key: 12702; new key: 12685
# Initial left partition: 33833
# Initial right partition: 7551
#
# Round 1:
#  right partition(after applied F, Key:12685): 7551
#  left partition(after XOR with right, right:7551): 43227
# Initial key: 12685; new key: 12700
# Round 1 switching results:
#  left partition: 7551
#  right partition: 43227
#
# Round 2:
#  right partition(after applied F, Key:12700): 43227
#  left partition(after XOR with right, right:43227): 33848
# Initial key: 12700; new key: 12683
# Round 2 switching results:
#  left partition: 43227
#  right partition: 33848
#
# Round 3:
#  right partition(after applied F, Key:12683): 33848
#  left partition(after XOR with right, right:33848): 7528
# Initial key: 12683; new key: 12698
# Round 3 switching results:
#  left partition: 33848
#  right partition: 7528
#
# Round 4:
#  right partition(after applied F, Key:12698): 7528
#  left partition(after XOR with right, right:7528): 43210
# Initial key: 12698; new key: 12681
# Round 4 switching results:
#  left partition: 7528
#  right partition: 43210
#
# Round 5:
#  right partition(after applied F, Key:12681): 43210
#  left partition(after XOR with right, right:43210): 33835
# Initial key: 12681; new key: 12696
# Round 5 switching results:
#  left partition: 43210
#  right partition: 33835
#
# Round 6:
#  right partition(after applied F, Key:12696): 33835
#  left partition(after XOR with right, right:33835): 7545
# Initial key: 12696; new key: 12679
# Round 6 switching results:
#  left partition: 33835
#  right partition: 7545
#
# Round 7:
#  right partition(after applied F, Key:12679): 7545
#  left partition(after XOR with right, right:7545): 43221
# Initial key: 12679; new key: 12694
# Round 7 switching results:
#  left partition: 7545
#  right partition: 43221
#
# Round 8:
#  right partition(after applied F, Key:12694): 43221
#  left partition(after XOR with right, right:43221): 33850
# Initial key: 12694; new key: 12677
# Round 8 switching results:
#  left partition: 43221
#  right partition: 33850
#
# Round 9:
#  right partition(after applied F, Key:12677): 33850
#  left partition(after XOR with right, right:33850): 7530
# Initial key: 12677; new key: 12692
# Round 9 switching results:
#  left partition: 33850
#  right partition: 7530
#
# Round 10:
#  right partition(after applied F, Key:12692): 7530
#  left partition(after XOR with right, right:7530): 43204
# Initial key: 12692; new key: 12675
# Round 10 switching results:
#  left partition: 7530
#  right partition: 43204
#
# Round 11:
#  right partition(after applied F, Key:12675): 43204
#  left partition(after XOR with right, right:43204): 33837
# Initial key: 12675; new key: 12690
# Round 11 switching results:
#  left partition: 43204
#  right partition: 33837
#
# Round 12:
#  right partition(after applied F, Key:12690): 33837
#  left partition(after XOR with right, right:33837): 7547
# Initial key: 12690; new key: 12673
# Round 12 switching results:
#  left partition: 33837
#  right partition: 7547
#
# Round 13:
#  right partition(after applied F, Key:12673): 7547
#  left partition(after XOR with right, right:7547): 43223
# Initial key: 12673; new key: 12688
# Round 13 switching results:
#  left partition: 7547
#  right partition: 43223
#
# Round 14:
#  right partition(after applied F, Key:12688): 43223
#  left partition(after XOR with right, right:43223): 33852
# Initial key: 12688; new key: 12671
# Round 14 switching results:
#  left partition: 43223
#  right partition: 33852
#
# Round 15:
#  right partition(after applied F, Key:12671): 33852
#  left partition(after XOR with right, right:33852): 7572
# Initial key: 12671; new key: 12654
# Round 15 switching results:
#  left partition: 33852
#  right partition: 7572
#
# Round 16:
#  right partition(after applied F, Key:12654): 7572
#  left partition(after XOR with right, right:7572): 43206
# Initial key: 12654; new key: 12669
# Round 16 switching results:
#  left partition: 7572
#  right partition: 43206
#
# Final left partition: 43206
# Initial right partition: 7572
#
# Initial key: 12702; new key: 12685
# Initial left partition: 48168
# Initial right partition: 28925
#
# Round 1:
#  right partition(after applied F, Key:12685): 28925
#  left partition(after XOR with right, right:28925): 64856
# Initial key: 12685; new key: 12700
# Round 1 switching results:
#  left partition: 28925
#  right partition: 64856
#
# Round 2:
#  right partition(after applied F, Key:12700): 64856
#  left partition(after XOR with right, right:64856): 48185
# Initial key: 12700; new key: 12683
# Round 2 switching results:
#  left partition: 64856
#  right partition: 48185
#
# Round 3:
#  right partition(after applied F, Key:12683): 48185
#  left partition(after XOR with right, right:48185): 28906
# Initial key: 12683; new key: 12698
# Round 3 switching results:
#  left partition: 48185
#  right partition: 28906
#
# Round 4:
#  right partition(after applied F, Key:12698): 28906
#  left partition(after XOR with right, right:28906): 64841
# Initial key: 12698; new key: 12681
# Round 4 switching results:
#  left partition: 28906
#  right partition: 64841
#
# Round 5:
#  right partition(after applied F, Key:12681): 64841
#  left partition(after XOR with right, right:64841): 48170
# Initial key: 12681; new key: 12696
# Round 5 switching results:
#  left partition: 64841
#  right partition: 48170
#
# Round 6:
#  right partition(after applied F, Key:12696): 48170
#  left partition(after XOR with right, right:48170): 28923
# Initial key: 12696; new key: 12679
# Round 6 switching results:
#  left partition: 48170
#  right partition: 28923
#
# Round 7:
#  right partition(after applied F, Key:12679): 28923
#  left partition(after XOR with right, right:28923): 64854
# Initial key: 12679; new key: 12694
# Round 7 switching results:
#  left partition: 28923
#  right partition: 64854
#
# Round 8:
#  right partition(after applied F, Key:12694): 64854
#  left partition(after XOR with right, right:64854): 48187
# Initial key: 12694; new key: 12677
# Round 8 switching results:
#  left partition: 64854
#  right partition: 48187
#
# Round 9:
#  right partition(after applied F, Key:12677): 48187
#  left partition(after XOR with right, right:48187): 28904
# Initial key: 12677; new key: 12692
# Round 9 switching results:
#  left partition: 48187
#  right partition: 28904
#
# Round 10:
#  right partition(after applied F, Key:12692): 28904
#  left partition(after XOR with right, right:28904): 64839
# Initial key: 12692; new key: 12675
# Round 10 switching results:
#  left partition: 28904
#  right partition: 64839
#
# Round 11:
#  right partition(after applied F, Key:12675): 64839
#  left partition(after XOR with right, right:64839): 48172
# Initial key: 12675; new key: 12690
# Round 11 switching results:
#  left partition: 64839
#  right partition: 48172
#
# Round 12:
#  right partition(after applied F, Key:12690): 48172
#  left partition(after XOR with right, right:48172): 28921
# Initial key: 12690; new key: 12673
# Round 12 switching results:
#  left partition: 48172
#  right partition: 28921
#
# Round 13:
#  right partition(after applied F, Key:12673): 28921
#  left partition(after XOR with right, right:28921): 64852
# Initial key: 12673; new key: 12688
# Round 13 switching results:
#  left partition: 28921
#  right partition: 64852
#
# Round 14:
#  right partition(after applied F, Key:12688): 64852
#  left partition(after XOR with right, right:64852): 48189
# Initial key: 12688; new key: 12671
# Round 14 switching results:
#  left partition: 64852
#  right partition: 48189
#
# Round 15:
#  right partition(after applied F, Key:12671): 48189
#  left partition(after XOR with right, right:48189): 28694
# Initial key: 12671; new key: 12654
# Round 15 switching results:
#  left partition: 48189
#  right partition: 28694
#
# Round 16:
#  right partition(after applied F, Key:12654): 28694
#  left partition(after XOR with right, right:28694): 64837
# Initial key: 12654; new key: 12669
# Round 16 switching results:
#  left partition: 28694
#  right partition: 64837
#
# Final left partition: 64837
# Initial right partition: 28694
#
# Initial key: 12702; new key: 12685
# Initial left partition: 62382
# Initial right partition: 20534
#
# Round 1:
#  right partition(after applied F, Key:12685): 20534
#  left partition(after XOR with right, right:20534): 37397
# Initial key: 12685; new key: 12700
# Round 1 switching results:
#  left partition: 20534
#  right partition: 37397
#
# Round 2:
#  right partition(after applied F, Key:12700): 37397
#  left partition(after XOR with right, right:37397): 62399
# Initial key: 12700; new key: 12683
# Round 2 switching results:
#  left partition: 37397
#  right partition: 62399
#
# Round 3:
#  right partition(after applied F, Key:12683): 62399
#  left partition(after XOR with right, right:62399): 20513
# Initial key: 12683; new key: 12698
# Round 3 switching results:
#  left partition: 62399
#  right partition: 20513
#
# Round 4:
#  right partition(after applied F, Key:12698): 20513
#  left partition(after XOR with right, right:20513): 37380
# Initial key: 12698; new key: 12681
# Round 4 switching results:
#  left partition: 20513
#  right partition: 37380
#
# Round 5:
#  right partition(after applied F, Key:12681): 37380
#  left partition(after XOR with right, right:37380): 62380
# Initial key: 12681; new key: 12696
# Round 5 switching results:
#  left partition: 37380
#  right partition: 62380
#
# Round 6:
#  right partition(after applied F, Key:12696): 62380
#  left partition(after XOR with right, right:62380): 20528
# Initial key: 12696; new key: 12679
# Round 6 switching results:
#  left partition: 62380
#  right partition: 20528
#
# Round 7:
#  right partition(after applied F, Key:12679): 20528
#  left partition(after XOR with right, right:20528): 37403
# Initial key: 12679; new key: 12694
# Round 7 switching results:
#  left partition: 20528
#  right partition: 37403
#
# Round 8:
#  right partition(after applied F, Key:12694): 37403
#  left partition(after XOR with right, right:37403): 62397
# Initial key: 12694; new key: 12677
# Round 8 switching results:
#  left partition: 37403
#  right partition: 62397
#
# Round 9:
#  right partition(after applied F, Key:12677): 62397
#  left partition(after XOR with right, right:62397): 20515
# Initial key: 12677; new key: 12692
# Round 9 switching results:
#  left partition: 62397
#  right partition: 20515
#
# Round 10:
#  right partition(after applied F, Key:12692): 20515
#  left partition(after XOR with right, right:20515): 37386
# Initial key: 12692; new key: 12675
# Round 10 switching results:
#  left partition: 20515
#  right partition: 37386
#
# Round 11:
#  right partition(after applied F, Key:12675): 37386
#  left partition(after XOR with right, right:37386): 62378
# Initial key: 12675; new key: 12690
# Round 11 switching results:
#  left partition: 37386
#  right partition: 62378
#
# Round 12:
#  right partition(after applied F, Key:12690): 62378
#  left partition(after XOR with right, right:62378): 20530
# Initial key: 12690; new key: 12673
# Round 12 switching results:
#  left partition: 62378
#  right partition: 20530
#
# Round 13:
#  right partition(after applied F, Key:12673): 20530
#  left partition(after XOR with right, right:20530): 37401
# Initial key: 12673; new key: 12688
# Round 13 switching results:
#  left partition: 20530
#  right partition: 37401
#
# Round 14:
#  right partition(after applied F, Key:12688): 37401
#  left partition(after XOR with right, right:37401): 62395
# Initial key: 12688; new key: 12671
# Round 14 switching results:
#  left partition: 37401
#  right partition: 62395
#
# Round 15:
#  right partition(after applied F, Key:12671): 62395
#  left partition(after XOR with right, right:62395): 20701
# Initial key: 12671; new key: 12654
# Round 15 switching results:
#  left partition: 62395
#  right partition: 20701
#
# Round 16:
#  right partition(after applied F, Key:12654): 20701
#  left partition(after XOR with right, right:20701): 37384
# Initial key: 12654; new key: 12669
# Round 16 switching results:
#  left partition: 20701
#  right partition: 37384
#
# Final left partition: 37384
# Initial right partition: 20701
#
# CPU times: user 2.76 ms, sys: 116 µs, total: 2.87 ms
# Wall time: 3.14 ms

# %%
HMAC_Value = HMAC(text, key_hmac, len_of_block_hmac, iv_hmac)
bin(HMAC_Value)
# Out:
# inner_hash: 0b111100011000000
# '0b110111000001000'

# %%
cipher_list_appended = cipher_list.copy()
cipher_list_appended.append([HMAC_Value])
cipher_list_appended
# Out:
# [b'\xec}`\x9c',
#  b'\xa5\xd5\x17\x18',
#  b'\x95\xfbs\xd2',
#  b'\x9fo\x1bP',
#  b'\xaf\x17r\xc8',
#  b'\xa3\x9d\x1dV',
#  b'\xc6\xa2=\xdc',
#  b'\x84)\x1d\x7f',
#  b'\xbc(p\xfd',
#  b'\xf3\xaeP6',
#  [28168]]

# %% [markdown]
# ### Results
# #### Plain Text

# %%
# plaintext
for i in blockList:
    print ([(i[k]) for k in range(len(i))])
# Out:
# ['H', 'e', 'l', 'l']
# ['o', ' ', 'w', 'o']
# ['r', 'l', 'd', '!']
# [' ', 'T', 'h', 'i']
# ['s', ' ', 'i', 's']
# [' ', 'L', 'o', 'u']
# ['i', 's', ' ', 'a']
# ['n', 'd', ' ', 'H']
# ['y', 'l', 'm', 'i']
# ['.', ' ', ' ', ' ']

# %% [markdown]
# #### Original Cipher Text

# %%
# ciphertext
for i in cipher_list:
    print ([chr(i[k]) for k in range(len(i))])
# Out:
# ['ì', '}', '`', '\x9c']
# ['¥', 'Õ', '\x17', '\x18']
# ['\x95', 'û', 's', 'Ò']
# ['\x9f', 'o', '\x1b', 'P']
# ['¯', '\x17', 'r', 'È']
# ['£', '\x9d', '\x1d', 'V']
# ['Æ', '¢', '=', 'Ü']
# ['\x84', ')', '\x1d', '\x7f']
# ['¼', '(', 'p', 'ý']
# ['ó', '®', 'P', '6']

# %% [markdown]
# #### HMAC Appended Cipher Text

# %%
# ciphertext
for i in cipher_list_appended:
    print ([chr(i[k]) for k in range(len(i))])
# Out:
# ['ì', '}', '`', '\x9c']
# ['¥', 'Õ', '\x17', '\x18']
# ['\x95', 'û', 's', 'Ò']
# ['\x9f', 'o', '\x1b', 'P']
# ['¯', '\x17', 'r', 'È']
# ['£', '\x9d', '\x1d', 'V']
# ['Æ', '¢', '=', 'Ü']
# ['\x84', ')', '\x1d', '\x7f']
# ['¼', '(', 'p', 'ý']
# ['ó', '®', 'P', '6']
# ['済']

# %% [markdown]
# #### Decrypted Back to Plain Text

# %%
# plaintext
for i in decrypted_list:
    print ([(i[k]) for k in range(len(i))])
# Out:
# ['H', 'e', 'l', 'l']
# ['o', ',', ' ', 'W']
# ['o', 'r', 'l', 'd']
# ['!', ' ', ' ', ' ']

# %% [markdown]
# © 2024 - Fathi Al Adha Hylmi & Louis Widi Anandaputra
